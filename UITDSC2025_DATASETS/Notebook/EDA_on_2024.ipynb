# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
import gdown

# %%
file_id = "10UvPQkdsvKq2bQ07nXjFtDPgo4aCTas9"
url = f"https://drive.google.com/uc?id={file_id}"
output = "PAPI.csv"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10UvPQkdsvKq2bQ07nXjFtDPgo4aCTas9
# To: /content/PAPI.csv
# 100%|██████████| 112k/112k [00:00<00:00, 11.7MB/s]
# 'PAPI.csv'

# %%
df = pd.read_csv("PAPI.csv")

# %%
df.head()
# Out:
#   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                Unweighted PAPI Score
# 1                Unweighted 95% CI Low
# 2               Unweighted 95% CI High
# 3            Unweighted Standard Error
# 4           Dimension 1: Participation
#
#               Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0           Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3  Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4  Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
#
#       Hà Nội   Cao Bằng  Tuyên Quang    Lào Cai  Điện Biên   Lai Châu  \
# 0  43.774715  41.332478    43.172611  41.849570  41.375828  43.479568
# 1  43.220791  39.598320    40.406404  39.282421  40.439476  42.184723
# 2  44.328640  43.066635    45.938817  44.416718  42.312180  44.774414
# 3   0.282599   0.884728     1.411256   1.309701   0.477706   0.660600
# 4   5.392270   4.640318     5.185756   4.870843   4.631536   5.236279
#
#       Sơn La  ...    Đắk Lắk   Lâm Đồng   Tây Ninh   Đồng Nai  \
# 0  43.887550  ...  42.257508  43.254680  44.313948  41.776783
# 1  42.421448  ...  41.795035  41.070513  41.749232  40.995208
# 2  45.353653  ...  42.719981  45.438847  46.878664  42.558359
# 3   0.747973  ...   0.235944   1.114312   1.308460   0.398741
# 4   5.204468  ...   4.619146   5.052988   4.970453   4.552126
#
#    TP. Hồ Chí Minh  Vĩnh Long  Đồng Tháp   An Giang    Cần Thơ     Cà Mau
# 0        43.602789  41.647474  43.835712  41.442199  43.001186  44.341113
# 1        42.301961  40.422285  42.028534  40.933153  41.403448  42.661096
# 2        44.903617  42.872662  45.642891  41.951246  44.598925  46.021130
# 3         0.663653   0.625063   0.921980   0.259704   0.815130   0.857106
# 4         4.801750   4.282942   4.590105   4.197340   4.295279   4.629526
#
# [5 rows x 37 columns]

# %%
# Bỏ cột "Thang điểm"
df = df.drop(columns=["Tỉnh/Thành phố trực thuộc trung ương","Thang điểm"])

# %%
df
# Out:
#                 Tỉnh/Thành phố trực thuộc trung ương.1     Hà Nội   Cao Bằng  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  43.774715  41.332478
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...  43.220791  39.598320
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...  44.328640  43.066635
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...   0.282599   0.884728
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   5.392270   4.640318
# ..                                                 ...        ...        ...
# 153  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...   0.056600   0.026064
# 154  Tỉ lệ người trả lời cho biết cổng thông tin đi...   0.353380   0.239384
# 155  Tỉ lệ người trả lời cho biết chính quyền địa p...   0.708495   0.553371
# 156  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...   0.141238   0.055113
# 157  Tỉ lệ người trả lời cho biết đã có thể thanh t...   0.471960   0.500000
#
#      Tuyên Quang    Lào Cai  Điện Biên   Lai Châu     Sơn La  Thái Nguyên  \
# 0      43.172611  41.849570  41.375828  43.479568  43.887550    45.951166
# 1      40.406404  39.282421  40.439476  42.184723  42.421448    43.167816
# 2      45.938817  44.416718  42.312180  44.774414  45.353653    48.734515
# 3       1.411256   1.309701   0.477706   0.660600   0.747973     1.420002
# 4       5.185756   4.870843   4.631536   5.236279   5.204468     5.745524
# ..           ...        ...        ...        ...        ...          ...
# 153     0.027067   0.027218   0.058202   0.027195   0.024436     0.028907
# 154     0.293513   0.302954   0.261197   0.254240   0.220296     0.316818
# 155     0.635558   0.617914   0.426394   0.605962   0.715403     0.718433
# 156     0.111842   0.097909   0.105953   0.148090   0.065027     0.156004
# 157     0.312237   0.556383   0.236565   0.336390   0.547157     0.610030
#
#       Lạng Sơn  ...    Đắk Lắk   Lâm Đồng   Tây Ninh   Đồng Nai  \
# 0    45.003624  ...  42.257508  43.254680  44.313948  41.776783
# 1    43.075245  ...  41.795035  41.070513  41.749232  40.995208
# 2    46.932003  ...  42.719981  45.438847  46.878664  42.558359
# 3     0.983815  ...   0.235944   1.114312   1.308460   0.398741
# 4     5.525624  ...   4.619146   5.052988   4.970453   4.552126
# ..         ...  ...        ...        ...        ...        ...
# 153   0.027696  ...   0.027130   0.044986   0.036765   0.025050
# 154   0.274446  ...   0.270121   0.345057   0.291351   0.246635
# 155   0.649323  ...   0.575117   0.525561   0.466039   0.488611
# 156   0.076172  ...   0.079242   0.105896   0.152288   0.081313
# 157   0.521093  ...   0.450618   0.454270   0.381205   0.225668
#
#      TP. Hồ Chí Minh  Vĩnh Long  Đồng Tháp   An Giang    Cần Thơ     Cà Mau
# 0          43.602789  41.647474  43.835712  41.442199  43.001186  44.341113
# 1          42.301961  40.422285  42.028534  40.933153  41.403448  42.661096
# 2          44.903617  42.872662  45.642891  41.951246  44.598925  46.021130
# 3           0.663653   0.625063   0.921980   0.259704   0.815130   0.857106
# 4           4.801750   4.282942   4.590105   4.197340   4.295279   4.629526
# ..               ...        ...        ...        ...        ...        ...
# 153         0.052651   0.015919   0.019064   0.029313   0.033897   0.034603
# 154         0.309688   0.275834   0.302844   0.191044   0.243858   0.293825
# 155         0.467078   0.416730   0.558704   0.455431   0.507878   0.509261
# 156         0.117665   0.047179   0.094828   0.029056   0.086086   0.117165
# 157         0.500791   0.573702   0.586522   0.763015   0.415016   0.576555
#
# [158 rows x 35 columns]

# %%
df = df.rename(columns={df.columns[0]: 'Tỉnh/Thành phố trực thuộc trung ương'})

# %%
df
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương     Hà Nội   Cao Bằng  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  43.774715  41.332478
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...  43.220791  39.598320
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...  44.328640  43.066635
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...   0.282599   0.884728
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   5.392270   4.640318
# ..                                                 ...        ...        ...
# 153  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...   0.056600   0.026064
# 154  Tỉ lệ người trả lời cho biết cổng thông tin đi...   0.353380   0.239384
# 155  Tỉ lệ người trả lời cho biết chính quyền địa p...   0.708495   0.553371
# 156  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...   0.141238   0.055113
# 157  Tỉ lệ người trả lời cho biết đã có thể thanh t...   0.471960   0.500000
#
#      Tuyên Quang    Lào Cai  Điện Biên   Lai Châu     Sơn La  Thái Nguyên  \
# 0      43.172611  41.849570  41.375828  43.479568  43.887550    45.951166
# 1      40.406404  39.282421  40.439476  42.184723  42.421448    43.167816
# 2      45.938817  44.416718  42.312180  44.774414  45.353653    48.734515
# 3       1.411256   1.309701   0.477706   0.660600   0.747973     1.420002
# 4       5.185756   4.870843   4.631536   5.236279   5.204468     5.745524
# ..           ...        ...        ...        ...        ...          ...
# 153     0.027067   0.027218   0.058202   0.027195   0.024436     0.028907
# 154     0.293513   0.302954   0.261197   0.254240   0.220296     0.316818
# 155     0.635558   0.617914   0.426394   0.605962   0.715403     0.718433
# 156     0.111842   0.097909   0.105953   0.148090   0.065027     0.156004
# 157     0.312237   0.556383   0.236565   0.336390   0.547157     0.610030
#
#       Lạng Sơn  ...    Đắk Lắk   Lâm Đồng   Tây Ninh   Đồng Nai  \
# 0    45.003624  ...  42.257508  43.254680  44.313948  41.776783
# 1    43.075245  ...  41.795035  41.070513  41.749232  40.995208
# 2    46.932003  ...  42.719981  45.438847  46.878664  42.558359
# 3     0.983815  ...   0.235944   1.114312   1.308460   0.398741
# 4     5.525624  ...   4.619146   5.052988   4.970453   4.552126
# ..         ...  ...        ...        ...        ...        ...
# 153   0.027696  ...   0.027130   0.044986   0.036765   0.025050
# 154   0.274446  ...   0.270121   0.345057   0.291351   0.246635
# 155   0.649323  ...   0.575117   0.525561   0.466039   0.488611
# 156   0.076172  ...   0.079242   0.105896   0.152288   0.081313
# 157   0.521093  ...   0.450618   0.454270   0.381205   0.225668
#
#      TP. Hồ Chí Minh  Vĩnh Long  Đồng Tháp   An Giang    Cần Thơ     Cà Mau
# 0          43.602789  41.647474  43.835712  41.442199  43.001186  44.341113
# 1          42.301961  40.422285  42.028534  40.933153  41.403448  42.661096
# 2          44.903617  42.872662  45.642891  41.951246  44.598925  46.021130
# 3           0.663653   0.625063   0.921980   0.259704   0.815130   0.857106
# 4           4.801750   4.282942   4.590105   4.197340   4.295279   4.629526
# ..               ...        ...        ...        ...        ...        ...
# 153         0.052651   0.015919   0.019064   0.029313   0.033897   0.034603
# 154         0.309688   0.275834   0.302844   0.191044   0.243858   0.293825
# 155         0.467078   0.416730   0.558704   0.455431   0.507878   0.509261
# 156         0.117665   0.047179   0.094828   0.029056   0.086086   0.117165
# 157         0.500791   0.573702   0.586522   0.763015   0.415016   0.576555
#
# [158 rows x 35 columns]

# %%
# Đặt cột "Tỉnh/Thành phố trực thuộc trung ương" làm index tạm
df = df.set_index("Tỉnh/Thành phố trực thuộc trung ương")

# Chuyển vị
df = df.T

# Reset index để tỉnh/thành trở thành 1 cột
df = df.reset_index().rename(columns={"index": "Tỉnh/Thành phố"})

# %%
df
# Out:
# Tỉnh/Thành phố trực thuộc trung ương   Tỉnh/Thành phố  \
# 0                                              Hà Nội
# 1                                            Cao Bằng
# 2                                         Tuyên Quang
# 3                                             Lào Cai
# 4                                           Điện Biên
# 5                                            Lai Châu
# 6                                              Sơn La
# 7                                         Thái Nguyên
# 8                                            Lạng Sơn
# 9                                          Quảng Ninh
# 10                                            Phú Thọ
# 11                                           Bắc Ninh
# 12                                          Hải Phòng
# 13                                           Hưng Yên
# 14                                          Ninh Bình
# 15                                          Thanh Hóa
# 16                                            Nghệ An
# 17                                            Hà Tĩnh
# 18                                          Quảng Trị
# 19                                     Thừa Thiên-Huế
# 20                                            Đà Nẵng
# 21                                         Quảng Ngãi
# 22                                          Khánh Hòa
# 23                                            Gia Lai
# 24                                            Đắk Lắk
# 25                                           Lâm Đồng
# 26                                           Tây Ninh
# 27                                           Đồng Nai
# 28                                    TP. Hồ Chí Minh
# 29                                          Vĩnh Long
# 30                                          Đồng Tháp
# 31                                           An Giang
# 32                                            Cần Thơ
# 33                                             Cà Mau
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số)  \
# 0                                                                    43.774715
# 1                                                                    41.332478
# 2                                                                    43.172611
# 3                                                                    41.849570
# 4                                                                    41.375828
# 5                                                                    43.479568
# 6                                                                    43.887550
# 7                                                                    45.951166
# 8                                                                    45.003624
# 9                                                                    47.821236
# 10                                                                   44.063235
# 11                                                                   45.028375
# 12                                                                   42.650545
# 13                                                                   44.602359
# 14                                                                   44.019932
# 15                                                                   44.870750
# 16                                                                   43.069889
# 17                                                                   45.553085
# 18                                                                   44.217131
# 19                                                                   45.095047
# 20                                                                   42.029420
# 21                                                                   42.197246
# 22                                                                   44.414544
# 23                                                                   42.341797
# 24                                                                   42.257508
# 25                                                                   43.254680
# 26                                                                   44.313948
# 27                                                                   41.776783
# 28                                                                   43.602789
# 29                                                                   41.647474
# 30                                                                   43.835712
# 31                                                                   41.442199
# 32                                                                   43.001186
# 33                                                                   44.341113
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%  \
# 0                                                                             43.220791
# 1                                                                             39.598320
# 2                                                                             40.406404
# 3                                                                             39.282421
# 4                                                                             40.439476
# 5                                                                             42.184723
# 6                                                                             42.421448
# 7                                                                             43.167816
# 8                                                                             43.075245
# 9                                                                             46.906075
# 10                                                                            43.585484
# 11                                                                            43.840976
# 12                                                                            40.559065
# 13                                                                            43.457243
# 14                                                                            43.340717
# 15                                                                            44.529171
# 16                                                                            42.400673
# 17                                                                            44.707905
# 18                                                                            43.596582
# 19                                                                            44.521580
# 20                                                                            41.054775
# 21                                                                            40.942642
# 22                                                                            42.916039
# 23                                                                            41.439915
# 24                                                                            41.795035
# 25                                                                            41.070513
# 26                                                                            41.749232
# 27                                                                            40.995208
# 28                                                                            42.301961
# 29                                                                            40.422285
# 30                                                                            42.028534
# 31                                                                            40.933153
# 32                                                                            41.403448
# 33                                                                            42.661096
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%  \
# 0                                                                             44.328640
# 1                                                                             43.066635
# 2                                                                             45.938817
# 3                                                                             44.416718
# 4                                                                             42.312180
# 5                                                                             44.774414
# 6                                                                             45.353653
# 7                                                                             48.734515
# 8                                                                             46.932003
# 9                                                                             48.736397
# 10                                                                            44.540986
# 11                                                                            46.215775
# 12                                                                            44.742025
# 13                                                                            45.747474
# 14                                                                            44.699147
# 15                                                                            45.212330
# 16                                                                            43.739105
# 17                                                                            46.398266
# 18                                                                            44.837680
# 19                                                                            45.668514
# 20                                                                            43.004065
# 21                                                                            43.451849
# 22                                                                            45.913050
# 23                                                                            43.243678
# 24                                                                            42.719981
# 25                                                                            45.438847
# 26                                                                            46.878664
# 27                                                                            42.558359
# 28                                                                            44.903617
# 29                                                                            42.872662
# 30                                                                            45.642891
# 31                                                                            41.951246
# 32                                                                            44.598925
# 33                                                                            46.021130
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - sai số   \
# 0                                                                              0.282599
# 1                                                                              0.884728
# 2                                                                              1.411256
# 3                                                                              1.309701
# 4                                                                              0.477706
# 5                                                                              0.660600
# 6                                                                              0.747973
# 7                                                                              1.420002
# 8                                                                              0.983815
# 9                                                                              0.466895
# 10                                                                             0.243737
# 11                                                                             0.605785
# 12                                                                             1.067026
# 13                                                                             0.584211
# 14                                                                             0.346520
# 15                                                                             0.174267
# 16                                                                             0.341418
# 17                                                                             0.431191
# 18                                                                             0.316590
# 19                                                                             0.292570
# 20                                                                             0.497242
# 21                                                                             0.640070
# 22                                                                             0.764503
# 23                                                                             0.460119
# 24                                                                             0.235944
# 25                                                                             1.114312
# 26                                                                             1.308460
# 27                                                                             0.398741
# 28                                                                             0.663653
# 29                                                                             0.625063
# 30                                                                             0.921980
# 31                                                                             0.259704
# 32                                                                             0.815130
# 33                                                                             0.857106
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở  \
# 0                                                                              5.392270
# 1                                                                              4.640318
# 2                                                                              5.185756
# 3                                                                              4.870843
# 4                                                                              4.631536
# 5                                                                              5.236279
# 6                                                                              5.204468
# 7                                                                              5.745524
# 8                                                                              5.525624
# 9                                                                              5.873931
# 10                                                                             5.233066
# 11                                                                             5.803446
# 12                                                                             5.295103
# 13                                                                             5.292784
# 14                                                                             5.586421
# 15                                                                             5.688568
# 16                                                                             5.318382
# 17                                                                             5.841213
# 18                                                                             5.479559
# 19                                                                             5.389178
# 20                                                                             4.558244
# 21                                                                             4.695246
# 22                                                                             4.571488
# 23                                                                             4.675178
# 24                                                                             4.619146
# 25                                                                             5.052988
# 26                                                                             4.970453
# 27                                                                             4.552126
# 28                                                                             4.801750
# 29                                                                             4.282942
# 30                                                                             4.590105
# 31                                                                             4.197340
# 32                                                                             4.295279
# 33                                                                             4.629526
#
# Tỉnh/Thành phố trực thuộc trung ương  1.1: Tri thức công dân  \
# 0                                                   1.425716
# 1                                                   1.056708
# 2                                                   0.993409
# 3                                                   0.954209
# 4                                                   0.940827
# 5                                                   1.033711
# 6                                                   1.139144
# 7                                                   1.357657
# 8                                                   1.035179
# 9                                                   1.294818
# 10                                                  0.969390
# 11                                                  1.141396
# 12                                                  1.238752
# 13                                                  1.134378
# 14                                                  1.207172
# 15                                                  1.143213
# 16                                                  1.099678
# 17                                                  1.261379
# 18                                                  1.215447
# 19                                                  1.200834
# 20                                                  1.074525
# 21                                                  0.958266
# 22                                                  1.192225
# 23                                                  1.056347
# 24                                                  1.000487
# 25                                                  1.050900
# 26                                                  1.059180
# 27                                                  1.031590
# 28                                                  1.187753
# 29                                                  0.950647
# 30                                                  0.969035
# 31                                                  0.876089
# 32                                                  0.944202
# 33                                                  1.147307
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về chính sách hiện hành (%)  \
# 0                                                                  0.810938
# 1                                                                  0.546855
# 2                                                                  0.560756
# 3                                                                  0.581350
# 4                                                                  0.445589
# 5                                                                  0.583741
# 6                                                                  0.612420
# 7                                                                  0.826309
# 8                                                                  0.542324
# 9                                                                  0.644873
# 10                                                                 0.647116
# 11                                                                 0.616262
# 12                                                                 0.582347
# 13                                                                 0.612288
# 14                                                                 0.601887
# 15                                                                 0.620179
# 16                                                                 0.580817
# 17                                                                 0.700623
# 18                                                                 0.720294
# 19                                                                 0.674878
# 20                                                                 0.600858
# 21                                                                 0.597786
# 22                                                                 0.669127
# 23                                                                 0.643389
# 24                                                                 0.583039
# 25                                                                 0.608786
# 26                                                                 0.693287
# 27                                                                 0.583808
# 28                                                                 0.736355
# 29                                                                 0.545741
# 30                                                                 0.609985
# 31                                                                 0.513142
# 32                                                                 0.604132
# 33                                                                 0.730263
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về vị trí lãnh đạo (%)  \
# 0                                                             0.639612
# 1                                                             0.443646
# 2                                                             0.380430
# 3                                                             0.335289
# 4                                                             0.391274
# 5                                                             0.404762
# 6                                                             0.484140
# 7                                                             0.571429
# 8                                                             0.426775
# 9                                                             0.606291
# 10                                                            0.315900
# 11                                                            0.484221
# 12                                                            0.587717
# 13                                                            0.479970
# 14                                                            0.549876
# 15                                                            0.483878
# 16                                                            0.464861
# 17                                                            0.548692
# 18                                                            0.498028
# 19                                                            0.507747
# 20                                                            0.432483
# 21                                                            0.330677
# 22                                                            0.502970
# 23                                                            0.395059
# 24                                                            0.375580
# 25                                                            0.407519
# 26                                                            0.372627
# 27                                                            0.402843
# 28                                                            0.465380
# 29                                                            0.349926
# 30                                                            0.334149
# 31                                                            0.299953
# 32                                                            0.315002
# 33                                                            0.432474
#
# Tỉnh/Thành phố trực thuộc trung ương  1.2: Cơ hội tham gia  ...  \
# 0                                                 1.531022  ...
# 1                                                 1.380181  ...
# 2                                                 1.476668  ...
# 3                                                 1.407232  ...
# 4                                                 1.381613  ...
# 5                                                 1.492470  ...
# 6                                                 1.466421  ...
# 7                                                 1.662174  ...
# 8                                                 1.776866  ...
# 9                                                 1.883087  ...
# 10                                                1.641892  ...
# 11                                                1.800641  ...
# 12                                                1.564284  ...
# 13                                                1.578477  ...
# 14                                                1.582230  ...
# 15                                                1.674948  ...
# 16                                                1.528961  ...
# 17                                                1.521316  ...
# 18                                                1.535966  ...
# 19                                                1.632521  ...
# 20                                                1.323720  ...
# 21                                                1.280490  ...
# 22                                                1.340489  ...
# 23                                                1.266673  ...
# 24                                                1.268819  ...
# 25                                                1.387703  ...
# 26                                                1.259961  ...
# 27                                                1.205145  ...
# 28                                                1.171438  ...
# 29                                                1.102683  ...
# 30                                                1.034663  ...
# 31                                                1.061606  ...
# 32                                                1.021905  ...
# 33                                                1.182422  ...
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm thủ tục cấp giấy chứng nhận quyền sử dụng đất (%)  \
# 0                                                                              0.024610
# 1                                                                              0.032581
# 2                                                                              0.030124
# 3                                                                              0.019233
# 4                                                                              0.027679
# 5                                                                              0.034783
# 6                                                                              0.016291
# 7                                                                              0.027246
# 8                                                                              0.022242
# 9                                                                              0.035881
# 10                                                                             0.026238
# 11                                                                             0.010126
# 12                                                                             0.013761
# 13                                                                             0.026513
# 14                                                                             0.025770
# 15                                                                             0.020536
# 16                                                                             0.011146
# 17                                                                             0.028349
# 18                                                                             0.028430
# 19                                                                             0.029084
# 20                                                                             0.007814
# 21                                                                             0.029836
# 22                                                                             0.035991
# 23                                                                             0.015941
# 24                                                                             0.033316
# 25                                                                             0.027754
# 26                                                                             0.016794
# 27                                                                             0.024571
# 28                                                                             0.024963
# 29                                                                             0.011214
# 30                                                                             0.006824
# 31                                                                             0.014784
# 32                                                                             0.012222
# 33                                                                             0.011214
#
# Tỉnh/Thành phố trực thuộc trung ương  8.2: Tiếp cận và sử dụng Internet tại địa phương  \
# 0                                                                             2.960508
# 1                                                                             2.071751
# 2                                                                             2.371423
# 3                                                                             2.369423
# 4                                                                             2.040645
# 5                                                                             2.418868
# 6                                                                             2.495427
# 7                                                                             2.895742
# 8                                                                             2.391233
# 9                                                                             2.951612
# 10                                                                            2.554278
# 11                                                                            2.812408
# 12                                                                            2.668212
# 13                                                                            2.511301
# 14                                                                            2.507841
# 15                                                                            2.481075
# 16                                                                            2.214779
# 17                                                                            2.415848
# 18                                                                            2.584105
# 19                                                                            2.429445
# 20                                                                            2.407643
# 21                                                                            2.064675
# 22                                                                            2.563160
# 23                                                                            2.239380
# 24                                                                            2.419593
# 25                                                                            2.442737
# 26                                                                            2.740215
# 27                                                                            2.652435
# 28                                                                            2.800175
# 29                                                                            2.187359
# 30                                                                            2.208411
# 31                                                                            2.126201
# 32                                                                            2.384912
# 33                                                                            2.481818
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời tiếp cận tin tức trong nước qua Internet (%)  \
# 0                                                                              0.809756
# 1                                                                              0.592026
# 2                                                                              0.667127
# 3                                                                              0.641752
# 4                                                                              0.620148
# 5                                                                              0.688113
# 6                                                                              0.748441
# 7                                                                              0.817108
# 8                                                                              0.605263
# 9                                                                              0.818354
# 10                                                                             0.681096
# 11                                                                             0.760876
# 12                                                                             0.683314
# 13                                                                             0.584621
# 14                                                                             0.610790
# 15                                                                             0.621056
# 16                                                                             0.598612
# 17                                                                             0.663427
# 18                                                                             0.723515
# 19                                                                             0.591567
# 20                                                                             0.622370
# 21                                                                             0.506959
# 22                                                                             0.631530
# 23                                                                             0.564317
# 24                                                                             0.600636
# 25                                                                             0.653391
# 26                                                                             0.740092
# 27                                                                             0.716352
# 28                                                                             0.736181
# 29                                                                             0.502984
# 30                                                                             0.516773
# 31                                                                             0.449130
# 32                                                                             0.599294
# 33                                                                             0.609702
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có kết nối Internet tại nhà (%)  \
# 0                                                                              0.961630
# 1                                                                              0.580871
# 2                                                                              0.707569
# 3                                                                              0.731597
# 4                                                                              0.531802
# 5                                                                              0.718532
# 6                                                                              0.709759
# 7                                                                              0.910664
# 8                                                                              0.782773
# 9                                                                              0.947042
# 10                                                                             0.816734
# 11                                                                             0.910779
# 12                                                                             0.891239
# 13                                                                             0.884269
# 14                                                                             0.855770
# 15                                                                             0.827479
# 16                                                                             0.670599
# 17                                                                             0.741184
# 18                                                                             0.794401
# 19                                                                             0.822200
# 20                                                                             0.776715
# 21                                                                             0.661173
# 22                                                                             0.872282
# 23                                                                             0.721461
# 24                                                                             0.806498
# 25                                                                             0.769327
# 26                                                                             0.882948
# 27                                                                             0.847578
# 28                                                                             0.927236
# 29                                                                             0.747763
# 30                                                                             0.748151
# 31                                                                             0.760433
# 32                                                                             0.784485
# ...
# 1                                                                              0.553371
# 2                                                                              0.635558
# 3                                                                              0.617914
# 4                                                                              0.426394
# 5                                                                              0.605962
# 6                                                                              0.715403
# 7                                                                              0.718433
# 8                                                                              0.649323
# 9                                                                              0.716405
# 10                                                                             0.657998
# 11                                                                             0.633897
# 12                                                                             0.614363
# 13                                                                             0.643953
# 14                                                                             0.666263
# 15                                                                             0.642437
# 16                                                                             0.695178
# 17                                                                             0.658380
# 18                                                                             0.568511
# 19                                                                             0.732672
# 20                                                                             0.509615
# 21                                                                             0.481912
# 22                                                                             0.636120
# 23                                                                             0.535928
# 24                                                                             0.575117
# 25                                                                             0.525561
# 26                                                                             0.466039
# 27                                                                             0.488611
# 28                                                                             0.467078
# 29                                                                             0.416730
# 30                                                                             0.558704
# 31                                                                             0.455431
# 32                                                                             0.507878
# 33                                                                             0.509261
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)*  \
# 0                                                                              0.141238
# 1                                                                              0.055113
# 2                                                                              0.111842
# 3                                                                              0.097909
# 4                                                                              0.105953
# 5                                                                              0.148090
# 6                                                                              0.065027
# 7                                                                              0.156004
# 8                                                                              0.076172
# 9                                                                              0.157760
# 10                                                                             0.087460
# 11                                                                             0.073548
# 12                                                                             0.094523
# 13                                                                             0.060940
# 14                                                                             0.046175
# 15                                                                             0.038191
# 16                                                                             0.040394
# 17                                                                             0.087851
# 18                                                                             0.067045
# 19                                                                             0.121161
# 20                                                                             0.066263
# 21                                                                             0.078851
# 22                                                                             0.085960
# 23                                                                             0.063890
# 24                                                                             0.079242
# 25                                                                             0.105896
# 26                                                                             0.152288
# 27                                                                             0.081313
# 28                                                                             0.117665
# 29                                                                             0.047179
# 30                                                                             0.094828
# 31                                                                             0.029056
# 32                                                                             0.086086
# 33                                                                             0.117165
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)*
# 0                                                                              0.471960
# 1                                                                              0.500000
# 2                                                                              0.312237
# 3                                                                              0.556383
# 4                                                                              0.236565
# 5                                                                              0.336390
# 6                                                                              0.547157
# 7                                                                              0.610030
# 8                                                                              0.521093
# 9                                                                              0.489023
# 10                                                                             0.639867
# 11                                                                             0.452425
# 12                                                                             0.675447
# 13                                                                             0.626322
# 14                                                                             0.701010
# 15                                                                             0.512061
# 16                                                                             0.579619
# 17                                                                             0.911437
# 18                                                                             0.534350
# 19                                                                             0.443239
# 20                                                                             0.791940
# 21                                                                             0.614700
# 22                                                                             0.492479
# 23                                                                             0.816413
# 24                                                                             0.450618
# 25                                                                             0.454270
# 26                                                                             0.381205
# 27                                                                             0.225668
# 28                                                                             0.500791
# 29                                                                             0.573702
# 30                                                                             0.586522
# 31                                                                             0.763015
# 32                                                                             0.415016
# 33                                                                             0.576555
#
# [34 rows x 159 columns]

# %%
# Xóa dấu * ở cuối hoặc giữa tên cột
df.columns = df.columns.str.replace(r"\*", "", regex=True).str.strip()

# %%
df
# Out:
# Tỉnh/Thành phố trực thuộc trung ương   Tỉnh/Thành phố  \
# 0                                              Hà Nội
# 1                                            Cao Bằng
# 2                                         Tuyên Quang
# 3                                             Lào Cai
# 4                                           Điện Biên
# 5                                            Lai Châu
# 6                                              Sơn La
# 7                                         Thái Nguyên
# 8                                            Lạng Sơn
# 9                                          Quảng Ninh
# 10                                            Phú Thọ
# 11                                           Bắc Ninh
# 12                                          Hải Phòng
# 13                                           Hưng Yên
# 14                                          Ninh Bình
# 15                                          Thanh Hóa
# 16                                            Nghệ An
# 17                                            Hà Tĩnh
# 18                                          Quảng Trị
# 19                                     Thừa Thiên-Huế
# 20                                            Đà Nẵng
# 21                                         Quảng Ngãi
# 22                                          Khánh Hòa
# 23                                            Gia Lai
# 24                                            Đắk Lắk
# 25                                           Lâm Đồng
# 26                                           Tây Ninh
# 27                                           Đồng Nai
# 28                                    TP. Hồ Chí Minh
# 29                                          Vĩnh Long
# 30                                          Đồng Tháp
# 31                                           An Giang
# 32                                            Cần Thơ
# 33                                             Cà Mau
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số)  \
# 0                                                                    43.774715
# 1                                                                    41.332478
# 2                                                                    43.172611
# 3                                                                    41.849570
# 4                                                                    41.375828
# 5                                                                    43.479568
# 6                                                                    43.887550
# 7                                                                    45.951166
# 8                                                                    45.003624
# 9                                                                    47.821236
# 10                                                                   44.063235
# 11                                                                   45.028375
# 12                                                                   42.650545
# 13                                                                   44.602359
# 14                                                                   44.019932
# 15                                                                   44.870750
# 16                                                                   43.069889
# 17                                                                   45.553085
# 18                                                                   44.217131
# 19                                                                   45.095047
# 20                                                                   42.029420
# 21                                                                   42.197246
# 22                                                                   44.414544
# 23                                                                   42.341797
# 24                                                                   42.257508
# 25                                                                   43.254680
# 26                                                                   44.313948
# 27                                                                   41.776783
# 28                                                                   43.602789
# 29                                                                   41.647474
# 30                                                                   43.835712
# 31                                                                   41.442199
# 32                                                                   43.001186
# 33                                                                   44.341113
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%  \
# 0                                                                             43.220791
# 1                                                                             39.598320
# 2                                                                             40.406404
# 3                                                                             39.282421
# 4                                                                             40.439476
# 5                                                                             42.184723
# 6                                                                             42.421448
# 7                                                                             43.167816
# 8                                                                             43.075245
# 9                                                                             46.906075
# 10                                                                            43.585484
# 11                                                                            43.840976
# 12                                                                            40.559065
# 13                                                                            43.457243
# 14                                                                            43.340717
# 15                                                                            44.529171
# 16                                                                            42.400673
# 17                                                                            44.707905
# 18                                                                            43.596582
# 19                                                                            44.521580
# 20                                                                            41.054775
# 21                                                                            40.942642
# 22                                                                            42.916039
# 23                                                                            41.439915
# 24                                                                            41.795035
# 25                                                                            41.070513
# 26                                                                            41.749232
# 27                                                                            40.995208
# 28                                                                            42.301961
# 29                                                                            40.422285
# 30                                                                            42.028534
# 31                                                                            40.933153
# 32                                                                            41.403448
# 33                                                                            42.661096
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%  \
# 0                                                                             44.328640
# 1                                                                             43.066635
# 2                                                                             45.938817
# 3                                                                             44.416718
# 4                                                                             42.312180
# 5                                                                             44.774414
# 6                                                                             45.353653
# 7                                                                             48.734515
# 8                                                                             46.932003
# 9                                                                             48.736397
# 10                                                                            44.540986
# 11                                                                            46.215775
# 12                                                                            44.742025
# 13                                                                            45.747474
# 14                                                                            44.699147
# 15                                                                            45.212330
# 16                                                                            43.739105
# 17                                                                            46.398266
# 18                                                                            44.837680
# 19                                                                            45.668514
# 20                                                                            43.004065
# 21                                                                            43.451849
# 22                                                                            45.913050
# 23                                                                            43.243678
# 24                                                                            42.719981
# 25                                                                            45.438847
# 26                                                                            46.878664
# 27                                                                            42.558359
# 28                                                                            44.903617
# 29                                                                            42.872662
# 30                                                                            45.642891
# 31                                                                            41.951246
# 32                                                                            44.598925
# 33                                                                            46.021130
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - sai số  \
# 0                                                                              0.282599
# 1                                                                              0.884728
# 2                                                                              1.411256
# 3                                                                              1.309701
# 4                                                                              0.477706
# 5                                                                              0.660600
# 6                                                                              0.747973
# 7                                                                              1.420002
# 8                                                                              0.983815
# 9                                                                              0.466895
# 10                                                                             0.243737
# 11                                                                             0.605785
# 12                                                                             1.067026
# 13                                                                             0.584211
# 14                                                                             0.346520
# 15                                                                             0.174267
# 16                                                                             0.341418
# 17                                                                             0.431191
# 18                                                                             0.316590
# 19                                                                             0.292570
# 20                                                                             0.497242
# 21                                                                             0.640070
# 22                                                                             0.764503
# 23                                                                             0.460119
# 24                                                                             0.235944
# 25                                                                             1.114312
# 26                                                                             1.308460
# 27                                                                             0.398741
# 28                                                                             0.663653
# 29                                                                             0.625063
# 30                                                                             0.921980
# 31                                                                             0.259704
# 32                                                                             0.815130
# 33                                                                             0.857106
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở  \
# 0                                                                              5.392270
# 1                                                                              4.640318
# 2                                                                              5.185756
# 3                                                                              4.870843
# 4                                                                              4.631536
# 5                                                                              5.236279
# 6                                                                              5.204468
# 7                                                                              5.745524
# 8                                                                              5.525624
# 9                                                                              5.873931
# 10                                                                             5.233066
# 11                                                                             5.803446
# 12                                                                             5.295103
# 13                                                                             5.292784
# 14                                                                             5.586421
# 15                                                                             5.688568
# 16                                                                             5.318382
# 17                                                                             5.841213
# 18                                                                             5.479559
# 19                                                                             5.389178
# 20                                                                             4.558244
# 21                                                                             4.695246
# 22                                                                             4.571488
# 23                                                                             4.675178
# 24                                                                             4.619146
# 25                                                                             5.052988
# 26                                                                             4.970453
# 27                                                                             4.552126
# 28                                                                             4.801750
# 29                                                                             4.282942
# 30                                                                             4.590105
# 31                                                                             4.197340
# 32                                                                             4.295279
# 33                                                                             4.629526
#
# Tỉnh/Thành phố trực thuộc trung ương  1.1: Tri thức công dân  \
# 0                                                   1.425716
# 1                                                   1.056708
# 2                                                   0.993409
# 3                                                   0.954209
# 4                                                   0.940827
# 5                                                   1.033711
# 6                                                   1.139144
# 7                                                   1.357657
# 8                                                   1.035179
# 9                                                   1.294818
# 10                                                  0.969390
# 11                                                  1.141396
# 12                                                  1.238752
# 13                                                  1.134378
# 14                                                  1.207172
# 15                                                  1.143213
# 16                                                  1.099678
# 17                                                  1.261379
# 18                                                  1.215447
# 19                                                  1.200834
# 20                                                  1.074525
# 21                                                  0.958266
# 22                                                  1.192225
# 23                                                  1.056347
# 24                                                  1.000487
# 25                                                  1.050900
# 26                                                  1.059180
# 27                                                  1.031590
# 28                                                  1.187753
# 29                                                  0.950647
# 30                                                  0.969035
# 31                                                  0.876089
# 32                                                  0.944202
# 33                                                  1.147307
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về chính sách hiện hành (%)  \
# 0                                                                  0.810938
# 1                                                                  0.546855
# 2                                                                  0.560756
# 3                                                                  0.581350
# 4                                                                  0.445589
# 5                                                                  0.583741
# 6                                                                  0.612420
# 7                                                                  0.826309
# 8                                                                  0.542324
# 9                                                                  0.644873
# 10                                                                 0.647116
# 11                                                                 0.616262
# 12                                                                 0.582347
# 13                                                                 0.612288
# 14                                                                 0.601887
# 15                                                                 0.620179
# 16                                                                 0.580817
# 17                                                                 0.700623
# 18                                                                 0.720294
# 19                                                                 0.674878
# 20                                                                 0.600858
# 21                                                                 0.597786
# 22                                                                 0.669127
# 23                                                                 0.643389
# 24                                                                 0.583039
# 25                                                                 0.608786
# 26                                                                 0.693287
# 27                                                                 0.583808
# 28                                                                 0.736355
# 29                                                                 0.545741
# 30                                                                 0.609985
# 31                                                                 0.513142
# 32                                                                 0.604132
# 33                                                                 0.730263
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về vị trí lãnh đạo (%)  \
# 0                                                             0.639612
# 1                                                             0.443646
# 2                                                             0.380430
# 3                                                             0.335289
# 4                                                             0.391274
# 5                                                             0.404762
# 6                                                             0.484140
# 7                                                             0.571429
# 8                                                             0.426775
# 9                                                             0.606291
# 10                                                            0.315900
# 11                                                            0.484221
# 12                                                            0.587717
# 13                                                            0.479970
# 14                                                            0.549876
# 15                                                            0.483878
# 16                                                            0.464861
# 17                                                            0.548692
# 18                                                            0.498028
# 19                                                            0.507747
# 20                                                            0.432483
# 21                                                            0.330677
# 22                                                            0.502970
# 23                                                            0.395059
# 24                                                            0.375580
# 25                                                            0.407519
# 26                                                            0.372627
# 27                                                            0.402843
# 28                                                            0.465380
# 29                                                            0.349926
# 30                                                            0.334149
# 31                                                            0.299953
# 32                                                            0.315002
# 33                                                            0.432474
#
# Tỉnh/Thành phố trực thuộc trung ương  1.2: Cơ hội tham gia  ...  \
# 0                                                 1.531022  ...
# 1                                                 1.380181  ...
# 2                                                 1.476668  ...
# 3                                                 1.407232  ...
# 4                                                 1.381613  ...
# 5                                                 1.492470  ...
# 6                                                 1.466421  ...
# 7                                                 1.662174  ...
# 8                                                 1.776866  ...
# 9                                                 1.883087  ...
# 10                                                1.641892  ...
# 11                                                1.800641  ...
# 12                                                1.564284  ...
# 13                                                1.578477  ...
# 14                                                1.582230  ...
# 15                                                1.674948  ...
# 16                                                1.528961  ...
# 17                                                1.521316  ...
# 18                                                1.535966  ...
# 19                                                1.632521  ...
# 20                                                1.323720  ...
# 21                                                1.280490  ...
# 22                                                1.340489  ...
# 23                                                1.266673  ...
# 24                                                1.268819  ...
# 25                                                1.387703  ...
# 26                                                1.259961  ...
# 27                                                1.205145  ...
# 28                                                1.171438  ...
# 29                                                1.102683  ...
# 30                                                1.034663  ...
# 31                                                1.061606  ...
# 32                                                1.021905  ...
# 33                                                1.182422  ...
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm thủ tục cấp giấy chứng nhận quyền sử dụng đất (%)  \
# 0                                                                              0.024610
# 1                                                                              0.032581
# 2                                                                              0.030124
# 3                                                                              0.019233
# 4                                                                              0.027679
# 5                                                                              0.034783
# 6                                                                              0.016291
# 7                                                                              0.027246
# 8                                                                              0.022242
# 9                                                                              0.035881
# 10                                                                             0.026238
# 11                                                                             0.010126
# 12                                                                             0.013761
# 13                                                                             0.026513
# 14                                                                             0.025770
# 15                                                                             0.020536
# 16                                                                             0.011146
# 17                                                                             0.028349
# 18                                                                             0.028430
# 19                                                                             0.029084
# 20                                                                             0.007814
# 21                                                                             0.029836
# 22                                                                             0.035991
# 23                                                                             0.015941
# 24                                                                             0.033316
# 25                                                                             0.027754
# 26                                                                             0.016794
# 27                                                                             0.024571
# 28                                                                             0.024963
# 29                                                                             0.011214
# 30                                                                             0.006824
# 31                                                                             0.014784
# 32                                                                             0.012222
# 33                                                                             0.011214
#
# Tỉnh/Thành phố trực thuộc trung ương  8.2: Tiếp cận và sử dụng Internet tại địa phương  \
# 0                                                                             2.960508
# 1                                                                             2.071751
# 2                                                                             2.371423
# 3                                                                             2.369423
# 4                                                                             2.040645
# 5                                                                             2.418868
# 6                                                                             2.495427
# 7                                                                             2.895742
# 8                                                                             2.391233
# 9                                                                             2.951612
# 10                                                                            2.554278
# 11                                                                            2.812408
# 12                                                                            2.668212
# 13                                                                            2.511301
# 14                                                                            2.507841
# 15                                                                            2.481075
# 16                                                                            2.214779
# 17                                                                            2.415848
# 18                                                                            2.584105
# 19                                                                            2.429445
# 20                                                                            2.407643
# 21                                                                            2.064675
# 22                                                                            2.563160
# 23                                                                            2.239380
# 24                                                                            2.419593
# 25                                                                            2.442737
# 26                                                                            2.740215
# 27                                                                            2.652435
# 28                                                                            2.800175
# 29                                                                            2.187359
# 30                                                                            2.208411
# 31                                                                            2.126201
# 32                                                                            2.384912
# 33                                                                            2.481818
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời tiếp cận tin tức trong nước qua Internet (%)  \
# 0                                                                              0.809756
# 1                                                                              0.592026
# 2                                                                              0.667127
# 3                                                                              0.641752
# 4                                                                              0.620148
# 5                                                                              0.688113
# 6                                                                              0.748441
# 7                                                                              0.817108
# 8                                                                              0.605263
# 9                                                                              0.818354
# 10                                                                             0.681096
# 11                                                                             0.760876
# 12                                                                             0.683314
# 13                                                                             0.584621
# 14                                                                             0.610790
# 15                                                                             0.621056
# 16                                                                             0.598612
# 17                                                                             0.663427
# 18                                                                             0.723515
# 19                                                                             0.591567
# 20                                                                             0.622370
# 21                                                                             0.506959
# 22                                                                             0.631530
# 23                                                                             0.564317
# 24                                                                             0.600636
# 25                                                                             0.653391
# 26                                                                             0.740092
# 27                                                                             0.716352
# 28                                                                             0.736181
# 29                                                                             0.502984
# 30                                                                             0.516773
# 31                                                                             0.449130
# 32                                                                             0.599294
# 33                                                                             0.609702
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có kết nối Internet tại nhà (%)  \
# 0                                                                              0.961630
# 1                                                                              0.580871
# 2                                                                              0.707569
# 3                                                                              0.731597
# 4                                                                              0.531802
# 5                                                                              0.718532
# 6                                                                              0.709759
# 7                                                                              0.910664
# 8                                                                              0.782773
# 9                                                                              0.947042
# 10                                                                             0.816734
# 11                                                                             0.910779
# 12                                                                             0.891239
# 13                                                                             0.884269
# 14                                                                             0.855770
# 15                                                                             0.827479
# 16                                                                             0.670599
# 17                                                                             0.741184
# 18                                                                             0.794401
# 19                                                                             0.822200
# 20                                                                             0.776715
# 21                                                                             0.661173
# 22                                                                             0.872282
# 23                                                                             0.721461
# 24                                                                             0.806498
# 25                                                                             0.769327
# 26                                                                             0.882948
# 27                                                                             0.847578
# 28                                                                             0.927236
# 29                                                                             0.747763
# 30                                                                             0.748151
# 31                                                                             0.760433
# 32                                                                             0.784485
# 33                                                                             0.839334
#
# ...
# 0                                                                              0.708495
# 1                                                                              0.553371
# 2                                                                              0.635558
# 3                                                                              0.617914
# 4                                                                              0.426394
# 5                                                                              0.605962
# 6                                                                              0.715403
# 7                                                                              0.718433
# 8                                                                              0.649323
# 9                                                                              0.716405
# 10                                                                             0.657998
# 11                                                                             0.633897
# 12                                                                             0.614363
# 13                                                                             0.643953
# 14                                                                             0.666263
# 15                                                                             0.642437
# 16                                                                             0.695178
# 17                                                                             0.658380
# 18                                                                             0.568511
# 19                                                                             0.732672
# 20                                                                             0.509615
# 21                                                                             0.481912
# 22                                                                             0.636120
# 23                                                                             0.535928
# 24                                                                             0.575117
# 25                                                                             0.525561
# 26                                                                             0.466039
# 27                                                                             0.488611
# 28                                                                             0.467078
# 29                                                                             0.416730
# 30                                                                             0.558704
# 31                                                                             0.455431
# 32                                                                             0.507878
# 33                                                                             0.509261
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)  \
# 0                                                                              0.141238
# 1                                                                              0.055113
# 2                                                                              0.111842
# 3                                                                              0.097909
# 4                                                                              0.105953
# 5                                                                              0.148090
# 6                                                                              0.065027
# 7                                                                              0.156004
# 8                                                                              0.076172
# 9                                                                              0.157760
# 10                                                                             0.087460
# 11                                                                             0.073548
# 12                                                                             0.094523
# 13                                                                             0.060940
# 14                                                                             0.046175
# 15                                                                             0.038191
# 16                                                                             0.040394
# 17                                                                             0.087851
# 18                                                                             0.067045
# 19                                                                             0.121161
# 20                                                                             0.066263
# 21                                                                             0.078851
# 22                                                                             0.085960
# 23                                                                             0.063890
# 24                                                                             0.079242
# 25                                                                             0.105896
# 26                                                                             0.152288
# 27                                                                             0.081313
# 28                                                                             0.117665
# 29                                                                             0.047179
# 30                                                                             0.094828
# 31                                                                             0.029056
# 32                                                                             0.086086
# 33                                                                             0.117165
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)
# 0                                                                              0.471960
# 1                                                                              0.500000
# 2                                                                              0.312237
# 3                                                                              0.556383
# 4                                                                              0.236565
# 5                                                                              0.336390
# 6                                                                              0.547157
# 7                                                                              0.610030
# 8                                                                              0.521093
# 9                                                                              0.489023
# 10                                                                             0.639867
# 11                                                                             0.452425
# 12                                                                             0.675447
# 13                                                                             0.626322
# 14                                                                             0.701010
# 15                                                                             0.512061
# 16                                                                             0.579619
# 17                                                                             0.911437
# 18                                                                             0.534350
# 19                                                                             0.443239
# 20                                                                             0.791940
# 21                                                                             0.614700
# 22                                                                             0.492479
# 23                                                                             0.816413
# 24                                                                             0.450618
# 25                                                                             0.454270
# 26                                                                             0.381205
# 27                                                                             0.225668
# 28                                                                             0.500791
# 29                                                                             0.573702
# 30                                                                             0.586522
# 31                                                                             0.763015
# 32                                                                             0.415016
# 33                                                                             0.576555
#
# [34 rows x 159 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Columns: 159 entries, Tỉnh/Thành phố to Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)
# dtypes: float64(158), object(1)
# memory usage: 42.4+ KB

# %%
df.describe()
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số)  \
# count                                                                34.000000
# mean                                                                 43.566914
# std                                                                   1.490116
# min                                                                  41.332478
# 25%                                                                  42.278580
# 50%                                                                  43.688752
# 75%                                                                  44.396186
# max                                                                  47.821236
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%  \
# count                                                                         34.000000
# mean                                                                          42.263410
# std                                                                            1.636824
# min                                                                           39.282421
# 25%                                                                           41.010099
# 50%                                                                           42.243342
# 75%                                                                           43.310736
# max                                                                           46.906075
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%  \
# count                                                                         34.000000
# mean                                                                          44.870419
# std                                                                            1.660367
# min                                                                           41.951246
# 25%                                                                           43.523663
# 50%                                                                           44.806047
# 75%                                                                           45.871656
# max                                                                           48.736397
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - sai số  \
# count                                                                         34.000000
# mean                                                                           0.665018
# std                                                                            0.359868
# min                                                                            0.174267
# 25%                                                                            0.359575
# 50%                                                                            0.615424
# 75%                                                                            0.877822
# max                                                                            1.420002
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở  \
# count                                                                         34.000000
# mean                                                                           5.050767
# std                                                                            0.488761
# min                                                                            4.197340
# 25%                                                                            4.630028
# 50%                                                                            5.119372
# 75%                                                                            5.391497
# max                                                                            5.873931
#
# Tỉnh/Thành phố trực thuộc trung ương  1.1: Tri thức công dân  \
# count                                              34.000000
# mean                                                1.098281
# std                                                 0.129802
# min                                                 0.876089
# 25%                                                 0.995178
# 50%                                                 1.066852
# 75%                                                 1.191107
# max                                                 1.425716
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về chính sách hiện hành (%)  \
# count                                                             34.000000
# mean                                                               0.624457
# std                                                                0.078966
# min                                                                0.445589
# 25%                                                                0.582520
# 50%                                                                0.609385
# 75%                                                                0.663624
# max                                                                0.826309
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về vị trí lãnh đạo (%)  \
# count                                                        34.000000
# mean                                                          0.441799
# std                                                           0.089521
# min                                                           0.299953
# 25%                                                           0.376793
# 50%                                                           0.432478
# 75%                                                           0.494576
# max                                                           0.639612
#
# Tỉnh/Thành phố trực thuộc trung ương  1.2: Cơ hội tham gia  \
# count                                            34.000000
# mean                                              1.424314
# std                                               0.223381
# min                                               1.021905
# 25%                                               1.267210
# 50%                                               1.436826
# 75%                                               1.574929
# max                                               1.883087
#
# Tỉnh/Thành phố trực thuộc trung ương  Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%)  \
# count                                                                         34.000000
# mean                                                                           0.496678
# std                                                                            0.149125
# min                                                                            0.208001
# 25%                                                                            0.364792
# 50%                                                                            0.541088
# 75%                                                                            0.625045
# max                                                                            0.712301
#
# Tỉnh/Thành phố trực thuộc trung ương  ...  \
# count                                 ...
# mean                                  ...
# std                                   ...
# min                                   ...
# 25%                                   ...
# 50%                                   ...
# 75%                                   ...
# max                                   ...
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm thủ tục cấp giấy chứng nhận quyền sử dụng đất (%)  \
# count                                                                         34.000000
# mean                                                                           0.022466
# std                                                                            0.008627
# min                                                                            0.006824
# 25%                                                                            0.015074
# 50%                                                                            0.024786
# 75%                                                                            0.028410
# max                                                                            0.035991
#
# Tỉnh/Thành phố trực thuộc trung ương  8.2: Tiếp cận và sử dụng Internet tại địa phương  \
# count                                                                        34.000000
# mean                                                                          2.466607
# std                                                                           0.246049
# min                                                                           2.040645
# 25%                                                                           2.369923
# 50%                                                                           2.436091
# 75%                                                                           2.578868
# max                                                                           2.960508
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời tiếp cận tin tức trong nước qua Internet (%)  \
# count                                                                         34.000000
# mean                                                                           0.646373
# std                                                                            0.089944
# min                                                                            0.449130
# 25%                                                                            0.598783
# 50%                                                                            0.626950
# 75%                                                                            0.709292
# max                                                                            0.818354
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có kết nối Internet tại nhà (%)  \
# count                                                                         34.000000
# mean                                                                           0.792420
# std                                                                            0.099263
# min                                                                            0.531802
# 25%                                                                            0.733994
# 50%                                                                            0.789443
# 75%                                                                            0.868154
# max                                                                            0.961630
#
# Tỉnh/Thành phố trực thuộc trung ương  8.3: Phúc đáp của chính quyền qua cổng thông tin điện tử  \
# count                                                                         34.000000
# mean                                                                           0.426794
# std                                                                            0.033543
# min                                                                            0.364538
# 25%                                                                            0.410063
# 50%                                                                            0.423430
# 75%                                                                            0.443552
# max                                                                            0.508954
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến ở địa phương khi làm thủ tục hành chính do cấp xã/phường thực hiện (%)  \
# count                                                                         34.000000
# mean                                                                           0.030870
# std                                                                            0.011159
# min                                                                            0.010159
# 25%                                                                            0.025304
# 50%                                                                            0.029750
# 75%                                                                            0.036444
# max                                                                            0.058202
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết cổng thông tin điện tử của tỉnh, thành phố dễ sử dụng cho tra cứu thông tin (%)  \
# count                                                                         34.000000
# mean                                                                           0.280556
# std                                                                            0.050233
# min                                                                            0.186271
# 25%                                                                            0.248037
# 50%                                                                            0.277025
# 75%                                                                            0.311207
# max                                                                            0.446668
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết chính quyền địa phương có đăng tải dự thảo chính sách, pháp luật lên cổng thông tin điện tử để lấy ý kiến nhân dân (%)  \
# count                                                                         34.000000
# mean                                                                           0.588085
# std                                                                            0.092561
# min                                                                            0.416730
# 25%                                                                            0.509349
# 50%                                                                            0.610163
# 75%                                                                            0.655829
# max                                                                            0.732672
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)  \
# count                                                                         34.000000
# mean                                                                           0.089355
# std                                                                            0.034932
# min                                                                            0.029056
# 25%                                                                            0.065336
# 50%                                                                            0.086023
# 75%                                                                            0.110369
# max                                                                            0.157760
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)
# count                                                                         34.000000
# mean                                                                           0.538221
# std                                                                            0.153484
# min                                                                            0.225668
# 25%                                                                            0.452886
# 50%                                                                            0.527722
# 75%                                                                            0.613533
# max                                                                            0.911437
#
# [8 rows x 158 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %% [markdown]
# ## Chỉ số PAPI tổng hợp (không có trọng số)

# %%
column_name = 'Chỉ số PAPI tổng hợp (không có trọng số)'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Chỉ số PAPI theo Tỉnh/Thành phố', fontsize=14)
plt.xlabel('Chỉ số PAPI tổng hợp (không có trọng số)', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 43.57
# Median: 43.69
# Standard Deviation: 1.49
# Minimum Value: 41.33
# Maximum Value: 47.82

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of {column_name}', fontsize=14)
plt.xlabel(column_name, fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số PAPI tổng hợp (không có trọng số)
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of {column_name}')
plt.xlabel(column_name)
# Out:
# Text(0.5, 0, 'Chỉ số PAPI tổng hợp (không có trọng số)')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Tỉnh/Thành phố trực thuộc trung ương Tỉnh/Thành phố  \
# 9                                        Quảng Ninh
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số)
# 9                                                                    47.821236

# %% [markdown]
# ## Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở

# %%
column_name = 'Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Tham gia của người dân ở cấp cơ sở', fontsize=14)
plt.xlabel('Tham gia của người dân ở cấp cơ sở', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 5.05
# Median: 5.12
# Standard Deviation: 0.49
# Minimum Value: 4.20
# Maximum Value: 5.87

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Tham gia của người dân ở cấp cơ sở', fontsize=14)
plt.xlabel('Tham gia của người dân ở cấp cơ sở', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số tham gia của người dân ở cấp cơ sở
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Tham gia của người dân ở cấp cơ sở')
plt.xlabel('Tham gia của người dân ở cấp cơ sở')
# Out:
# Text(0.5, 0, 'Tham gia của người dân ở cấp cơ sở')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở]
# Index: []

# %%
column_name = '1.1: Tri thức công dân'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Tri thức công dân', fontsize=14)
plt.xlabel('Tri thức công dân', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 1.10
# Median: 1.07
# Standard Deviation: 0.13
# Minimum Value: 0.88
# Maximum Value: 1.43

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Tri thức công dân', fontsize=14)
plt.xlabel('Tri thức công dân', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số tri thức công dân
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Tri thức công dân')
plt.xlabel('Tri thức công dân')
# Out:
# Text(0.5, 0, 'Tri thức công dân')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, 1.1: Tri thức công dân]
# Index: []

# %% [markdown]
# ## Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách

# %%
column_name = 'Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Công khai, minh bạch trong hoạch định chính sách', fontsize=14)
plt.xlabel('Công khai, minh bạch trong hoạch định chính sách', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 5.35
# Median: 5.37
# Standard Deviation: 0.30
# Minimum Value: 4.80
# Maximum Value: 5.96

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Công khai, minh bạch trong hoạch định chính sách', fontsize=14)
plt.xlabel('Công khai, minh bạch trong hoạch định chính sách', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số công khai, minh bạch trong hoạch định chính sách
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Công khai, minh bạch trong hoạch định chính sách')
plt.xlabel('Công khai, minh bạch trong hoạch định chính sách')
# Out:
# Text(0.5, 0, 'Công khai, minh bạch trong hoạch định chính sách')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách]
# Index: []

# %% [markdown]
# ## Chỉ số nội dung 3: Trách nhiệm giải trình với người dân

# %%
column_name = 'Chỉ số nội dung 3: Trách nhiệm giải trình với người dân'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Trách nhiệm giải trình với người dân', fontsize=14)
plt.xlabel('Trách nhiệm giải trình với người dân', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 4.31
# Median: 4.30
# Standard Deviation: 0.13
# Minimum Value: 3.95
# Maximum Value: 4.56

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Trách nhiệm giải trình với người dân', fontsize=14)
plt.xlabel('Trách nhiệm giải trình với người dân', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số trách nhiệm giải trình với người dân
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Trách nhiệm giải trình với người dân')
plt.xlabel('Trách nhiệm giải trình với người dân')
# Out:
# Text(0.5, 0, 'Trách nhiệm giải trình với người dân')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Tỉnh/Thành phố trực thuộc trung ương Tỉnh/Thành phố  \
# 31                                         An Giang
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 3: Trách nhiệm giải trình với người dân
# 31                                                                             3.949541

# %% [markdown]
# ## Chỉ số nội dung 4: Kiểm soát tham nhũng trong khu vực công

# %%
column_name = 'Chỉ số nội dung 4: Kiểm soát tham nhũng trong khu vực công'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Kiểm soát tham nhũng trong khu vực công', fontsize=14)
plt.xlabel('Kiểm soát tham nhũng trong khu vực công', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 7.01
# Median: 7.01
# Standard Deviation: 0.34
# Minimum Value: 6.22
# Maximum Value: 7.99

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Kiểm soát tham nhũng trong khu vực công', fontsize=14)
plt.xlabel('Kiểm soát tham nhũng trong khu vực công', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số kiểm soát tham nhũng trong khu vực công
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Kiểm soát tham nhũng trong khu vực công')
plt.xlabel('Kiểm soát tham nhũng trong khu vực công')
# Out:
# Text(0.5, 0, 'Kiểm soát tham nhũng trong khu vực công')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Tỉnh/Thành phố trực thuộc trung ương Tỉnh/Thành phố  \
# 9                                        Quảng Ninh
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 4: Kiểm soát tham nhũng trong khu vực công
# 9                                                                              7.989056

# %% [markdown]
# ## Chỉ số nội dung 5: Thủ tục hành chính công

# %%
column_name = 'Chỉ số nội dung 5: Thủ tục hành chính công'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Thủ tục hành chính công', fontsize=14)
plt.xlabel('Thủ tục hành chính công', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 7.20
# Median: 7.19
# Standard Deviation: 0.16
# Minimum Value: 6.81
# Maximum Value: 7.56

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Thủ tục hành chính công', fontsize=14)
plt.xlabel('Thủ tục hành chính công', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số thủ tục hành chính công
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Thủ tục hành chính công')
plt.xlabel('Thủ tục hành chính công')
# Out:
# Text(0.5, 0, 'Thủ tục hành chính công')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Tỉnh/Thành phố trực thuộc trung ương Tỉnh/Thành phố  \
# 1                                          Cao Bằng
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 5: Thủ tục hành chính công
# 1                                                                        6.81419

# %% [markdown]
# ## Chỉ số nội dung 6: Cung ứng dịch vụ công

# %%
column_name = 'Chỉ số nội dung 6: Cung ứng dịch vụ công'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Cung ứng dịch vụ công', fontsize=14)
plt.xlabel('Cung ứng dịch vụ công', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 7.60
# Median: 7.58
# Standard Deviation: 0.33
# Minimum Value: 6.74
# Maximum Value: 8.42

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Cung ứng dịch vụ công', fontsize=14)
plt.xlabel('Cung ứng dịch vụ công', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số cung ứng dịch vụ công
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Cung ứng dịch vụ công')
plt.xlabel('Cung ứng dịch vụ công')
# Out:
# Text(0.5, 0, 'Cung ứng dịch vụ công')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Tỉnh/Thành phố trực thuộc trung ương Tỉnh/Thành phố  \
# 4                                         Điện Biên
# 9                                        Quảng Ninh
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 6: Cung ứng dịch vụ công
# 4                                                                     6.742524
# 9                                                                     8.419840

# %% [markdown]
# ## Chỉ số nội dung 7: Quản trị môi trường

# %%
column_name = 'Chỉ số nội dung 7: Quản trị môi trường'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Quản trị môi trường', fontsize=14)
plt.xlabel('Quản trị môi trường', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 3.65
# Median: 3.66
# Standard Deviation: 0.29
# Minimum Value: 2.87
# Maximum Value: 4.41

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Quản trị môi trường', fontsize=14)
plt.xlabel('Quản trị môi trường', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số quản trị môi trường
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Quản trị môi trường')
plt.xlabel('Quản trị môi trường')
# Out:
# Text(0.5, 0, 'Quản trị môi trường')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Tỉnh/Thành phố trực thuộc trung ương Tỉnh/Thành phố  \
# 0                                            Hà Nội
# 30                                        Đồng Tháp
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 7: Quản trị môi trường
# 0                                                                   2.872574
# 30                                                                  4.412209

# %% [markdown]
# ## Chỉ số nội dung 8: Quản trị điện tử

# %%
column_name = 'Chỉ số nội dung 8: Quản trị điện tử'

# Tùy chỉnh giao diện
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ

# Vẽ histogram
sns.barplot(data=df, y='Tỉnh/Thành phố', x=column_name, color='skyblue', orient='h')

# Thêm tiêu đề và nhãn
plt.title('Quản trị điện tử', fontsize=14)
plt.xlabel('Quản trị điện tử', fontsize=12)
plt.ylabel('Tỉnh/Thành phố', fontsize=12)

# Thêm lưới để dễ quan sát
plt.grid(True, axis='x', alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# Tính và hiển thị các thống kê cơ bản
mean_val = df[column_name].mean()
median_val = df[column_name].median()
std_val = df[column_name].std()
min_val = df[column_name].min()
max_val = df[column_name].max()

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")
print(f"Minimum Value: {min_val:.2f}")
print(f"Maximum Value: {max_val:.2f}")

# Hiển thị biểu đồ
plt.show()
# Out:
# Mean: 3.39
# Median: 3.39
# Standard Deviation: 0.28
# Minimum Value: 2.94
# Maximum Value: 4.05

# %%
# Vẽ histogram
sns.histplot(data=df, x=column_name, bins=10, kde=True, color='skyblue')

# Thêm tiêu đề và nhãn
plt.title(f'Histogram of Quản trị điện tử', fontsize=14)
plt.xlabel('Quản trị điện tử', fontsize=12)
plt.ylabel('Tần số', fontsize=12)

# Thêm lưới
plt.grid(True, alpha=0.3)

# Hiển thị biểu đồ
plt.show()

# %%
# Tìm giá trị ngoại lai theo chỉ số quản trị điện tử
# Tính Q1, Q3 và IQR
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng ngoại lai
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Tìm các giá trị ngoại lai
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

# Vẽ boxplot để trực quan hóa
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[column_name])
plt.title(f'Boxplot of Quản trị điện tử')
plt.xlabel('Quản trị điện tử')
# Out:
# Text(0.5, 0, 'Quản trị điện tử')

# %%
outlier_indices = df.index[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
column_index = df.columns.get_loc(column_name)
df.iloc[outlier_indices, [0, column_index]]
# Out:
# Tỉnh/Thành phố trực thuộc trung ương Tỉnh/Thành phố  \
# 0                                            Hà Nội
# 1                                          Cao Bằng
# 7                                       Thái Nguyên
# 9                                        Quảng Ninh
# 31                                         An Giang
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 8: Quản trị điện tử
# 0                                                                4.045536
# 1                                                                2.942627
# 7                                                                3.919680
# 9                                                                3.941986
# 31                                                               2.954330

# %% [markdown]
# ## Sự tương quan

# %%
# Chỉ định các cột muốn tính tương quan
selected_columns = ["Chỉ số PAPI tổng hợp (không có trọng số)", "Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở", "Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách",
                    "Chỉ số nội dung 3: Trách nhiệm giải trình với người dân","Chỉ số nội dung 4: Kiểm soát tham nhũng trong khu vực công","Chỉ số nội dung 5: Thủ tục hành chính công",
                    "Chỉ số nội dung 6: Cung ứng dịch vụ công","Chỉ số nội dung 7: Quản trị môi trường","Chỉ số nội dung 8: Quản trị điện tử"]
df_selected = df[selected_columns]
# Tính ma trận tương quan
corr_matrix = df_selected.corr(method="pearson")

print("Ma trận tương quan:")
print(corr_matrix)

# Vẽ heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, linewidths=0.5)
plt.title("Heatmap ma trận tương quan", fontsize=14)
plt.xlabel("Các chỉ số đánh giá PAPI")
plt.ylabel("Các chỉ số đánh giá PAPI")
plt.show()
# Out:
# Ma trận tương quan:
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số PAPI tổng hợp (không có trọng số)  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                            1.000000
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                                  0.770207
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                                  0.879812
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                  0.723558
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                  0.751630
# Chỉ số nội dung 5: Thủ tục hành chính công                                          0.582778
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                            0.569667
# Chỉ số nội dung 7: Quản trị môi trường                                              0.139429
# Chỉ số nội dung 8: Quản trị điện tử                                                 0.627562
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                                     0.770207
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                                           1.000000
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                                           0.818270
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                           0.647418
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                           0.249520
# Chỉ số nội dung 5: Thủ tục hành chính công                                                   0.241966
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                                     0.333779
# Chỉ số nội dung 7: Quản trị môi trường                                                      -0.189261
# Chỉ số nội dung 8: Quản trị điện tử                                                          0.533471
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                                     0.879812
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                                           0.818270
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                                           1.000000
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                           0.766906
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                           0.489865
# Chỉ số nội dung 5: Thủ tục hành chính công                                                   0.346220
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                                     0.405857
# Chỉ số nội dung 7: Quản trị môi trường                                                      -0.089374
# Chỉ số nội dung 8: Quản trị điện tử                                                          0.643345
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 3: Trách nhiệm giải trình với người dân  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                                     0.723558
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                                           0.647418
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                                           0.766906
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                           1.000000
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                           0.448035
# Chỉ số nội dung 5: Thủ tục hành chính công                                                   0.467892
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                                     0.141863
# Chỉ số nội dung 7: Quản trị môi trường                                                       0.005604
# Chỉ số nội dung 8: Quản trị điện tử                                                          0.437391
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 4: Kiểm soát tham nhũng trong khu vực công  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                                     0.751630
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                                           0.249520
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                                           0.489865
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                           0.448035
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                           1.000000
# Chỉ số nội dung 5: Thủ tục hành chính công                                                   0.664839
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                                     0.332618
# Chỉ số nội dung 7: Quản trị môi trường                                                       0.444130
# Chỉ số nội dung 8: Quản trị điện tử                                                          0.376076
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 5: Thủ tục hành chính công  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                              0.582778
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                                    0.241966
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                                    0.346220
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                    0.467892
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                    0.664839
# Chỉ số nội dung 5: Thủ tục hành chính công                                            1.000000
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                              0.106183
# Chỉ số nội dung 7: Quản trị môi trường                                                0.340684
# Chỉ số nội dung 8: Quản trị điện tử                                                   0.216235
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 6: Cung ứng dịch vụ công  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                            0.569667
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                                  0.333779
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                                  0.405857
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                  0.141863
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                  0.332618
# Chỉ số nội dung 5: Thủ tục hành chính công                                          0.106183
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                            1.000000
# Chỉ số nội dung 7: Quản trị môi trường                                             -0.087797
# Chỉ số nội dung 8: Quản trị điện tử                                                 0.394329
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 7: Quản trị môi trường  \
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                          0.139429
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                               -0.189261
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                               -0.089374
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                                0.005604
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                                0.444130
# Chỉ số nội dung 5: Thủ tục hành chính công                                        0.340684
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                         -0.087797
# Chỉ số nội dung 7: Quản trị môi trường                                            1.000000
# Chỉ số nội dung 8: Quản trị điện tử                                              -0.510336
#
# Tỉnh/Thành phố trực thuộc trung ương                Chỉ số nội dung 8: Quản trị điện tử
# Tỉnh/Thành phố trực thuộc trung ương
# Chỉ số PAPI tổng hợp (không có trọng số)                                       0.627562
# Chỉ số nội dung 1: Tham gia của người dân ở cấp...                             0.533471
# Chỉ số nội dung 2: Công khai, minh bạch trong h...                             0.643345
# Chỉ số nội dung 3: Trách nhiệm giải trình với n...                             0.437391
# Chỉ số nội dung 4: Kiểm soát tham nhũng trong k...                             0.376076
# Chỉ số nội dung 5: Thủ tục hành chính công                                     0.216235
# Chỉ số nội dung 6: Cung ứng dịch vụ công                                       0.394329
# Chỉ số nội dung 7: Quản trị môi trường                                        -0.510336
# Chỉ số nội dung 8: Quản trị điện tử                                            1.000000

# %%
df
# Out:
# Tỉnh/Thành phố trực thuộc trung ương   Tỉnh/Thành phố  \
# 0                                              Hà Nội
# 1                                            Cao Bằng
# 2                                         Tuyên Quang
# 3                                             Lào Cai
# 4                                           Điện Biên
# 5                                            Lai Châu
# 6                                              Sơn La
# 7                                         Thái Nguyên
# 8                                            Lạng Sơn
# 9                                          Quảng Ninh
# 10                                            Phú Thọ
# 11                                           Bắc Ninh
# 12                                          Hải Phòng
# 13                                           Hưng Yên
# 14                                          Ninh Bình
# 15                                          Thanh Hóa
# 16                                            Nghệ An
# 17                                            Hà Tĩnh
# 18                                          Quảng Trị
# 19                                     Thừa Thiên-Huế
# 20                                            Đà Nẵng
# 21                                         Quảng Ngãi
# 22                                          Khánh Hòa
# 23                                            Gia Lai
# 24                                            Đắk Lắk
# 25                                           Lâm Đồng
# 26                                           Tây Ninh
# 27                                           Đồng Nai
# 28                                    TP. Hồ Chí Minh
# 29                                          Vĩnh Long
# 30                                          Đồng Tháp
# 31                                           An Giang
# 32                                            Cần Thơ
# 33                                             Cà Mau
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số)  \
# 0                                                                    43.774715
# 1                                                                    41.332478
# 2                                                                    43.172611
# 3                                                                    41.849570
# 4                                                                    41.375828
# 5                                                                    43.479568
# 6                                                                    43.887550
# 7                                                                    45.951166
# 8                                                                    45.003624
# 9                                                                    47.821236
# 10                                                                   44.063235
# 11                                                                   45.028375
# 12                                                                   42.650545
# 13                                                                   44.602359
# 14                                                                   44.019932
# 15                                                                   44.870750
# 16                                                                   43.069889
# 17                                                                   45.553085
# 18                                                                   44.217131
# 19                                                                   45.095047
# 20                                                                   42.029420
# 21                                                                   42.197246
# 22                                                                   44.414544
# 23                                                                   42.341797
# 24                                                                   42.257508
# 25                                                                   43.254680
# 26                                                                   44.313948
# 27                                                                   41.776783
# 28                                                                   43.602789
# 29                                                                   41.647474
# 30                                                                   43.835712
# 31                                                                   41.442199
# 32                                                                   43.001186
# 33                                                                   44.341113
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%  \
# 0                                                                             43.220791
# 1                                                                             39.598320
# 2                                                                             40.406404
# 3                                                                             39.282421
# 4                                                                             40.439476
# 5                                                                             42.184723
# 6                                                                             42.421448
# 7                                                                             43.167816
# 8                                                                             43.075245
# 9                                                                             46.906075
# 10                                                                            43.585484
# 11                                                                            43.840976
# 12                                                                            40.559065
# 13                                                                            43.457243
# 14                                                                            43.340717
# 15                                                                            44.529171
# 16                                                                            42.400673
# 17                                                                            44.707905
# 18                                                                            43.596582
# 19                                                                            44.521580
# 20                                                                            41.054775
# 21                                                                            40.942642
# 22                                                                            42.916039
# 23                                                                            41.439915
# 24                                                                            41.795035
# 25                                                                            41.070513
# 26                                                                            41.749232
# 27                                                                            40.995208
# 28                                                                            42.301961
# 29                                                                            40.422285
# 30                                                                            42.028534
# 31                                                                            40.933153
# 32                                                                            41.403448
# 33                                                                            42.661096
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%  \
# 0                                                                             44.328640
# 1                                                                             43.066635
# 2                                                                             45.938817
# 3                                                                             44.416718
# 4                                                                             42.312180
# 5                                                                             44.774414
# 6                                                                             45.353653
# 7                                                                             48.734515
# 8                                                                             46.932003
# 9                                                                             48.736397
# 10                                                                            44.540986
# 11                                                                            46.215775
# 12                                                                            44.742025
# 13                                                                            45.747474
# 14                                                                            44.699147
# 15                                                                            45.212330
# 16                                                                            43.739105
# 17                                                                            46.398266
# 18                                                                            44.837680
# 19                                                                            45.668514
# 20                                                                            43.004065
# 21                                                                            43.451849
# 22                                                                            45.913050
# 23                                                                            43.243678
# 24                                                                            42.719981
# 25                                                                            45.438847
# 26                                                                            46.878664
# 27                                                                            42.558359
# 28                                                                            44.903617
# 29                                                                            42.872662
# 30                                                                            45.642891
# 31                                                                            41.951246
# 32                                                                            44.598925
# 33                                                                            46.021130
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - sai số  \
# 0                                                                              0.282599
# 1                                                                              0.884728
# 2                                                                              1.411256
# 3                                                                              1.309701
# 4                                                                              0.477706
# 5                                                                              0.660600
# 6                                                                              0.747973
# 7                                                                              1.420002
# 8                                                                              0.983815
# 9                                                                              0.466895
# 10                                                                             0.243737
# 11                                                                             0.605785
# 12                                                                             1.067026
# 13                                                                             0.584211
# 14                                                                             0.346520
# 15                                                                             0.174267
# 16                                                                             0.341418
# 17                                                                             0.431191
# 18                                                                             0.316590
# 19                                                                             0.292570
# 20                                                                             0.497242
# 21                                                                             0.640070
# 22                                                                             0.764503
# 23                                                                             0.460119
# 24                                                                             0.235944
# 25                                                                             1.114312
# 26                                                                             1.308460
# 27                                                                             0.398741
# 28                                                                             0.663653
# 29                                                                             0.625063
# 30                                                                             0.921980
# 31                                                                             0.259704
# 32                                                                             0.815130
# 33                                                                             0.857106
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở  \
# 0                                                                              5.392270
# 1                                                                              4.640318
# 2                                                                              5.185756
# 3                                                                              4.870843
# 4                                                                              4.631536
# 5                                                                              5.236279
# 6                                                                              5.204468
# 7                                                                              5.745524
# 8                                                                              5.525624
# 9                                                                              5.873931
# 10                                                                             5.233066
# 11                                                                             5.803446
# 12                                                                             5.295103
# 13                                                                             5.292784
# 14                                                                             5.586421
# 15                                                                             5.688568
# 16                                                                             5.318382
# 17                                                                             5.841213
# 18                                                                             5.479559
# 19                                                                             5.389178
# 20                                                                             4.558244
# 21                                                                             4.695246
# 22                                                                             4.571488
# 23                                                                             4.675178
# 24                                                                             4.619146
# 25                                                                             5.052988
# 26                                                                             4.970453
# 27                                                                             4.552126
# 28                                                                             4.801750
# 29                                                                             4.282942
# 30                                                                             4.590105
# 31                                                                             4.197340
# 32                                                                             4.295279
# 33                                                                             4.629526
#
# Tỉnh/Thành phố trực thuộc trung ương  1.1: Tri thức công dân  \
# 0                                                   1.425716
# 1                                                   1.056708
# 2                                                   0.993409
# 3                                                   0.954209
# 4                                                   0.940827
# 5                                                   1.033711
# 6                                                   1.139144
# 7                                                   1.357657
# 8                                                   1.035179
# 9                                                   1.294818
# 10                                                  0.969390
# 11                                                  1.141396
# 12                                                  1.238752
# 13                                                  1.134378
# 14                                                  1.207172
# 15                                                  1.143213
# 16                                                  1.099678
# 17                                                  1.261379
# 18                                                  1.215447
# 19                                                  1.200834
# 20                                                  1.074525
# 21                                                  0.958266
# 22                                                  1.192225
# 23                                                  1.056347
# 24                                                  1.000487
# 25                                                  1.050900
# 26                                                  1.059180
# 27                                                  1.031590
# 28                                                  1.187753
# 29                                                  0.950647
# 30                                                  0.969035
# 31                                                  0.876089
# 32                                                  0.944202
# 33                                                  1.147307
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về chính sách hiện hành (%)  \
# 0                                                                  0.810938
# 1                                                                  0.546855
# 2                                                                  0.560756
# 3                                                                  0.581350
# 4                                                                  0.445589
# 5                                                                  0.583741
# 6                                                                  0.612420
# 7                                                                  0.826309
# 8                                                                  0.542324
# 9                                                                  0.644873
# 10                                                                 0.647116
# 11                                                                 0.616262
# 12                                                                 0.582347
# 13                                                                 0.612288
# 14                                                                 0.601887
# 15                                                                 0.620179
# 16                                                                 0.580817
# 17                                                                 0.700623
# 18                                                                 0.720294
# 19                                                                 0.674878
# 20                                                                 0.600858
# 21                                                                 0.597786
# 22                                                                 0.669127
# 23                                                                 0.643389
# 24                                                                 0.583039
# 25                                                                 0.608786
# 26                                                                 0.693287
# 27                                                                 0.583808
# 28                                                                 0.736355
# 29                                                                 0.545741
# 30                                                                 0.609985
# 31                                                                 0.513142
# 32                                                                 0.604132
# 33                                                                 0.730263
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về vị trí lãnh đạo (%)  \
# 0                                                             0.639612
# 1                                                             0.443646
# 2                                                             0.380430
# 3                                                             0.335289
# 4                                                             0.391274
# 5                                                             0.404762
# 6                                                             0.484140
# 7                                                             0.571429
# 8                                                             0.426775
# 9                                                             0.606291
# 10                                                            0.315900
# 11                                                            0.484221
# 12                                                            0.587717
# 13                                                            0.479970
# 14                                                            0.549876
# 15                                                            0.483878
# 16                                                            0.464861
# 17                                                            0.548692
# 18                                                            0.498028
# 19                                                            0.507747
# 20                                                            0.432483
# 21                                                            0.330677
# 22                                                            0.502970
# 23                                                            0.395059
# 24                                                            0.375580
# 25                                                            0.407519
# 26                                                            0.372627
# 27                                                            0.402843
# 28                                                            0.465380
# 29                                                            0.349926
# 30                                                            0.334149
# 31                                                            0.299953
# 32                                                            0.315002
# 33                                                            0.432474
#
# Tỉnh/Thành phố trực thuộc trung ương  1.2: Cơ hội tham gia  ...  \
# 0                                                 1.531022  ...
# 1                                                 1.380181  ...
# 2                                                 1.476668  ...
# 3                                                 1.407232  ...
# 4                                                 1.381613  ...
# 5                                                 1.492470  ...
# 6                                                 1.466421  ...
# 7                                                 1.662174  ...
# 8                                                 1.776866  ...
# 9                                                 1.883087  ...
# 10                                                1.641892  ...
# 11                                                1.800641  ...
# 12                                                1.564284  ...
# 13                                                1.578477  ...
# 14                                                1.582230  ...
# 15                                                1.674948  ...
# 16                                                1.528961  ...
# 17                                                1.521316  ...
# 18                                                1.535966  ...
# 19                                                1.632521  ...
# 20                                                1.323720  ...
# 21                                                1.280490  ...
# 22                                                1.340489  ...
# 23                                                1.266673  ...
# 24                                                1.268819  ...
# 25                                                1.387703  ...
# 26                                                1.259961  ...
# 27                                                1.205145  ...
# 28                                                1.171438  ...
# 29                                                1.102683  ...
# 30                                                1.034663  ...
# 31                                                1.061606  ...
# 32                                                1.021905  ...
# 33                                                1.182422  ...
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm thủ tục cấp giấy chứng nhận quyền sử dụng đất (%)  \
# 0                                                                              0.024610
# 1                                                                              0.032581
# 2                                                                              0.030124
# 3                                                                              0.019233
# 4                                                                              0.027679
# 5                                                                              0.034783
# 6                                                                              0.016291
# 7                                                                              0.027246
# 8                                                                              0.022242
# 9                                                                              0.035881
# 10                                                                             0.026238
# 11                                                                             0.010126
# 12                                                                             0.013761
# 13                                                                             0.026513
# 14                                                                             0.025770
# 15                                                                             0.020536
# 16                                                                             0.011146
# 17                                                                             0.028349
# 18                                                                             0.028430
# 19                                                                             0.029084
# 20                                                                             0.007814
# 21                                                                             0.029836
# 22                                                                             0.035991
# 23                                                                             0.015941
# 24                                                                             0.033316
# 25                                                                             0.027754
# 26                                                                             0.016794
# 27                                                                             0.024571
# 28                                                                             0.024963
# 29                                                                             0.011214
# 30                                                                             0.006824
# 31                                                                             0.014784
# 32                                                                             0.012222
# 33                                                                             0.011214
#
# Tỉnh/Thành phố trực thuộc trung ương  8.2: Tiếp cận và sử dụng Internet tại địa phương  \
# 0                                                                             2.960508
# 1                                                                             2.071751
# 2                                                                             2.371423
# 3                                                                             2.369423
# 4                                                                             2.040645
# 5                                                                             2.418868
# 6                                                                             2.495427
# 7                                                                             2.895742
# 8                                                                             2.391233
# 9                                                                             2.951612
# 10                                                                            2.554278
# 11                                                                            2.812408
# 12                                                                            2.668212
# 13                                                                            2.511301
# 14                                                                            2.507841
# 15                                                                            2.481075
# 16                                                                            2.214779
# 17                                                                            2.415848
# 18                                                                            2.584105
# 19                                                                            2.429445
# 20                                                                            2.407643
# 21                                                                            2.064675
# 22                                                                            2.563160
# 23                                                                            2.239380
# 24                                                                            2.419593
# 25                                                                            2.442737
# 26                                                                            2.740215
# 27                                                                            2.652435
# 28                                                                            2.800175
# 29                                                                            2.187359
# 30                                                                            2.208411
# 31                                                                            2.126201
# 32                                                                            2.384912
# 33                                                                            2.481818
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời tiếp cận tin tức trong nước qua Internet (%)  \
# 0                                                                              0.809756
# 1                                                                              0.592026
# 2                                                                              0.667127
# 3                                                                              0.641752
# 4                                                                              0.620148
# 5                                                                              0.688113
# 6                                                                              0.748441
# 7                                                                              0.817108
# 8                                                                              0.605263
# 9                                                                              0.818354
# 10                                                                             0.681096
# 11                                                                             0.760876
# 12                                                                             0.683314
# 13                                                                             0.584621
# 14                                                                             0.610790
# 15                                                                             0.621056
# 16                                                                             0.598612
# 17                                                                             0.663427
# 18                                                                             0.723515
# 19                                                                             0.591567
# 20                                                                             0.622370
# 21                                                                             0.506959
# 22                                                                             0.631530
# 23                                                                             0.564317
# 24                                                                             0.600636
# 25                                                                             0.653391
# 26                                                                             0.740092
# 27                                                                             0.716352
# 28                                                                             0.736181
# 29                                                                             0.502984
# 30                                                                             0.516773
# 31                                                                             0.449130
# 32                                                                             0.599294
# 33                                                                             0.609702
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có kết nối Internet tại nhà (%)  \
# 0                                                                              0.961630
# 1                                                                              0.580871
# 2                                                                              0.707569
# 3                                                                              0.731597
# 4                                                                              0.531802
# 5                                                                              0.718532
# 6                                                                              0.709759
# 7                                                                              0.910664
# 8                                                                              0.782773
# 9                                                                              0.947042
# 10                                                                             0.816734
# 11                                                                             0.910779
# 12                                                                             0.891239
# 13                                                                             0.884269
# 14                                                                             0.855770
# 15                                                                             0.827479
# 16                                                                             0.670599
# 17                                                                             0.741184
# 18                                                                             0.794401
# 19                                                                             0.822200
# 20                                                                             0.776715
# 21                                                                             0.661173
# 22                                                                             0.872282
# 23                                                                             0.721461
# 24                                                                             0.806498
# 25                                                                             0.769327
# 26                                                                             0.882948
# 27                                                                             0.847578
# 28                                                                             0.927236
# 29                                                                             0.747763
# 30                                                                             0.748151
# 31                                                                             0.760433
# 32                                                                             0.784485
# 33                                                                             0.839334
#
# ...
# 0                                                                              0.708495
# 1                                                                              0.553371
# 2                                                                              0.635558
# 3                                                                              0.617914
# 4                                                                              0.426394
# 5                                                                              0.605962
# 6                                                                              0.715403
# 7                                                                              0.718433
# 8                                                                              0.649323
# 9                                                                              0.716405
# 10                                                                             0.657998
# 11                                                                             0.633897
# 12                                                                             0.614363
# 13                                                                             0.643953
# 14                                                                             0.666263
# 15                                                                             0.642437
# 16                                                                             0.695178
# 17                                                                             0.658380
# 18                                                                             0.568511
# 19                                                                             0.732672
# 20                                                                             0.509615
# 21                                                                             0.481912
# 22                                                                             0.636120
# 23                                                                             0.535928
# 24                                                                             0.575117
# 25                                                                             0.525561
# 26                                                                             0.466039
# 27                                                                             0.488611
# 28                                                                             0.467078
# 29                                                                             0.416730
# 30                                                                             0.558704
# 31                                                                             0.455431
# 32                                                                             0.507878
# 33                                                                             0.509261
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)  \
# 0                                                                              0.141238
# 1                                                                              0.055113
# 2                                                                              0.111842
# 3                                                                              0.097909
# 4                                                                              0.105953
# 5                                                                              0.148090
# 6                                                                              0.065027
# 7                                                                              0.156004
# 8                                                                              0.076172
# 9                                                                              0.157760
# 10                                                                             0.087460
# 11                                                                             0.073548
# 12                                                                             0.094523
# 13                                                                             0.060940
# 14                                                                             0.046175
# 15                                                                             0.038191
# 16                                                                             0.040394
# 17                                                                             0.087851
# 18                                                                             0.067045
# 19                                                                             0.121161
# 20                                                                             0.066263
# 21                                                                             0.078851
# 22                                                                             0.085960
# 23                                                                             0.063890
# 24                                                                             0.079242
# 25                                                                             0.105896
# 26                                                                             0.152288
# 27                                                                             0.081313
# 28                                                                             0.117665
# 29                                                                             0.047179
# 30                                                                             0.094828
# 31                                                                             0.029056
# 32                                                                             0.086086
# 33                                                                             0.117165
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)
# 0                                                                              0.471960
# 1                                                                              0.500000
# 2                                                                              0.312237
# 3                                                                              0.556383
# 4                                                                              0.236565
# 5                                                                              0.336390
# 6                                                                              0.547157
# 7                                                                              0.610030
# 8                                                                              0.521093
# 9                                                                              0.489023
# 10                                                                             0.639867
# 11                                                                             0.452425
# 12                                                                             0.675447
# 13                                                                             0.626322
# 14                                                                             0.701010
# 15                                                                             0.512061
# 16                                                                             0.579619
# 17                                                                             0.911437
# 18                                                                             0.534350
# 19                                                                             0.443239
# 20                                                                             0.791940
# 21                                                                             0.614700
# 22                                                                             0.492479
# 23                                                                             0.816413
# 24                                                                             0.450618
# 25                                                                             0.454270
# 26                                                                             0.381205
# 27                                                                             0.225668
# 28                                                                             0.500791
# 29                                                                             0.573702
# 30                                                                             0.586522
# 31                                                                             0.763015
# 32                                                                             0.415016
# 33                                                                             0.576555
#
# [34 rows x 159 columns]

# %% [markdown]
# # PREPROCESSING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Columns: 159 entries, Tỉnh/Thành phố to Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)
# dtypes: float64(158), object(1)
# memory usage: 42.4+ KB

# %%
print(df.duplicated().any())
# Out:
# False

# %%
print(df.isna().any())
# Out:
# Tỉnh/Thành phố trực thuộc trung ương
# Tỉnh/Thành phố                                                                                                                                         False
# Chỉ số PAPI tổng hợp (không có trọng số)                                                                                                               False
# Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%                                                                     False
# Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%                                                                        False
# Chỉ số PAPI tổng hợp (không có trọng số) - sai số                                                                                                      False
#                                                                                                                                                        ...
# Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến ở địa phương khi làm thủ tục hành chính do cấp xã/phường thực hiện (%)            False
# Tỉ lệ người trả lời cho biết cổng thông tin điện tử của tỉnh, thành phố dễ sử dụng cho tra cứu thông tin (%)                                           False
# Tỉ lệ người trả lời cho biết chính quyền địa phương có đăng tải dự thảo chính sách, pháp luật lên cổng thông tin điện tử để lấy ý kiến nhân dân (%)    False
# Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)                                                                False
# Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)                                                 False
# Length: 159, dtype: bool

# %%
print(list(df.columns))
# Out:
# ['Tỉnh/Thành phố', 'Chỉ số PAPI tổng hợp (không có trọng số)', 'Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%', 'Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%', 'Chỉ số PAPI tổng hợp (không có trọng số) - sai số', 'Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở', '1.1: Tri thức công dân', 'Hiểu biết về chính sách hiện hành (%)', 'Hiểu biết về vị trí lãnh đạo (%)', '1.2: Cơ hội tham gia', 'Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%)', 'Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%)', 'Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%)', 'Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%)', 'Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%)', 'Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%)', '1.3: Chất lượng bầu cử', 'Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%)', 'Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%)', 'Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%)', 'Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%)', 'Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%)', 'Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%)', '1.4: Đóng góp tự nguyện', 'Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%)', 'Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%)', 'Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%)', 'Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%)', 'Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%)', 'Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách', '2.1: Tiếp cận thông tin', 'Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%)', 'Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%)', 'Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%)', 'Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%)', 'Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%)', 'Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%)', '2.2: Công khai danh sách hộ nghèo', 'Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%)', 'Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%)', 'Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%)', '2.3: Công khai thu, chi ngân sách cấp xã/phường', 'Thu chi ngân sách của xã/phường được công bố công khai (%)', 'Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%)', 'Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%)', '2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất', 'Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%)', 'Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%)', 'Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%)', 'Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đìn ...

# %%
print(df["Tỉnh/Thành phố"].duplicated().any())
# Out:
# False

# %%
# Check những cột PAPI tổng hợp
cols = [
    'Chỉ số PAPI tổng hợp (không có trọng số)',
    'Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%',
    'Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%',
    'Chỉ số PAPI tổng hợp (không có trọng số) - sai số'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số)  \
# min                                                                  41.332478
# max                                                                  47.821236
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%  \
# min                                                                           39.282421
# max                                                                           46.906075
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%  \
# min                                                                           41.951246
# max                                                                           48.736397
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - sai số
# min                                                                            0.174267
# max                                                                            1.420002

# %%
cols = [
    "1.1: Tri thức công dân",
    "1.2: Cơ hội tham gia",
    "1.3: Chất lượng bầu cử",
    "1.4: Đóng góp tự nguyện"
]

# Kiểm tra các giá trị ngoài khoảng [0.25, 2.5]
out_of_range = (df[cols] < 0.25) | (df[cols] > 2.5)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    "2.1: Tiếp cận thông tin",
    "2.2: Công khai danh sách hộ nghèo",
    "2.3: Công khai thu, chi ngân sách cấp xã/phường",
    "2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất"
]

# Kiểm tra các giá trị ngoài khoảng [0.25, 2.5]
out_of_range = (df[cols] < 0.25) | (df[cols] > 2.5)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    "3.1: Mức độ và hiệu quả trong tiếp xúc với chính quyền",
    "3.2: Giải đáp khiếu nại, tố cáo, khúc mắc của người dân",
    "3.3: Tiếp cận dịch vụ tư pháp"
]

# Kiểm tra các giá trị ngoài khoảng [0.33, 3.33]
out_of_range = (df[cols] < 0.33) | (df[cols] > 3.33)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    "4.1: Kiểm soát tham nhũng trong chính quyền địa phương",
    "4.2: Kiểm soát tham nhũng trong cung ứng dịch vụ công",
    "4.3: Công bằng trong tuyển dụng vào khu vực công",
    "4.4: Quyết tâm chống tham nhũng của chính quyền địa phương"
]

# Kiểm tra các giá trị ngoài khoảng [0.25, 2.5]
out_of_range = (df[cols] < 0.25) | (df[cols] > 2.5)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    "5.1: Dịch vụ chứng thực, xác nhận của chính quyền",
    "5.3: Thủ tục liên quan đến giấy chứng nhận quyền sử dụng đất",
    "5.4: Dịch vụ hành chính cấp xã/phường"
]

# Kiểm tra các giá trị ngoài khoảng [0.33, 3.33]
out_of_range = (df[cols] < 0.33) | (df[cols] > 3.33)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    "6.1: Y tế công lập",
    "6.2: Giáo dục tiểu học công lập",
    "6.3: Cơ sở hạ tầng căn bản",
    "6.4: An ninh, trật tự khu dân cư"
]

# Kiểm tra các giá trị ngoài khoảng [0.25, 2.5]
out_of_range = (df[cols] < 0.25) | (df[cols] > 2.5)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    "7.1: Nghiêm túc trong bảo vệ môi trường",
    "7.2: Chất lượng không khí",
    "7.3: Chất lượng nước"
]

# Kiểm tra các giá trị ngoài khoảng [0.33, 3.33]
out_of_range = (df[cols] < 0.33) | (df[cols] > 3.33)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    "8.1: Sử dụng cổng thông tin điện tử của chính quyền địa phương",
    "8.2: Tiếp cận và sử dụng Internet tại địa phương",
    "8.3: Phúc đáp của chính quyền qua cổng thông tin điện tử"
]

# Kiểm tra các giá trị ngoài khoảng [0.33, 3.33]
out_of_range = (df[cols] < 0.33) | (df[cols] > 3.33)

# In ra các dòng có giá trị ngoài khoảng
print(df[out_of_range.any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Tỉnh/Thành phố, Chỉ số PAPI tổng hợp (không có trọng số), Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%, Chỉ số PAPI tổng hợp (không có trọng số) - sai số, Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở, 1.1: Tri thức công dân, Hiểu biết về chính sách hiện hành (%), Hiểu biết về vị trí lãnh đạo (%), 1.2: Cơ hội tham gia, Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%), Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%), Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%), Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%), Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%), 1.3: Chất lượng bầu cử, Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%), Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%), Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%), Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%), Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%), 1.4: Đóng góp tự nguyện, Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%), Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%), Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%), Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%), Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%), Chỉ số nội dung 2: Công khai, minh bạch trong hoạch định chính sách, 2.1: Tiếp cận thông tin, Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%), Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%), Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%), Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%), 2.2: Công khai danh sách hộ nghèo, Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%), Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%), 2.3: Công khai thu, chi ngân sách cấp xã/phường, Thu chi ngân sách của xã/phường được công bố công khai (%), Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%), Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%), 2.4: Quy hoạch, kế hoạch sử dụng đất; giá bồi thường thu hồi đất, Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%), Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%), Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%), Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi), Tỷ lệ người trả lời cho biết hộ gia đình ...
# Index: []
#
# [0 rows x 159 columns]

# %%
cols = [
    'Hiểu biết về chính sách hiện hành (%)',
    'Hiểu biết về vị trí lãnh đạo (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về chính sách hiện hành (%)  \
# min                                                                0.445589
# max                                                                0.826309
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về vị trí lãnh đạo (%)
# min                                                           0.299953
# max                                                           0.639612

# %%
cols = [
    'Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%)',
    'Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%)',
    'Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%)',
    'Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%)',
    'Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%)',
    'Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tham gia vào các tổ chức chính trị, chính trị-xã hội, đoàn thể (%)  \
# min                                                                            0.208001
# max                                                                            0.712301
#
# Tỉnh/Thành phố trực thuộc trung ương  Tham gia vào các tổ chức xã hội, hội, nhóm, câu lạc bộ tự lập (%)  \
# min                                                                            0.055811
# max                                                                            0.295811
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Hội đồng Nhân dân lần gần đây nhất (%)  \
# min                                                                            0.467646
# max                                                                            0.908741
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời đã tham gia bầu cử đại biểu Quốc hội lần gần đây nhất (%)  \
# min                                                                            0.466246
# max                                                                            0.971831
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết trưởng thôn/tổ trưởng tổ dân phố là do dân bầu (%)  \
# min                                                                            0.708341
# max                                                                            0.948349
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời trực tiếp bầu trưởng thôn/tổ trưởng tổ dân phố (%)
# min                                                                            0.565209
# max                                                                            0.766138

# %%
cols = [
    'Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%)',
    'Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%)',
    'Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%)',
    'Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%)',
    'Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%)',
    'Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có từ hai ứng cử viên trở lên để dân bầu trưởng thôn/tổ trưởng tổ dân phố (%)  \
# min                                                                            0.239384
# max                                                                            0.607489
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết gia đình được mời đi bầu trưởng thôn/tổ trưởng tổ dân phố (%)  \
# min                                                                            0.293611
# max                                                                            0.851300
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết hình thức bầu trưởng thôn/tổ trưởng tổ dân phố là bỏ phiếu kín (%)  \
# min                                                                            0.305979
# max                                                                            0.989325
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết kết quả bầu cử trưởng thôn/tổ trưởng tổ dân phố được niêm yết công khai (%)  \
# min                                                                            0.486870
# max                                                                            0.977325
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết chính quyền không gợi ý bầu cho một ứng viên cụ thể (%)  \
# min                                                                            0.026523
# max                                                                            0.891851
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ đã bầu cho người đã trúng cử (%)
# min                                                                            0.801412
# max                                                                            0.975061

# %%
cols = [
    'Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%)',
    'Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%)',
    'Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%)',
    'Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%)',
    'Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã đóng góp tự nguyện cho một công trình công cộng ở xã/phường nơi sinh sống (%)  \
# min                                                                            0.238152
# max                                                                            0.674527
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết Ban Thanh tra nhân dân hoặc Ban giám sát đầu tư cộng đồng giám sát việc xây mới/tu sửa công trình (%)  \
# min                                                                            0.191827
# max                                                                            0.623433
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đóng góp của họ được ghi chép vào sổ sách của xã/phường (%)  \
# min                                                                            0.375344
# max                                                                            0.873321
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã tham gia vào việc quyết định xây mới/tu sửa công trình công cộng ở xã/phường (%)  \
# min                                                                            0.264176
# max                                                                            0.734623
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có tham gia đóng góp ý kiến trong quá trình thiết kế để xây mới/tu sửa công trình (%)
# min                                                                            0.153038
# max                                                                            0.523592

# %%
cols = [
    'Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%)',
    'Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%)',
    'Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%)',
    'Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%)',
    'Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%)',
    'Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã tìm kiếm thông tin về chính sách, pháp luật từ chính quyền địa phương (%)  \
# min                                                                            0.110223
# max                                                                            0.288375
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã nhận được thông tin chính sách, pháp luật từ chính quyền địa phương (%)  \
# min                                                                            0.088302
# max                                                                            0.274568
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết thông tin chính sách, pháp luật nhận được là hữu ích (%)  \
# min                                                                            0.082483
# max                                                                            0.267422
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết thông tin về chính sách, pháp luật từ cơ quan chính quyền là đáng tin cậy (%)  \
# min                                                                            0.085285
# max                                                                            0.262025
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết KHÔNG phải trả chi phí không chính thức mới lấy được thông tin từ chính quyền địa phương (%)  \
# min                                                                            0.931665
# max                                                                            1.000000
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết KHÔNG phải chờ đợi quá lâu mới lấy được thông tin từ chính quyền địa phương (%)
# min                                                                             0.98735
# max                                                                             1.00000

# %%
cols = [
    'Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%)',
    'Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%)',
    'Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết danh sách hộ nghèo được công bố công khai trong 12 tháng qua (%)  \
# min                                                                            0.386815
# max                                                                            0.833832
#
# Tỉnh/Thành phố trực thuộc trung ương  Có những hộ thực tế rất nghèo nhưng không được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%)  \
# min                                                                            0.125740
# max                                                                            0.466626
#
# Tỉnh/Thành phố trực thuộc trung ương  Có những hộ thực tế không nghèo nhưng lại được đưa vào danh sách hộ nghèo (% người trả lời cho là đúng) (%)
# min                                                                            0.103677
# max                                                                            0.522485

# %%
cols = [
    'Thu chi ngân sách của xã/phường được công bố công khai (%)',
    'Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%)',
    'Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Thu chi ngân sách của xã/phường được công bố công khai (%)  \
# min                                                                            0.247191
# max                                                                            0.690530
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã từng đọc bảng kê thu chi ngân sách (%)  \
# min                                                                            0.126961
# max                                                                            0.355702
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ tin vào tính chính xác của thông tin về thu chi ngân sách đã công bố (%)
# min                                                                            0.694806
# max                                                                            0.945538

# %%
cols = [
    'Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%)',
    'Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%)',
    'Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%)',
    'Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi)',
    'Tỷ lệ người trả lời cho biết hộ gia đình không bị thu hồi đất theo quy hoạch, kế hoạch sử dụng đất gần đây (%)',
    'Tỷ lệ người trả lời cho biết hộ gia đình bị thu hồi đất được đền bù với giá xấp xỉ giá thị trường (%)',
    'Tỷ lệ người trả lời biết nơi cung cấp thông tin bảng giá đất được chính thức ban hành ở địa phương (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời được biết về quy hoạch, kế hoạch sử dụng đất hiện thời của địa phương (%)  \
# min                                                                            0.110844
# max                                                                            0.301379
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ có dịp góp ý kiến cho quy hoạch, kế hoạch sử dụng đất của địa phương (%)  \
# min                                                                            0.014707
# max                                                                            0.093725
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết chính quyền địa phương đã tiếp thu ý kiến đóng góp của người dân cho quy hoạch, kế hoạch sử dụng đất (%)  \
# min                                                                            0.711331
# max                                                                            1.000000
#
# Tỉnh/Thành phố trực thuộc trung ương  Ảnh hưởng của kế hoạch/quy hoạch sử dụng đất tới hộ gia đình (1=Không có ảnh hưởng gì, 2=Bất lợi; 3=Có lợi)  \
# min                                                                            2.106874
# max                                                                            2.441503
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết hộ gia đình không bị thu hồi đất theo quy hoạch, kế hoạch sử dụng đất gần đây (%)  \
# min                                                                            0.683472
# max                                                                            0.947521
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết hộ gia đình bị thu hồi đất được đền bù với giá xấp xỉ giá thị trường (%)  \
# min                                                                            0.078043
# max                                                                            0.739260
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời biết nơi cung cấp thông tin bảng giá đất được chính thức ban hành ở địa phương (%)
# min                                                                            0.303839
# max                                                                            0.675879

# %%
cols = [
    'Tỷ lệ người trả lời cho biết họ đã liên hệ với trưởng thôn/tổ trưởng TDP để giải quyết khúc mắc (%)',
    'Tỷ lệ người trả lời cho biết cuộc gặp với trưởng thôn/tổ trưởng TDP để giải quyết khúc mắc có kết quả tốt (%)',
    'Tỷ lệ người trả lời cho biết họ đã liên hệ cán bộ UBND xã/phường để giải quyết khúc mắc (%)',
    'Tỷ lệ người trả lời cho biết cuộc gặp với cán bộ UBND xã/phường để giải quyết khúc mắc có kết quả tốt (%)',
    'Tỷ lệ người trả lời cho biết họ đã liên hệ cán bộ đoàn thể để giải quyết khúc mắc (%)',
    'Tỷ lệ người trả lời cho biết cuộc gặp với cán bộ đoàn thể để giải quyết khúc mắc có kết quả tốt (%)',
    'Tỷ lệ người trả lời cho biết họ đã liên hệ cán bộ HĐND xã/phường để giải quyết khúc mắc (%)',
    'Tỷ lệ người trả lời cho biết cuộc gặp với cán bộ HĐND xã/phường để giải quyết khúc mắc có kết quả tốt (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ đã liên hệ với trưởng thôn/tổ trưởng TDP để giải quyết khúc mắc (%)  \
# min                                                                            0.176651
# max                                                                            0.353104
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết cuộc gặp với trưởng thôn/tổ trưởng TDP để giải quyết khúc mắc có kết quả tốt (%)  \
# min                                                                            0.817403
# max                                                                            0.989784
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ đã liên hệ cán bộ UBND xã/phường để giải quyết khúc mắc (%)  \
# min                                                                            0.107309
# max                                                                            0.255577
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết cuộc gặp với cán bộ UBND xã/phường để giải quyết khúc mắc có kết quả tốt (%)  \
# min                                                                            0.753858
# max                                                                            1.000000
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ đã liên hệ cán bộ đoàn thể để giải quyết khúc mắc (%)  \
# min                                                                            0.049738
# max                                                                            0.144003
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết cuộc gặp với cán bộ đoàn thể để giải quyết khúc mắc có kết quả tốt (%)  \
# min                                                                            0.863935
# max                                                                            1.000000
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ đã liên hệ cán bộ HĐND xã/phường để giải quyết khúc mắc (%)  \
# min                                                                            0.008165
# max                                                                            0.078318
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết cuộc gặp với cán bộ HĐND xã/phường để giải quyết khúc mắc có kết quả tốt (%)
# min                                                                            0.627456
# max                                                                            1.000000

# %%
cols = [
    'Tỷ lệ người trả lời cho biết họ đã gửi khuyến nghị, tố giác, tố cáo, khiếu nại tới chính quyền địa phương (%)',
    'Tỷ lệ người trả lời đã gửi khuyến nghị, tố giác, tố cáo, khiếu nại cho biết đã được chính quyền phúc đáp thỏa đáng (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết họ đã gửi khuyến nghị, tố giác, tố cáo, khiếu nại tới chính quyền địa phương (%)  \
# min                                                                            0.116061
# max                                                                            0.381419
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời đã gửi khuyến nghị, tố giác, tố cáo, khiếu nại cho biết đã được chính quyền phúc đáp thỏa đáng (%)
# min                                                                            0.099692
# max                                                                            0.332769

# %%
cols = [
    'Tỷ lệ người trả lời tin vào tòa án và các cơ quan tư pháp địa phương (%)',
    'Tỷ lệ người trả lời cho biết sẽ sử dụng tòa án địa phương khi có tranh chấp dân sự (%)',
    'Tỷ lệ người trả lời cho biết sẽ sử dụng các biện pháp phi tòa án khi có tranh chấp dân sự (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời tin vào tòa án và các cơ quan tư pháp địa phương (%)  \
# min                                                                            0.828539
# max                                                                            0.955207
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết sẽ sử dụng tòa án địa phương khi có tranh chấp dân sự (%)  \
# min                                                                            0.584164
# max                                                                            0.940114
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết sẽ sử dụng các biện pháp phi tòa án khi có tranh chấp dân sự (%)
# min                                                                            0.031649
# max                                                                            0.190538

# %%
cols = [
    'Tỷ lệ người trả lời cho biết cán bộ chính quyền KHÔNG dùng tiền công quỹ vào mục đích riêng (%)',
    'Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền để được nhận giấy chứng nhận quyền sử dụng đất (%)',
    'Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền để nhận được giấy phép xây dựng (%)',
    'Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền cho cán bộ khi làm chứng thực, xác nhận (%)',
    'Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền khi làm thủ tục hành chính ở Ủy ban Nhân dân cấp xã (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết cán bộ chính quyền KHÔNG dùng tiền công quỹ vào mục đích riêng (%)  \
# min                                                                            0.583393
# max                                                                            0.796688
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền để được nhận giấy chứng nhận quyền sử dụng đất (%)  \
# min                                                                            0.503158
# max                                                                            0.747341
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền để nhận được giấy phép xây dựng (%)  \
# min                                                                            0.486230
# max                                                                            0.783221
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền cho cán bộ khi làm chứng thực, xác nhận (%)  \
# min                                                                            0.135746
# max                                                                            0.452816
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền khi làm thủ tục hành chính ở Ủy ban Nhân dân cấp xã (%)
# min                                                                            0.127940
# max                                                                            0.272556

# %%
cols = [
    'Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền để được quan tâm hơn khi đi khám chữa bệnh (%)',
    'Tỷ lệ người trả lời cho biết phụ huynh học sinh tiểu học KHÔNG phải chi thêm tiền để con em được quan tâm hơn (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết người dân KHÔNG phải chi thêm tiền để được quan tâm hơn khi đi khám chữa bệnh (%)  \
# min                                                                            0.641205
# max                                                                            0.843597
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết phụ huynh học sinh tiểu học KHÔNG phải chi thêm tiền để con em được quan tâm hơn (%)
# min                                                                            0.636720
# max                                                                            0.867115

# %%
cols = [
    'Tỷ lệ người trả lời cho biết KHÔNG phải đưa tiền ‘lót tay’ để xin được việc làm trong cơ quan nhà nước (%)',
    'Mối quan hệ cá nhân với người có chức quyền là không quan trọng khi xin vào làm 1 trong số 5 vị trí được hỏi (0=rất quan trọng; 5=không quan trọng chút nào)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết KHÔNG phải đưa tiền ‘lót tay’ để xin được việc làm trong cơ quan nhà nước (%)  \
# min                                                                            0.410209
# max                                                                            0.708525
#
# Tỉnh/Thành phố trực thuộc trung ương  Mối quan hệ cá nhân với người có chức quyền là không quan trọng khi xin vào làm 1 trong số 5 vị trí được hỏi (0=rất quan trọng; 5=không quan trọng chút nào)
# min                                                                            0.885359
# max                                                                            2.601346

# %%
cols = [
    'Tỷ lệ người dân cho biết KHÔNG bị vòi vĩnh đòi hối lộ trong 12 tháng vừa qua (%)',
    'Tỷ lệ người dân cho biết chính quyền tỉnh/thành phố đã xử lý nghiêm túc vụ việc tham nhũng ở địa phương (%)',
    'Mức tiền đòi hối lộ người dân bắt đầu tố cáo (đơn vị 1000 VNĐ)',
    'Người bị vòi vĩnh đã tố cáo hành vi đòi hối lộ (%)',
    "Tỷ lệ người làm thủ tục sổ đỏ đã phải 'chung chi' (%)",
    "Tỷ lệ người dân (có người thân hoặc bản thân) đi điều trị ở bệnh viện tuyến huyện/quận đã phải 'chung chi' (%)"
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người dân cho biết KHÔNG bị vòi vĩnh đòi hối lộ trong 12 tháng vừa qua (%)  \
# min                                                                            0.929127
# max                                                                            0.999297
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người dân cho biết chính quyền tỉnh/thành phố đã xử lý nghiêm túc vụ việc tham nhũng ở địa phương (%)  \
# min                                                                            0.409189
# max                                                                            0.757230
#
# Tỉnh/Thành phố trực thuộc trung ương  Mức tiền đòi hối lộ người dân bắt đầu tố cáo (đơn vị 1000 VNĐ)  \
# min                                                                         24300.04102
# max                                                                         41019.00781
#
# Tỉnh/Thành phố trực thuộc trung ương  Người bị vòi vĩnh đã tố cáo hành vi đòi hối lộ (%)  \
# min                                                                            0.000000
# max                                                                            0.194595
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người làm thủ tục sổ đỏ đã phải 'chung chi' (%)  \
# min                                                                            0.250828
# max                                                                            0.622950
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người dân (có người thân hoặc bản thân) đi điều trị ở bệnh viện tuyến huyện/quận đã phải 'chung chi' (%)
# min                                                                            0.235394
# max                                                                            0.722336

# %%
cols = [
    'Tỉ lệ người dân đã làm thủ tục lấy chứng thực, xác nhận của chính quyền (%)',
    'Tổng chất lượng dịch vụ chứng thực, xác nhận của chính quyền (4 tiêu chí)',
    'Mức độ hài lòng với dịch vụ nhận được (5 điểm)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người dân đã làm thủ tục lấy chứng thực, xác nhận của chính quyền (%)  \
# min                                                                            0.147238
# max                                                                            0.470167
#
# Tỉnh/Thành phố trực thuộc trung ương  Tổng chất lượng dịch vụ chứng thực, xác nhận của chính quyền (4 tiêu chí)  \
# min                                                                            3.567369
# max                                                                            3.996537
#
# Tỉnh/Thành phố trực thuộc trung ương  Mức độ hài lòng với dịch vụ nhận được (5 điểm)  \
# min                                                                         3.921736
# max                                                                         4.495267
#
# Tỉnh/Thành phố trực thuộc trung ương  Mức độ hài lòng với dịch vụ nhận được (5 điểm)  \
# min                                                                         3.127271
# max                                                                         4.340656
#
# Tỉnh/Thành phố trực thuộc trung ương  Mức độ hài lòng với dịch vụ nhận được (5 điểm)
# min                                                                         3.891029
# max                                                                         4.532808

# %%
cols = [
    'Tỉ lệ người dân cho biết hộ gia đình đã xin cấp giấy chứng nhận quyền sử dụng đất (%)',
    'Tỷ lệ người đi làm thủ tục cho biết không phải đi qua nhiều ‘cửa’ để làm xong các thủ tục liên quan đến đến giấy CNQSD đất (%)',
    'Tỷ lệ người đi làm thủ tục cho biết đã nhận được kết quả liên quan đến giấy CNQSD đất (%)',
    'Tổng chất lượng dịch vụ hành chính về thủ tục liên quan đến giấy CNQSD đất (4 tiêu chí)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người dân cho biết hộ gia đình đã xin cấp giấy chứng nhận quyền sử dụng đất (%)  \
# min                                                                            0.071260
# max                                                                            0.211471
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người đi làm thủ tục cho biết không phải đi qua nhiều ‘cửa’ để làm xong các thủ tục liên quan đến đến giấy CNQSD đất (%)  \
# min                                                                            0.585024
# max                                                                            0.990789
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người đi làm thủ tục cho biết đã nhận được kết quả liên quan đến giấy CNQSD đất (%)  \
# min                                                                            0.636170
# max                                                                            0.936263
#
# Tỉnh/Thành phố trực thuộc trung ương  Tổng chất lượng dịch vụ hành chính về thủ tục liên quan đến giấy CNQSD đất (4 tiêu chí)
# min                                                                            2.952636
# max                                                                            3.894545

# %%
cols = [
    'Tỉ lệ người dân cho biết hộ gia đình/bản thân đã làm thủ tục hành chính ở UBND xã/phường/thị trấn (%)',
    'Tỷ lệ người đi làm thủ tục cho biết không phải đi qua nhiều ‘cửa’ để làm xong thủ tục (%)',
    'Tổng chất lượng dịch vụ hành chính của UBND xã/phường (4 tiêu chí)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người dân cho biết hộ gia đình/bản thân đã làm thủ tục hành chính ở UBND xã/phường/thị trấn (%)  \
# min                                                                            0.120563
# max                                                                            0.311911
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người đi làm thủ tục cho biết không phải đi qua nhiều ‘cửa’ để làm xong thủ tục (%)  \
# min                                                                            0.910513
# max                                                                            1.000000
#
# Tỉnh/Thành phố trực thuộc trung ương  Tổng chất lượng dịch vụ hành chính của UBND xã/phường (4 tiêu chí)
# min                                                                            2.970149
# max                                                                            3.812081

# %%
cols = [
    'Tỷ lệ người được hỏi có bảo hiểm y tế (%)',
    'Tác dụng của thẻ bảo hiểm y tế (1=Không có tác dụng, 4=Có tác dụng rất tốt)',
    'Dịch vụ khám chữa bệnh miễn phí cho trẻ dưới 6 tuổi (1=Rất kém; 5=Rất tốt)',
    'Tỷ lệ người được hỏi cho biết người nghèo được hỗ trợ để mua bảo hiểm y tế (%)',
    'Tỷ lệ người được hỏi cho biết trẻ em dưới 6 tuổi được miễn phí khám chữa bệnh (%)',
    'Tổng chất lượng bệnh viện tuyến huyện/quận (10 tiêu chí)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi có bảo hiểm y tế (%)  \
# min                                                                    0.869361
# max                                                                    0.987429
#
# Tỉnh/Thành phố trực thuộc trung ương  Tác dụng của thẻ bảo hiểm y tế (1=Không có tác dụng, 4=Có tác dụng rất tốt)  \
# min                                                                            3.375368
# max                                                                            3.726743
#
# Tỉnh/Thành phố trực thuộc trung ương  Dịch vụ khám chữa bệnh miễn phí cho trẻ dưới 6 tuổi (1=Rất kém; 5=Rất tốt)  \
# min                                                                            4.015229
# max                                                                            4.576151
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết người nghèo được hỗ trợ để mua bảo hiểm y tế (%)  \
# min                                                                            0.549694
# max                                                                            0.950249
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết trẻ em dưới 6 tuổi được miễn phí khám chữa bệnh (%)  \
# min                                                                            0.502045
# max                                                                            0.992578
#
# Tỉnh/Thành phố trực thuộc trung ương  Tổng chất lượng bệnh viện tuyến huyện/quận (10 tiêu chí)
# min                                                                            2.059157
# max                                                                            6.382187

# %%
cols = [
    'Quãng đường đi bộ tới trường (KM – theo giá trị trung vị)',
    'Quãng thời gian tới trường (PHÚT – theo giá trị trung vị)',
    'Nhận xét về chất lượng dạy học của trường tiểu học công lập (1=Rất kém; 5=Rất tốt)',
    'Tổng chất lượng trường tiểu học tại địa bàn xã/phường (8 tiêu chí)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Quãng đường đi bộ tới trường (KM – theo giá trị trung vị)  \
# min                                                                                0.55
# max                                                                                1.60
#
# Tỉnh/Thành phố trực thuộc trung ương  Quãng thời gian tới trường (PHÚT – theo giá trị trung vị)  \
# min                                                                                 5.0
# max                                                                                10.0
#
# Tỉnh/Thành phố trực thuộc trung ương  Nhận xét về chất lượng dạy học của trường tiểu học công lập (1=Rất kém; 5=Rất tốt)  \
# min                                                                            4.027622
# max                                                                            4.392212
#
# Tỉnh/Thành phố trực thuộc trung ương  Tổng chất lượng trường tiểu học tại địa bàn xã/phường (8 tiêu chí)
# min                                                                            3.445079
# max                                                                            5.728079

# %%
cols = [
    'Tỷ lệ người được hỏi cho biết hộ gia đình đã dùng điện lưới (%)',
    'Tỷ lệ người được hỏi cho biết hộ gia đình không bị cắt/cúp điện trong 12 tháng qua (%)',
    'Loại đường giao thông gần hộ gia đình nhất (1=Đường đất; 4=Đường trải nhựa)',
    'Mức độ thường xuyên của dịch vụ thu gom rác thải của chính quyền địa phương (0=Không có; 4=Hàng ngày)',
    'Tỷ lệ người được hỏi cho biết hộ gia đình mình dùng nước máy là nguồn nước ăn uống chính (%) (5=Trạm cấp nước tập trung; 6=nước máy về tận nhà)',
    'Tỷ lệ người được hỏi cho biết hộ gia đình mình dùng nước chưa hợp vệ sinh (%) (1=Nước mưa; 2=Nước sông/hồ/suối)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết hộ gia đình đã dùng điện lưới (%)  \
# min                                                                            0.966016
# max                                                                            1.000000
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết hộ gia đình không bị cắt/cúp điện trong 12 tháng qua (%)  \
# min                                                                            0.046573
# max                                                                            0.638414
#
# Tỉnh/Thành phố trực thuộc trung ương  Loại đường giao thông gần hộ gia đình nhất (1=Đường đất; 4=Đường trải nhựa)  \
# min                                                                            2.912919
# max                                                                            3.708188
#
# Tỉnh/Thành phố trực thuộc trung ương  Mức độ thường xuyên của dịch vụ thu gom rác thải của chính quyền địa phương (0=Không có; 4=Hàng ngày)  \
# min                                                                            1.763761
# max                                                                            3.926196
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết hộ gia đình mình dùng nước máy là nguồn nước ăn uống chính (%) (5=Trạm cấp nước tập trung; 6=nước máy về tận nhà)  \
# min                                                                            0.082247
# max                                                                            0.989284
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết hộ gia đình mình dùng nước chưa hợp vệ sinh (%) (1=Nước mưa; 2=Nước sông/hồ/suối)
# min                                                                            0.000000
# max                                                                            0.233085

# %%
cols = [
    'Mức độ an toàn, trật tự ở địa bàn đang sinh sống (1=Rất không an toàn; 3=Rất an toàn)',
    'Tỷ lệ người được hỏi cho biết có thay đổi về mức độ an ninh theo hướng tốt lên sau 3 năm (%)',
    'Tỷ lệ người được hỏi cho biết là nạn nhân của một trong 4 loại tội phạm về an ninh, trật tự (%)',
    'Cảm thấy an toàn khi đi bộ một mình vào ban ngày (3=rất an toàn)',
    'Cảm thấy an toàn khi đi bộ một mình vào ban đêm (3=rất an toàn)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Mức độ an toàn, trật tự ở địa bàn đang sinh sống (1=Rất không an toàn; 3=Rất an toàn)  \
# min                                                                             2.20696
# max                                                                             2.56214
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết có thay đổi về mức độ an ninh theo hướng tốt lên sau 3 năm (%)  \
# min                                                                            0.058767
# max                                                                            0.224857
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết là nạn nhân của một trong 4 loại tội phạm về an ninh, trật tự (%)  \
# min                                                                            1.138528
# max                                                                           18.469500
#
# Tỉnh/Thành phố trực thuộc trung ương  Cảm thấy an toàn khi đi bộ một mình vào ban ngày (3=rất an toàn)  \
# min                                                                            2.220152
# max                                                                            2.584497
#
# Tỉnh/Thành phố trực thuộc trung ương  Cảm thấy an toàn khi đi bộ một mình vào ban đêm (3=rất an toàn)
# min                                                                            1.954397
# max                                                                            2.418112

# %%
col_name = "Tỷ lệ người được hỏi cho biết là nạn nhân của một trong 4 loại tội phạm về an ninh, trật tự (%)"

# Chia 100 trực tiếp trên toàn bộ cột
df[col_name] = df[col_name] / 100

# %%
cols = [
    'Mức độ an toàn, trật tự ở địa bàn đang sinh sống (1=Rất không an toàn; 3=Rất an toàn)',
    'Tỷ lệ người được hỏi cho biết có thay đổi về mức độ an ninh theo hướng tốt lên sau 3 năm (%)',
    'Tỷ lệ người được hỏi cho biết là nạn nhân của một trong 4 loại tội phạm về an ninh, trật tự (%)',
    'Cảm thấy an toàn khi đi bộ một mình vào ban ngày (3=rất an toàn)',
    'Cảm thấy an toàn khi đi bộ một mình vào ban đêm (3=rất an toàn)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Mức độ an toàn, trật tự ở địa bàn đang sinh sống (1=Rất không an toàn; 3=Rất an toàn)  \
# min                                                                             2.20696
# max                                                                             2.56214
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết có thay đổi về mức độ an ninh theo hướng tốt lên sau 3 năm (%)  \
# min                                                                            0.058767
# max                                                                            0.224857
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người được hỏi cho biết là nạn nhân của một trong 4 loại tội phạm về an ninh, trật tự (%)  \
# min                                                                            0.011385
# max                                                                            0.184695
#
# Tỉnh/Thành phố trực thuộc trung ương  Cảm thấy an toàn khi đi bộ một mình vào ban ngày (3=rất an toàn)  \
# min                                                                            2.220152
# max                                                                            2.584497
#
# Tỉnh/Thành phố trực thuộc trung ương  Cảm thấy an toàn khi đi bộ một mình vào ban đêm (3=rất an toàn)
# min                                                                            1.954397
# max                                                                            2.418112

# %%
cols = [
    'Tỷ lệ người trả lời cho biết doanh nghiệp tại địa phương KHÔNG đưa hối lội để trốn tránh nghĩa vụ bảo vệ môi trường (%)',
    'Tỉ lệ người trả lời cho biết bảo vệ môi trường cần được ưu tiên hơn phát triển kinh tế bằng mọi giá (%)',
    'Tỉ lệ người trả lời cho biết họ đã báo cáo và yêu cầu xử lý sự cố/vấn đề môi trường ở địa phương (%)',
    'Cơ quan chức năng của chính quyền địa phương đã giải quyết sự cố/vấn đề môi trường được thông báo (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết doanh nghiệp tại địa phương KHÔNG đưa hối lội để trốn tránh nghĩa vụ bảo vệ môi trường (%)  \
# min                                                                            0.504972
# max                                                                            0.728767
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết bảo vệ môi trường cần được ưu tiên hơn phát triển kinh tế bằng mọi giá (%)  \
# min                                                                            0.516373
# max                                                                            0.819849
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết họ đã báo cáo và yêu cầu xử lý sự cố/vấn đề môi trường ở địa phương (%)  \
# min                                                                            0.733682
# max                                                                            0.953114
#
# Tỉnh/Thành phố trực thuộc trung ương  Cơ quan chức năng của chính quyền địa phương đã giải quyết sự cố/vấn đề môi trường được thông báo (%)
# min                                                                            0.450640
# max                                                                            0.746956

# %%
cols = [
    'Tỷ lệ người trả lời cho biết không phải đeo khẩu trang để tránh ô nhiễm không khí khi đi lại ở địa bàn nơi cư trú (%)',
    'Tỷ lệ người trả lời đánh giá chất lượng không khí nơi cư trú đủ tốt (%)',
    'Tỷ lệ người trả lời cho rằng chất lượng không khí ở địa phương tốt hơn 3 năm trước (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết không phải đeo khẩu trang để tránh ô nhiễm không khí khi đi lại ở địa bàn nơi cư trú (%)  \
# min                                                                            0.150374
# max                                                                            0.452284
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời đánh giá chất lượng không khí nơi cư trú đủ tốt (%)  \
# min                                                                            0.747091
# max                                                                            0.968504
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho rằng chất lượng không khí ở địa phương tốt hơn 3 năm trước (%)
# min                                                                            0.297577
# max                                                                            0.678052

# %%
cols = [
    'Nước từ sông/kênh/rạch/suối gần nhà đủ sạch để uống (%)',
    'Nước từ sông/kênh/rạch/suối gần nhà đủ sạch để giặt giũ (%)',
    'Nước từ sông/kênh/rạch/suối gần nhà đủ sạch để bơi lội (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Nước từ sông/kênh/rạch/suối gần nhà đủ sạch để uống (%)  \
# min                                                                            0.000211
# max                                                                            0.173690
#
# Tỉnh/Thành phố trực thuộc trung ương  Nước từ sông/kênh/rạch/suối gần nhà đủ sạch để giặt giũ (%)  \
# min                                                                            0.000363
# max                                                                            0.426451
#
# Tỉnh/Thành phố trực thuộc trung ương  Nước từ sông/kênh/rạch/suối gần nhà đủ sạch để bơi lội (%)
# min                                                                            0.007696
# max                                                                            0.424341

# %%
cols = [
    'Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm chứng thực, xác nhận (%)',
    'Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm thủ tục cấp giấy chứng nhận quyền sử dụng đất (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm chứng thực, xác nhận (%)  \
# min                                                                            0.028484
# max                                                                            0.104350
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm thủ tục cấp giấy chứng nhận quyền sử dụng đất (%)
# min                                                                            0.006824
# max                                                                            0.035991

# %%
cols = [
    'Tỷ lệ người trả lời tiếp cận tin tức trong nước qua Internet (%)',
    'Tỷ lệ người trả lời cho biết có kết nối Internet tại nhà (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời tiếp cận tin tức trong nước qua Internet (%)  \
# min                                                                            0.449130
# max                                                                            0.818354
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có kết nối Internet tại nhà (%)
# min                                                                            0.531802
# max                                                                            0.961630

# %%
cols = [
    'Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến ở địa phương khi làm thủ tục hành chính do cấp xã/phường thực hiện (%)',
    'Tỉ lệ người trả lời cho biết cổng thông tin điện tử của tỉnh, thành phố dễ sử dụng cho tra cứu thông tin (%)',
    'Tỉ lệ người trả lời cho biết chính quyền địa phương có đăng tải dự thảo chính sách, pháp luật lên cổng thông tin điện tử để lấy ý kiến nhân dân (%)',
    'Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)',
    'Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)'
]

# Xem min và max của từng cột
print(df[cols].agg(['min', 'max']))
# Out:
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến ở địa phương khi làm thủ tục hành chính do cấp xã/phường thực hiện (%)  \
# min                                                                            0.010159
# max                                                                            0.058202
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết cổng thông tin điện tử của tỉnh, thành phố dễ sử dụng cho tra cứu thông tin (%)  \
# min                                                                            0.186271
# max                                                                            0.446668
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết chính quyền địa phương có đăng tải dự thảo chính sách, pháp luật lên cổng thông tin điện tử để lấy ý kiến nhân dân (%)  \
# min                                                                            0.416730
# max                                                                            0.732672
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)  \
# min                                                                            0.029056
# max                                                                            0.157760
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)
# min                                                                            0.225668
# max                                                                            0.911437

# %%
df
# Out:
# Tỉnh/Thành phố trực thuộc trung ương   Tỉnh/Thành phố  \
# 0                                              Hà Nội
# 1                                            Cao Bằng
# 2                                         Tuyên Quang
# 3                                             Lào Cai
# 4                                           Điện Biên
# 5                                            Lai Châu
# 6                                              Sơn La
# 7                                         Thái Nguyên
# 8                                            Lạng Sơn
# 9                                          Quảng Ninh
# 10                                            Phú Thọ
# 11                                           Bắc Ninh
# 12                                          Hải Phòng
# 13                                           Hưng Yên
# 14                                          Ninh Bình
# 15                                          Thanh Hóa
# 16                                            Nghệ An
# 17                                            Hà Tĩnh
# 18                                          Quảng Trị
# 19                                     Thừa Thiên-Huế
# 20                                            Đà Nẵng
# 21                                         Quảng Ngãi
# 22                                          Khánh Hòa
# 23                                            Gia Lai
# 24                                            Đắk Lắk
# 25                                           Lâm Đồng
# 26                                           Tây Ninh
# 27                                           Đồng Nai
# 28                                    TP. Hồ Chí Minh
# 29                                          Vĩnh Long
# 30                                          Đồng Tháp
# 31                                           An Giang
# 32                                            Cần Thơ
# 33                                             Cà Mau
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số)  \
# 0                                                                    43.774715
# 1                                                                    41.332478
# 2                                                                    43.172611
# 3                                                                    41.849570
# 4                                                                    41.375828
# 5                                                                    43.479568
# 6                                                                    43.887550
# 7                                                                    45.951166
# 8                                                                    45.003624
# 9                                                                    47.821236
# 10                                                                   44.063235
# 11                                                                   45.028375
# 12                                                                   42.650545
# 13                                                                   44.602359
# 14                                                                   44.019932
# 15                                                                   44.870750
# 16                                                                   43.069889
# 17                                                                   45.553085
# 18                                                                   44.217131
# 19                                                                   45.095047
# 20                                                                   42.029420
# 21                                                                   42.197246
# 22                                                                   44.414544
# 23                                                                   42.341797
# 24                                                                   42.257508
# 25                                                                   43.254680
# 26                                                                   44.313948
# 27                                                                   41.776783
# 28                                                                   43.602789
# 29                                                                   41.647474
# 30                                                                   43.835712
# 31                                                                   41.442199
# 32                                                                   43.001186
# 33                                                                   44.341113
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối thiểu trong khoảng tin cậy 95%  \
# 0                                                                             43.220791
# 1                                                                             39.598320
# 2                                                                             40.406404
# 3                                                                             39.282421
# 4                                                                             40.439476
# 5                                                                             42.184723
# 6                                                                             42.421448
# 7                                                                             43.167816
# 8                                                                             43.075245
# 9                                                                             46.906075
# 10                                                                            43.585484
# 11                                                                            43.840976
# 12                                                                            40.559065
# 13                                                                            43.457243
# 14                                                                            43.340717
# 15                                                                            44.529171
# 16                                                                            42.400673
# 17                                                                            44.707905
# 18                                                                            43.596582
# 19                                                                            44.521580
# 20                                                                            41.054775
# 21                                                                            40.942642
# 22                                                                            42.916039
# 23                                                                            41.439915
# 24                                                                            41.795035
# 25                                                                            41.070513
# 26                                                                            41.749232
# 27                                                                            40.995208
# 28                                                                            42.301961
# 29                                                                            40.422285
# 30                                                                            42.028534
# 31                                                                            40.933153
# 32                                                                            41.403448
# 33                                                                            42.661096
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - điểm tối đa trong khoảng tin cậy 95%  \
# 0                                                                             44.328640
# 1                                                                             43.066635
# 2                                                                             45.938817
# 3                                                                             44.416718
# 4                                                                             42.312180
# 5                                                                             44.774414
# 6                                                                             45.353653
# 7                                                                             48.734515
# 8                                                                             46.932003
# 9                                                                             48.736397
# 10                                                                            44.540986
# 11                                                                            46.215775
# 12                                                                            44.742025
# 13                                                                            45.747474
# 14                                                                            44.699147
# 15                                                                            45.212330
# 16                                                                            43.739105
# 17                                                                            46.398266
# 18                                                                            44.837680
# 19                                                                            45.668514
# 20                                                                            43.004065
# 21                                                                            43.451849
# 22                                                                            45.913050
# 23                                                                            43.243678
# 24                                                                            42.719981
# 25                                                                            45.438847
# 26                                                                            46.878664
# 27                                                                            42.558359
# 28                                                                            44.903617
# 29                                                                            42.872662
# 30                                                                            45.642891
# 31                                                                            41.951246
# 32                                                                            44.598925
# 33                                                                            46.021130
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số PAPI tổng hợp (không có trọng số) - sai số  \
# 0                                                                              0.282599
# 1                                                                              0.884728
# 2                                                                              1.411256
# 3                                                                              1.309701
# 4                                                                              0.477706
# 5                                                                              0.660600
# 6                                                                              0.747973
# 7                                                                              1.420002
# 8                                                                              0.983815
# 9                                                                              0.466895
# 10                                                                             0.243737
# 11                                                                             0.605785
# 12                                                                             1.067026
# 13                                                                             0.584211
# 14                                                                             0.346520
# 15                                                                             0.174267
# 16                                                                             0.341418
# 17                                                                             0.431191
# 18                                                                             0.316590
# 19                                                                             0.292570
# 20                                                                             0.497242
# 21                                                                             0.640070
# 22                                                                             0.764503
# 23                                                                             0.460119
# 24                                                                             0.235944
# 25                                                                             1.114312
# 26                                                                             1.308460
# 27                                                                             0.398741
# 28                                                                             0.663653
# 29                                                                             0.625063
# 30                                                                             0.921980
# 31                                                                             0.259704
# 32                                                                             0.815130
# 33                                                                             0.857106
#
# Tỉnh/Thành phố trực thuộc trung ương  Chỉ số nội dung 1: Tham gia của người dân ở cấp cơ sở  \
# 0                                                                              5.392270
# 1                                                                              4.640318
# 2                                                                              5.185756
# 3                                                                              4.870843
# 4                                                                              4.631536
# 5                                                                              5.236279
# 6                                                                              5.204468
# 7                                                                              5.745524
# 8                                                                              5.525624
# 9                                                                              5.873931
# 10                                                                             5.233066
# 11                                                                             5.803446
# 12                                                                             5.295103
# 13                                                                             5.292784
# 14                                                                             5.586421
# 15                                                                             5.688568
# 16                                                                             5.318382
# 17                                                                             5.841213
# 18                                                                             5.479559
# 19                                                                             5.389178
# 20                                                                             4.558244
# 21                                                                             4.695246
# 22                                                                             4.571488
# 23                                                                             4.675178
# 24                                                                             4.619146
# 25                                                                             5.052988
# 26                                                                             4.970453
# 27                                                                             4.552126
# 28                                                                             4.801750
# 29                                                                             4.282942
# 30                                                                             4.590105
# 31                                                                             4.197340
# 32                                                                             4.295279
# 33                                                                             4.629526
#
# Tỉnh/Thành phố trực thuộc trung ương  1.1: Tri thức công dân  \
# 0                                                   1.425716
# 1                                                   1.056708
# 2                                                   0.993409
# 3                                                   0.954209
# 4                                                   0.940827
# 5                                                   1.033711
# 6                                                   1.139144
# 7                                                   1.357657
# 8                                                   1.035179
# 9                                                   1.294818
# 10                                                  0.969390
# 11                                                  1.141396
# 12                                                  1.238752
# 13                                                  1.134378
# 14                                                  1.207172
# 15                                                  1.143213
# 16                                                  1.099678
# 17                                                  1.261379
# 18                                                  1.215447
# 19                                                  1.200834
# 20                                                  1.074525
# 21                                                  0.958266
# 22                                                  1.192225
# 23                                                  1.056347
# 24                                                  1.000487
# 25                                                  1.050900
# 26                                                  1.059180
# 27                                                  1.031590
# 28                                                  1.187753
# 29                                                  0.950647
# 30                                                  0.969035
# 31                                                  0.876089
# 32                                                  0.944202
# 33                                                  1.147307
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về chính sách hiện hành (%)  \
# 0                                                                  0.810938
# 1                                                                  0.546855
# 2                                                                  0.560756
# 3                                                                  0.581350
# 4                                                                  0.445589
# 5                                                                  0.583741
# 6                                                                  0.612420
# 7                                                                  0.826309
# 8                                                                  0.542324
# 9                                                                  0.644873
# 10                                                                 0.647116
# 11                                                                 0.616262
# 12                                                                 0.582347
# 13                                                                 0.612288
# 14                                                                 0.601887
# 15                                                                 0.620179
# 16                                                                 0.580817
# 17                                                                 0.700623
# 18                                                                 0.720294
# 19                                                                 0.674878
# 20                                                                 0.600858
# 21                                                                 0.597786
# 22                                                                 0.669127
# 23                                                                 0.643389
# 24                                                                 0.583039
# 25                                                                 0.608786
# 26                                                                 0.693287
# 27                                                                 0.583808
# 28                                                                 0.736355
# 29                                                                 0.545741
# 30                                                                 0.609985
# 31                                                                 0.513142
# 32                                                                 0.604132
# 33                                                                 0.730263
#
# Tỉnh/Thành phố trực thuộc trung ương  Hiểu biết về vị trí lãnh đạo (%)  \
# 0                                                             0.639612
# 1                                                             0.443646
# 2                                                             0.380430
# 3                                                             0.335289
# 4                                                             0.391274
# 5                                                             0.404762
# 6                                                             0.484140
# 7                                                             0.571429
# 8                                                             0.426775
# 9                                                             0.606291
# 10                                                            0.315900
# 11                                                            0.484221
# 12                                                            0.587717
# 13                                                            0.479970
# 14                                                            0.549876
# 15                                                            0.483878
# 16                                                            0.464861
# 17                                                            0.548692
# 18                                                            0.498028
# 19                                                            0.507747
# 20                                                            0.432483
# 21                                                            0.330677
# 22                                                            0.502970
# 23                                                            0.395059
# 24                                                            0.375580
# 25                                                            0.407519
# 26                                                            0.372627
# 27                                                            0.402843
# 28                                                            0.465380
# 29                                                            0.349926
# 30                                                            0.334149
# 31                                                            0.299953
# 32                                                            0.315002
# 33                                                            0.432474
#
# Tỉnh/Thành phố trực thuộc trung ương  1.2: Cơ hội tham gia  ...  \
# 0                                                 1.531022  ...
# 1                                                 1.380181  ...
# 2                                                 1.476668  ...
# 3                                                 1.407232  ...
# 4                                                 1.381613  ...
# 5                                                 1.492470  ...
# 6                                                 1.466421  ...
# 7                                                 1.662174  ...
# 8                                                 1.776866  ...
# 9                                                 1.883087  ...
# 10                                                1.641892  ...
# 11                                                1.800641  ...
# 12                                                1.564284  ...
# 13                                                1.578477  ...
# 14                                                1.582230  ...
# 15                                                1.674948  ...
# 16                                                1.528961  ...
# 17                                                1.521316  ...
# 18                                                1.535966  ...
# 19                                                1.632521  ...
# 20                                                1.323720  ...
# 21                                                1.280490  ...
# 22                                                1.340489  ...
# 23                                                1.266673  ...
# 24                                                1.268819  ...
# 25                                                1.387703  ...
# 26                                                1.259961  ...
# 27                                                1.205145  ...
# 28                                                1.171438  ...
# 29                                                1.102683  ...
# 30                                                1.034663  ...
# 31                                                1.061606  ...
# 32                                                1.021905  ...
# 33                                                1.182422  ...
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết đã lấy đủ thông tin chỉ dẫn và biểu mẫu cần thực hiện từ cổng thông tin điện tử địa phương khi làm thủ tục cấp giấy chứng nhận quyền sử dụng đất (%)  \
# 0                                                                              0.024610
# 1                                                                              0.032581
# 2                                                                              0.030124
# 3                                                                              0.019233
# 4                                                                              0.027679
# 5                                                                              0.034783
# 6                                                                              0.016291
# 7                                                                              0.027246
# 8                                                                              0.022242
# 9                                                                              0.035881
# 10                                                                             0.026238
# 11                                                                             0.010126
# 12                                                                             0.013761
# 13                                                                             0.026513
# 14                                                                             0.025770
# 15                                                                             0.020536
# 16                                                                             0.011146
# 17                                                                             0.028349
# 18                                                                             0.028430
# 19                                                                             0.029084
# 20                                                                             0.007814
# 21                                                                             0.029836
# 22                                                                             0.035991
# 23                                                                             0.015941
# 24                                                                             0.033316
# 25                                                                             0.027754
# 26                                                                             0.016794
# 27                                                                             0.024571
# 28                                                                             0.024963
# 29                                                                             0.011214
# 30                                                                             0.006824
# 31                                                                             0.014784
# 32                                                                             0.012222
# 33                                                                             0.011214
#
# Tỉnh/Thành phố trực thuộc trung ương  8.2: Tiếp cận và sử dụng Internet tại địa phương  \
# 0                                                                             2.960508
# 1                                                                             2.071751
# 2                                                                             2.371423
# 3                                                                             2.369423
# 4                                                                             2.040645
# 5                                                                             2.418868
# 6                                                                             2.495427
# 7                                                                             2.895742
# 8                                                                             2.391233
# 9                                                                             2.951612
# 10                                                                            2.554278
# 11                                                                            2.812408
# 12                                                                            2.668212
# 13                                                                            2.511301
# 14                                                                            2.507841
# 15                                                                            2.481075
# 16                                                                            2.214779
# 17                                                                            2.415848
# 18                                                                            2.584105
# 19                                                                            2.429445
# 20                                                                            2.407643
# 21                                                                            2.064675
# 22                                                                            2.563160
# 23                                                                            2.239380
# 24                                                                            2.419593
# 25                                                                            2.442737
# 26                                                                            2.740215
# 27                                                                            2.652435
# 28                                                                            2.800175
# 29                                                                            2.187359
# 30                                                                            2.208411
# 31                                                                            2.126201
# 32                                                                            2.384912
# 33                                                                            2.481818
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời tiếp cận tin tức trong nước qua Internet (%)  \
# 0                                                                              0.809756
# 1                                                                              0.592026
# 2                                                                              0.667127
# 3                                                                              0.641752
# 4                                                                              0.620148
# 5                                                                              0.688113
# 6                                                                              0.748441
# 7                                                                              0.817108
# 8                                                                              0.605263
# 9                                                                              0.818354
# 10                                                                             0.681096
# 11                                                                             0.760876
# 12                                                                             0.683314
# 13                                                                             0.584621
# 14                                                                             0.610790
# 15                                                                             0.621056
# 16                                                                             0.598612
# 17                                                                             0.663427
# 18                                                                             0.723515
# 19                                                                             0.591567
# 20                                                                             0.622370
# 21                                                                             0.506959
# 22                                                                             0.631530
# 23                                                                             0.564317
# 24                                                                             0.600636
# 25                                                                             0.653391
# 26                                                                             0.740092
# 27                                                                             0.716352
# 28                                                                             0.736181
# 29                                                                             0.502984
# 30                                                                             0.516773
# 31                                                                             0.449130
# 32                                                                             0.599294
# 33                                                                             0.609702
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỷ lệ người trả lời cho biết có kết nối Internet tại nhà (%)  \
# 0                                                                              0.961630
# 1                                                                              0.580871
# 2                                                                              0.707569
# 3                                                                              0.731597
# 4                                                                              0.531802
# 5                                                                              0.718532
# 6                                                                              0.709759
# 7                                                                              0.910664
# 8                                                                              0.782773
# 9                                                                              0.947042
# 10                                                                             0.816734
# 11                                                                             0.910779
# 12                                                                             0.891239
# 13                                                                             0.884269
# 14                                                                             0.855770
# 15                                                                             0.827479
# 16                                                                             0.670599
# 17                                                                             0.741184
# 18                                                                             0.794401
# 19                                                                             0.822200
# 20                                                                             0.776715
# 21                                                                             0.661173
# 22                                                                             0.872282
# 23                                                                             0.721461
# 24                                                                             0.806498
# 25                                                                             0.769327
# 26                                                                             0.882948
# 27                                                                             0.847578
# 28                                                                             0.927236
# 29                                                                             0.747763
# 30                                                                             0.748151
# 31                                                                             0.760433
# 32                                                                             0.784485
# 33                                                                             0.839334
#
# ...
# 0                                                                              0.708495
# 1                                                                              0.553371
# 2                                                                              0.635558
# 3                                                                              0.617914
# 4                                                                              0.426394
# 5                                                                              0.605962
# 6                                                                              0.715403
# 7                                                                              0.718433
# 8                                                                              0.649323
# 9                                                                              0.716405
# 10                                                                             0.657998
# 11                                                                             0.633897
# 12                                                                             0.614363
# 13                                                                             0.643953
# 14                                                                             0.666263
# 15                                                                             0.642437
# 16                                                                             0.695178
# 17                                                                             0.658380
# 18                                                                             0.568511
# 19                                                                             0.732672
# 20                                                                             0.509615
# 21                                                                             0.481912
# 22                                                                             0.636120
# 23                                                                             0.535928
# 24                                                                             0.575117
# 25                                                                             0.525561
# 26                                                                             0.466039
# 27                                                                             0.488611
# 28                                                                             0.467078
# 29                                                                             0.416730
# 30                                                                             0.558704
# 31                                                                             0.455431
# 32                                                                             0.507878
# 33                                                                             0.509261
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã sử dụng cổng dịch vụ công trực tuyến của địa phương (%)  \
# 0                                                                              0.141238
# 1                                                                              0.055113
# 2                                                                              0.111842
# 3                                                                              0.097909
# 4                                                                              0.105953
# 5                                                                              0.148090
# 6                                                                              0.065027
# 7                                                                              0.156004
# 8                                                                              0.076172
# 9                                                                              0.157760
# 10                                                                             0.087460
# 11                                                                             0.073548
# 12                                                                             0.094523
# 13                                                                             0.060940
# 14                                                                             0.046175
# 15                                                                             0.038191
# 16                                                                             0.040394
# 17                                                                             0.087851
# 18                                                                             0.067045
# 19                                                                             0.121161
# 20                                                                             0.066263
# 21                                                                             0.078851
# 22                                                                             0.085960
# 23                                                                             0.063890
# 24                                                                             0.079242
# 25                                                                             0.105896
# 26                                                                             0.152288
# 27                                                                             0.081313
# 28                                                                             0.117665
# 29                                                                             0.047179
# 30                                                                             0.094828
# 31                                                                             0.029056
# 32                                                                             0.086086
# 33                                                                             0.117165
#
# Tỉnh/Thành phố trực thuộc trung ương  Tỉ lệ người trả lời cho biết đã có thể thanh toán trực tuyến trên cổng dịch vụ công của địa phương (%)
# 0                                                                              0.471960
# 1                                                                              0.500000
# 2                                                                              0.312237
# 3                                                                              0.556383
# 4                                                                              0.236565
# 5                                                                              0.336390
# 6                                                                              0.547157
# 7                                                                              0.610030
# 8                                                                              0.521093
# 9                                                                              0.489023
# 10                                                                             0.639867
# 11                                                                             0.452425
# 12                                                                             0.675447
# 13                                                                             0.626322
# 14                                                                             0.701010
# 15                                                                             0.512061
# 16                                                                             0.579619
# 17                                                                             0.911437
# 18                                                                             0.534350
# 19                                                                             0.443239
# 20                                                                             0.791940
# 21                                                                             0.614700
# 22                                                                             0.492479
# 23                                                                             0.816413
# 24                                                                             0.450618
# 25                                                                             0.454270
# 26                                                                             0.381205
# 27                                                                             0.225668
# 28                                                                             0.500791
# 29                                                                             0.573702
# 30                                                                             0.586522
# 31                                                                             0.763015
# 32                                                                             0.415016
# 33                                                                             0.576555
#
# [34 rows x 159 columns]

# %%
from google.colab import files

# Xuất DataFrame ra file CSV với encoding UTF-8 để hiển thị tiếng Việt đúng
file_name = "df_2024.csv"
df.to_csv(file_name, index=False, encoding="utf-8-sig")

# Tải file về máy
files.download(file_name)
