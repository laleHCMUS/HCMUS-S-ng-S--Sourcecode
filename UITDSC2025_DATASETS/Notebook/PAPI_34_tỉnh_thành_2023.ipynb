# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
excel_path = "/content/drive/My Drive/UITDSC2025_DATASETS/2024PAPI_ProvincialIndicators_BangChiTieuCapTinh.xlsx"
dfs = pd.read_excel(excel_path, sheet_name=None)

# %%
# Đọc sheet PAPI 2023, bỏ qua dòng tiêu đề phụ
df_2023_PAPI_VIE_ENG = pd.read_excel(
    excel_path,
    sheet_name="2023_VIE_ENG",
    header=1  # Bỏ dòng đầu, lấy tên tỉnh làm cột
)
df_2023_PAPI_VIE_ENG.head(5)
# Out:
#   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                Unweighted PAPI Score
# 1                Unweighted 95% CI Low
# 2               Unweighted 95% CI High
# 3            Unweighted Standard Error
# 4           Dimension 1: Participation
#
#               Tỉnh/Thành phố trực thuộc trung ương.1         Unnamed: 2  \
# 0           Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3  Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4  Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
#
#       Hà Nội   Hà Giang   Cao Bằng    Bắc Kạn  Tuyên Quang    Lào Cai  \
# 0  43.960304  44.247929  41.655148  43.348305    41.493946  42.107502
# 1  43.700916  42.789047  41.337597  42.581257    41.136345  39.640434
# 2  44.219692  45.706810  41.972698  44.115353    41.851547  44.574570
# 3   0.157685   0.886877   0.193045   0.466301     0.217390   1.499769
# 4   5.427534   5.283103   4.772978   5.448391     4.968036   5.001327
#
#    Điện Biên  ...   Trà Vinh  Vĩnh Long  Đồng Tháp   An Giang  Kiên Giang  \
# 0  42.020432  ...  40.143326  40.823086  41.322628  41.845451   40.989231
# 1  41.638435  ...  39.749874  40.458561  40.915852  41.090034   39.902859
# 2  42.402428  ...  40.536777  41.187611  41.729404  42.600868   42.075603
# 3   0.232222  ...   0.239186   0.221600   0.247287   0.459229    0.660423
# 4   4.696440  ...   3.934829   4.178352   3.924989   4.338145    3.948747
#
#      Cần Thơ  Hậu Giang  Sóc Trăng   Bạc Liêu     Cà Mau
# 0  40.174438  41.069191  45.619614  45.578411  40.105442
# 1  38.339314  40.363041  45.161324  45.030888  39.787140
# 2  42.009563  41.775341  46.077904  46.125935  40.423744
# 3   1.115600   0.429279   0.278603   0.332847   0.193501
# 4   3.864248   4.338764   4.958764   5.021307   3.804902
#
# [5 rows x 66 columns]

# %%
# Đổi tên cột "Unnamed: 2" thành "Thang điểm"
df_2023_PAPI_VIE_ENG.rename(columns={"Unnamed: 2": "Thang điểm"}, inplace=True)

# Xem lại 5 dòng đầu
print(df_2023_PAPI_VIE_ENG.head())
# Out:
#   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                Unweighted PAPI Score
# 1                Unweighted 95% CI Low
# 2               Unweighted 95% CI High
# 3            Unweighted Standard Error
# 4           Dimension 1: Participation
#
#               Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0           Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3  Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4  Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
#
#       Hà Nội   Hà Giang   Cao Bằng    Bắc Kạn  Tuyên Quang    Lào Cai  \
# 0  43.960304  44.247929  41.655148  43.348305    41.493946  42.107502
# 1  43.700916  42.789047  41.337597  42.581257    41.136345  39.640434
# 2  44.219692  45.706810  41.972698  44.115353    41.851547  44.574570
# 3   0.157685   0.886877   0.193045   0.466301     0.217390   1.499769
# 4   5.427534   5.283103   4.772978   5.448391     4.968036   5.001327
#
#    Điện Biên  ...   Trà Vinh  Vĩnh Long  Đồng Tháp   An Giang  Kiên Giang  \
# 0  42.020432  ...  40.143326  40.823086  41.322628  41.845451   40.989231
# 1  41.638435  ...  39.749874  40.458561  40.915852  41.090034   39.902859
# 2  42.402428  ...  40.536777  41.187611  41.729404  42.600868   42.075603
# 3   0.232222  ...   0.239186   0.221600   0.247287   0.459229    0.660423
# 4   4.696440  ...   3.934829   4.178352   3.924989   4.338145    3.948747
#
#      Cần Thơ  Hậu Giang  Sóc Trăng   Bạc Liêu     Cà Mau
# 0  40.174438  41.069191  45.619614  45.578411  40.105442
# 1  38.339314  40.363041  45.161324  45.030888  39.787140
# 2  42.009563  41.775341  46.077904  46.125935  40.423744
# 3   1.115600   0.429279   0.278603   0.332847   0.193501
# 4   3.864248   4.338764   4.958764   5.021307   3.804902
#
# [5 rows x 66 columns]

# %%
df_2023_PAPI_VIE_ENG.head(5)
# Out:
#   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                Unweighted PAPI Score
# 1                Unweighted 95% CI Low
# 2               Unweighted 95% CI High
# 3            Unweighted Standard Error
# 4           Dimension 1: Participation
#
#               Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0           Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3  Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4  Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
#
#       Hà Nội   Hà Giang   Cao Bằng    Bắc Kạn  Tuyên Quang    Lào Cai  \
# 0  43.960304  44.247929  41.655148  43.348305    41.493946  42.107502
# 1  43.700916  42.789047  41.337597  42.581257    41.136345  39.640434
# 2  44.219692  45.706810  41.972698  44.115353    41.851547  44.574570
# 3   0.157685   0.886877   0.193045   0.466301     0.217390   1.499769
# 4   5.427534   5.283103   4.772978   5.448391     4.968036   5.001327
#
#    Điện Biên  ...   Trà Vinh  Vĩnh Long  Đồng Tháp   An Giang  Kiên Giang  \
# 0  42.020432  ...  40.143326  40.823086  41.322628  41.845451   40.989231
# 1  41.638435  ...  39.749874  40.458561  40.915852  41.090034   39.902859
# 2  42.402428  ...  40.536777  41.187611  41.729404  42.600868   42.075603
# 3   0.232222  ...   0.239186   0.221600   0.247287   0.459229    0.660423
# 4   4.696440  ...   3.934829   4.178352   3.924989   4.338145    3.948747
#
#      Cần Thơ  Hậu Giang  Sóc Trăng   Bạc Liêu     Cà Mau
# 0  40.174438  41.069191  45.619614  45.578411  40.105442
# 1  38.339314  40.363041  45.161324  45.030888  39.787140
# 2  42.009563  41.775341  46.077904  46.125935  40.423744
# 3   1.115600   0.429279   0.278603   0.332847   0.193501
# 4   3.864248   4.338764   4.958764   5.021307   3.804902
#
# [5 rows x 66 columns]

# %%
df_2023_PAPI_VIE_ENG.rename(columns={"Hà Giang": "Tuyên Quang 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Yên Bái": "Lào Cai 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bắc Kạn": "Thái Nguyên 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Vĩnh Phúc": "Phú Thọ 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Hòa Bình": "Phú Thọ 2"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bắc Giang": "Bắc Ninh 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Thái Bình": "Hưng Yên 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Hải Dương": "Hải Phòng 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Nam Định": "Ninh Bình 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Hà Nam": "Ninh Bình 2"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Quảng Bình": "Quảng Trị 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Quảng Nam": "Đà Nẵng 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Kon Tum": "Quảng Ngãi 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bình Định": "Gia Lai 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Ninh Thuận": "Khánh Hòa 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bình Thuận": "Lâm Đồng 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Đắk Nông": "Lâm Đồng 2"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Phú Yên": "Đắk Lắk 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bình Dương": "TP. Hồ Chí Minh 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bà Rịa-Vũng Tàu": "TP. Hồ Chí Minh 2"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bình Phước": "Đồng Nai 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Long An": "Tây Ninh 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Sóc Trăng": "Cần Thơ 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Hậu Giang": "Cần Thơ 2"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bến Tre": "Vĩnh Long 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Trà Vinh": "Vĩnh Long 2"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Tiền Giang": "Đồng Tháp 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Bạc Liêu": "Cà Mau 1"}, inplace=True)
df_2023_PAPI_VIE_ENG.rename(columns={"Kiên Giang": "An Giang 1"}, inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 160                                       Observations
# 161  Note: Provinces without data in indicators mea...
# 162  Copyright @CECODES, VFF-CRT, RTA and UNDP (202...
# 163                                                NaN
# 164  * Các tiêu chí giữ nguyên kết quả của năm 2021...
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
# 161  Ghi chú: Các tỉnh có ô dữ liệu trống là do mẫu...                NaN
# 162  Bản quyền @CECODES, RTA and UNDP (2024). WWW.P...                NaN
# 163                                                NaN                NaN
# 164                                                NaN                NaN
#
#           Hà Nội  Tuyên Quang 1    Cao Bằng  Thái Nguyên 1  Tuyên Quang  \
# 0      43.960304      44.247929   41.655148      43.348305    41.493946
# 1      43.700916      42.789047   41.337597      42.581257    41.136345
# 2      44.219692      45.706810   41.972698      44.115353    41.851547
# 3       0.157685       0.886877    0.193045       0.466301     0.217390
# 4       5.427534       5.283103    4.772978       5.448391     4.968036
# ..           ...            ...         ...            ...          ...
# 160  1120.000000     248.000000  248.000000     251.000000   256.000000
# 161          NaN            NaN         NaN            NaN          NaN
# 162          NaN            NaN         NaN            NaN          NaN
# 163          NaN            NaN         NaN            NaN          NaN
# 164          NaN            NaN         NaN            NaN          NaN
#
#         Lào Cai   Điện Biên  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp  \
# 0     42.107502   42.020432  ...    40.143326   40.823086   41.322628
# 1     39.640434   41.638435  ...    39.749874   40.458561   40.915852
# 2     44.574570   42.402428  ...    40.536777   41.187611   41.729404
# 3      1.499769    0.232222  ...     0.239186    0.221600    0.247287
# 4      5.001327    4.696440  ...     3.934829    4.178352    3.924989
# ..          ...         ...  ...          ...         ...         ...
# 160  254.000000  248.000000  ...   255.000000  250.000000  250.000000
# 161         NaN         NaN  ...          NaN         NaN         NaN
# 162         NaN         NaN  ...          NaN         NaN         NaN
# 163         NaN         NaN  ...          NaN         NaN         NaN
# 164         NaN         NaN  ...          NaN         NaN         NaN
#
#        An Giang  An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1  \
# 0     41.845451   40.989231   40.174438   41.069191   45.619614   45.578411
# 1     41.090034   39.902859   38.339314   40.363041   45.161324   45.030888
# 2     42.600868   42.075603   42.009563   41.775341   46.077904   46.125935
# 3      0.459229    0.660423    1.115600    0.429279    0.278603    0.332847
# 4      4.338145    3.948747    3.864248    4.338764    4.958764    5.021307
# ..          ...         ...         ...         ...         ...         ...
# 160  491.000000  246.000000  371.000000  255.000000  247.000000  246.000000
# 161         NaN         NaN         NaN         NaN         NaN         NaN
# 162         NaN         NaN         NaN         NaN         NaN         NaN
# 163         NaN         NaN         NaN         NaN         NaN         NaN
# 164         NaN         NaN         NaN         NaN         NaN         NaN
#
#          Cà Mau
# 0     40.105442
# 1     39.787140
# 2     40.423744
# 3      0.193501
# 4      3.804902
# ..          ...
# 160  246.000000
# 161         NaN
# 162         NaN
# 163         NaN
# 164         NaN
#
# [165 rows x 66 columns]

# %%
# Lấy dữ liệu đến dòng 160 (bỏ các dòng Note, Copyright)
df_2023_PAPI_VIE_ENG = df_2023_PAPI_VIE_ENG.iloc[:161, :]

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội  Tuyên Quang 1    Cao Bằng  Thái Nguyên 1  Tuyên Quang  \
# 0      43.960304      44.247929   41.655148      43.348305    41.493946
# 1      43.700916      42.789047   41.337597      42.581257    41.136345
# 2      44.219692      45.706810   41.972698      44.115353    41.851547
# 3       0.157685       0.886877    0.193045       0.466301     0.217390
# 4       5.427534       5.283103    4.772978       5.448391     4.968036
# ..           ...            ...         ...            ...          ...
# 156     0.341589       0.262792    0.282083       0.285950     0.270725
# 157     0.619799       0.640916    0.502874       0.657151     0.490069
# 158     0.131653       0.165162    0.050837       0.087987     0.044473
# 159     0.295258       0.476013    0.150194       0.179546     1.000000
# 160  1120.000000     248.000000  248.000000     251.000000   256.000000
#
#         Lào Cai   Điện Biên  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp  \
# 0     42.107502   42.020432  ...    40.143326   40.823086   41.322628
# 1     39.640434   41.638435  ...    39.749874   40.458561   40.915852
# 2     44.574570   42.402428  ...    40.536777   41.187611   41.729404
# 3      1.499769    0.232222  ...     0.239186    0.221600    0.247287
# 4      5.001327    4.696440  ...     3.934829    4.178352    3.924989
# ..          ...         ...  ...          ...         ...         ...
# 156    0.239399    0.290189  ...     0.235352    0.285029    0.238577
# 157    0.632553    0.599581  ...     0.416123    0.399126    0.553394
# 158    0.099778    0.089363  ...     0.035474    0.077305    0.062164
# 159    0.538190    0.140513  ...     0.000000    0.536965    0.236152
# 160  254.000000  248.000000  ...   255.000000  250.000000  250.000000
#
#        An Giang  An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1  \
# 0     41.845451   40.989231   40.174438   41.069191   45.619614   45.578411
# 1     41.090034   39.902859   38.339314   40.363041   45.161324   45.030888
# 2     42.600868   42.075603   42.009563   41.775341   46.077904   46.125935
# 3      0.459229    0.660423    1.115600    0.429279    0.278603    0.332847
# 4      4.338145    3.948747    3.864248    4.338764    4.958764    5.021307
# ..          ...         ...         ...         ...         ...         ...
# 156    0.140221    0.241908    0.189155    0.247089    0.308778    0.324232
# 157    0.393954    0.441836    0.545319    0.537096    0.651170    0.703507
# 158    0.029921    0.036087    0.060014    0.047824    0.107128    0.116432
# 159    0.697692    0.441678    0.231057    0.000000    0.500000    0.164164
# 160  491.000000  246.000000  371.000000  255.000000  247.000000  246.000000
#
#          Cà Mau
# 0     40.105442
# 1     39.787140
# 2     40.423744
# 3      0.193501
# 4      3.804902
# ..          ...
# 156    0.206163
# 157    0.532134
# 158    0.078543
# 159    0.436157
# 160  246.000000
#
# [161 rows x 66 columns]

# %%
# Đếm số ô NaN theo cột
missing_per_column = df_2023_PAPI_VIE_ENG.isna().sum()

# In ra các cột có ít nhất 1 giá trị trống
missing_columns = missing_per_column[missing_per_column > 0]
print(missing_columns)
# Out:
# Thang điểm             4
# Quảng Ninh           161
# TP. Hồ Chí Minh 1    161
# Cần Thơ 1              2
# Cà Mau 1               4
# Cà Mau                 4
# dtype: int64

# %%
excel_path_1 = "/content/drive/My Drive/UITDSC2025_DATASETS/danso_VN.xlsx"
danso = pd.read_excel(excel_path_1, sheet_name=None)

# %%
danso
# Out:
# {'Sheet1':              Unnamed: 0     2019     2020     2021     2022     2023     2024  \
#  0   Đồng bằng sông Hồng  22620.2  22920.2  23224.8  23454.2  23732.4  24016.0
#  1                Hà Nội   8093.9   8246.5   8330.8   8435.7   8587.1   8717.6
#  2             Vĩnh Phúc   1154.8   1171.2   1191.8   1197.6   1211.3   1225.3
#  3              Bắc Ninh   1378.6   1419.1   1462.9   1488.2   1517.4   1546.6
#  4            Quảng Ninh   1324.8   1337.6   1350.9   1362.9   1381.2   1396.5
#  ..                  ...      ...      ...      ...      ...      ...      ...
#  64              Cần Thơ   1236.0   1240.7   1247.0   1252.3   1258.9   1271.7
#  65            Hậu Giang    732.2    729.8    729.9    729.5    728.3    730.0
#  66            Sóc Trăng   1199.5   1195.7   1206.8   1197.8   1198.8   1205.3
#  67             Bạc Liêu    908.2    913.5    918.5    921.8    925.2    928.7
#  68               Cà Mau   1194.3   1193.9   1208.8   1207.6   1207.4   1212.0
#
#      2019 (làm tròn)  2020 (làm tròn)  2021 (làm tròn)  2022(làm tròn)  \
#  0              22.6             22.9             23.2            23.5
#  1               8.1              8.2              8.3             8.4
#  2               1.2              1.2              1.2             1.2
#  3               1.4              1.4              1.5             1.5
#  4               1.3              1.3              1.4             1.4
#  ..              ...              ...              ...             ...
#  64              1.2              1.2              1.2             1.3
#  65              0.7              0.7              0.7             0.7
#  66              1.2              1.2              1.2             1.2
#  67              0.9              0.9              0.9             0.9
#  68              1.2              1.2              1.2             1.2
#
#      2023 (làm tròn)  2024 (làm tròn)  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
#  0              23.7             24.0          NaN       22.620       22.920
#  1               8.6              8.7          NaN        8.094        8.247
#  2               1.2              1.2          NaN        1.155        1.171
#  3               1.5              1.5          NaN        1.379        1.419
#  4               1.4              1.4          NaN        1.325        1.338
#  ..              ...              ...          ...          ...          ...
#  64              1.3              1.3          NaN        1.236        1.241
#  65              0.7              0.7          NaN        0.732        0.730
#  66              1.2              1.2          NaN        1.200        1.196
#  67              0.9              0.9          NaN        0.908        0.914
#  68              1.2              1.2          NaN        1.194        1.194
#
#      Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19
#  0        23.225       23.454       23.732       24.016
#  1         8.331        8.436        8.587        8.718
#  2         1.192        1.198        1.211        1.225
#  3         1.463        1.488        1.517        1.547
#  4         1.351        1.363        1.381        1.397
#  ..          ...          ...          ...          ...
#  64        1.247        1.252        1.259        1.272
#  65        0.730        0.730        0.728        0.730
#  66        1.207        1.198        1.199        1.205
#  67        0.919        0.922        0.925        0.929
#  68        1.209        1.208        1.207        1.212
#
#  [69 rows x 20 columns]}

# %%
# Truy cập vào sheet "Sheet1"
df_danso = danso["Sheet1"]

# Lấy 2 cột: Tên tỉnh và dân số 2023 (làm tròn)
df_danso = df_danso[["Unnamed: 0", "2023 (làm tròn)"]]

# Đổi tên cột cho dễ dùng
df_danso = df_danso.rename(columns={"Unnamed: 0": "Tỉnh"})

# Chuyển thành dict để tra cứu nhanh
danso_dict = dict(zip(df_danso["Tỉnh"], df_danso["2023 (làm tròn)"]))

# %%
danso_dict
# Out:
# {'Đồng bằng sông Hồng': 23.7,
#  'Hà Nội': 8.6,
#  'Vĩnh Phúc': 1.2,
#  'Bắc Ninh': 1.5,
#  'Quảng Ninh': 1.4,
#  'Hải Dương': 2.0,
#  'Hải Phòng': 2.1,
#  'Hưng Yên': 1.3,
#  'Thái Bình': 1.9,
#  'Hà Nam': 0.9,
#  'Nam Định': 1.9,
#  'Ninh Bình': 1.0,
#  'Trung du và miền núi phía Bắc': 13.2,
#  'Hà Giang': 0.9,
#  'Cao Bằng': 0.5,
#  'Bắc Kạn': 0.3,
#  'Tuyên Quang': 0.8,
#  'Lào Cai': 0.8,
#  'Yên Bái': 0.9,
#  'Thái Nguyên': 1.4,
#  'Lạng Sơn': 0.8,
#  'Bắc Giang': 1.9,
#  'Phú Thọ': 1.5,
#  'Điện Biên': 0.6,
#  'Lai Châu': 0.5,
#  'Sơn La': 1.3,
#  'Hòa Bình': 0.9,
#  'Bắc Trung Bộ và Duyên hải miền Trung': 20.8,
#  'Thanh Hoá': 3.7,
#  'Nghệ An': 3.4,
#  'Hà Tĩnh': 1.3,
#  'Quảng Bình': 0.9,
#  'Quảng Trị': 0.7,
#  'Thừa Thiên Huế': 1.2,
#  'Đà Nẵng': 1.2,
#  'Quảng Nam': 1.5,
#  'Quảng Ngãi': 1.2,
#  'Bình Định': 1.5,
#  'Phú Yên': 0.9,
#  'Khánh Hòa': 1.3,
#  'Ninh Thuận': 0.6,
#  'Bình Thuận': 1.3,
#  'Tây Nguyên': 6.2,
#  'Kon Tum': 0.6,
#  'Gia Lai': 1.6,
#  'Đắk Lắk': 1.9,
#  'Đắk Nông': 0.7,
#  'Lâm Đồng': 1.3,
#  'Đông Nam Bộ': 19.0,
#  'Bình Phước': 1.0,
#  'Tây Ninh': 1.2,
#  'Bình Dương': 2.8,
#  'Đồng Nai': 3.3,
#  'Bà Rịa-Vũng Tàu': 1.2,
#  'TP. Hồ Chí Minh': 9.5,
#  'Đồng bằng sông Cửu Long': 17.5,
#  'Long An': 1.7,
#  'Tiền Giang': 1.8,
#  'Bến Tre': 1.3,
#  'Trà Vinh': 1.0,
#  'Vĩnh Long': 1.0,
#  'Đồng Tháp': 1.6,
#  'An Giang': 1.9,
#  'Kiên Giang': 1.8,
#  'Cần Thơ': 1.3,
#  'Hậu Giang': 0.7,
#  'Sóc Trăng': 1.2,
#  'Bạc Liêu': 0.9,
#  'Cà Mau': 1.2}

# %%
# Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Tuyên Quang"] *= danso_dict["Tuyên Quang"]
df_2023_PAPI_VIE_ENG["Tuyên Quang 1"] *= danso_dict["Hà Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Tuyên Quang"
df_2023_PAPI_VIE_ENG["Tuyên Quang"] = (
    df_2023_PAPI_VIE_ENG["Tuyên Quang"] + df_2023_PAPI_VIE_ENG["Tuyên Quang 1"]
) / (danso_dict["Tuyên Quang"] + danso_dict["Hà Giang"])

# Bước 3: Xóa cột "Tuyên Quang 1"
df_2023_PAPI_VIE_ENG.drop(columns=["Tuyên Quang 1"], inplace=True)
# Out:
# /tmp/ipython-input-2996471987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Tuyên Quang"] *= danso_dict["Tuyên Quang"]
# /tmp/ipython-input-2996471987.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Tuyên Quang 1"] *= danso_dict["Hà Giang"]
# /tmp/ipython-input-2996471987.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Tuyên Quang"] = (
# /tmp/ipython-input-2996471987.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Tuyên Quang 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Thái Nguyên 1  Tuyên Quang     Lào Cai  \
# 0      43.960304   41.655148      43.348305    42.951937   42.107502
# 1      43.700916   41.337597      42.581257    42.011305   39.640434
# 2      44.219692   41.972698      44.115353    43.892569   44.574570
# 3       0.157685    0.193045       0.466301     0.571825    1.499769
# 4       5.427534    4.772978       5.448391     5.134837    5.001327
# ..           ...         ...            ...          ...         ...
# 156     0.341589    0.282083       0.285950     0.266525    0.239399
# 157     0.619799    0.502874       0.657151     0.569929    0.632553
# 158     0.131653    0.050837       0.087987     0.108368    0.099778
# 159     0.295258    0.150194       0.179546     0.722595    0.538190
# 160  1120.000000  248.000000     251.000000   251.764706  254.000000
#
#       Điện Biên    Lai Châu  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp  \
# 0     42.020432   43.622257  ...    40.143326   40.823086   41.322628
# 1     41.638435   42.995277  ...    39.749874   40.458561   40.915852
# 2     42.402428   44.249237  ...    40.536777   41.187611   41.729404
# 3      0.232222    0.381152  ...     0.239186    0.221600    0.247287
# 4      4.696440    4.966353  ...     3.934829    4.178352    3.924989
# ..          ...         ...  ...          ...         ...         ...
# 156    0.290189    0.410376  ...     0.235352    0.285029    0.238577
# 157    0.599581    0.546348  ...     0.416123    0.399126    0.553394
# 158    0.089363    0.134379  ...     0.035474    0.077305    0.062164
# 159    0.140513    0.233626  ...     0.000000    0.536965    0.236152
# 160  248.000000  246.000000  ...   255.000000  250.000000  250.000000
#
#        An Giang  An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1  \
# 0     41.845451   40.989231   40.174438   41.069191   45.619614   45.578411
# 1     41.090034   39.902859   38.339314   40.363041   45.161324   45.030888
# 2     42.600868   42.075603   42.009563   41.775341   46.077904   46.125935
# 3      0.459229    0.660423    1.115600    0.429279    0.278603    0.332847
# 4      4.338145    3.948747    3.864248    4.338764    4.958764    5.021307
# ..          ...         ...         ...         ...         ...         ...
# 156    0.140221    0.241908    0.189155    0.247089    0.308778    0.324232
# 157    0.393954    0.441836    0.545319    0.537096    0.651170    0.703507
# 158    0.029921    0.036087    0.060014    0.047824    0.107128    0.116432
# 159    0.697692    0.441678    0.231057    0.000000    0.500000    0.164164
# 160  491.000000  246.000000  371.000000  255.000000  247.000000  246.000000
#
#          Cà Mau
# 0     40.105442
# 1     39.787140
# 2     40.423744
# 3      0.193501
# 4      3.804902
# ..          ...
# 156    0.206163
# 157    0.532134
# 158    0.078543
# 159    0.436157
# 160  246.000000
#
# [161 rows x 65 columns]

# %%
# Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Lào Cai"] *= danso_dict["Lào Cai"]
df_2023_PAPI_VIE_ENG["Lào Cai 1"] *= danso_dict["Yên Bái"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Lào Cai"
df_2023_PAPI_VIE_ENG["Lào Cai"] = (
    df_2023_PAPI_VIE_ENG["Lào Cai"] + df_2023_PAPI_VIE_ENG["Lào Cai 1"]
) / (danso_dict["Lào Cai"] + danso_dict["Yên Bái"])

# Bước 3: Xóa cột "Lào Cai 1"
df_2023_PAPI_VIE_ENG.drop(columns=["Lào Cai 1"], inplace=True)
# Out:
# /tmp/ipython-input-4242406621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Lào Cai"] *= danso_dict["Lào Cai"]
# /tmp/ipython-input-4242406621.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Lào Cai 1"] *= danso_dict["Yên Bái"]
# /tmp/ipython-input-4242406621.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Lào Cai"] = (
# /tmp/ipython-input-4242406621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Lào Cai 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Thái Nguyên 1  Tuyên Quang     Lào Cai  \
# 0      43.960304   41.655148      43.348305    42.951937   42.310404
# 1      43.700916   41.337597      42.581257    42.011305   39.987069
# 2      44.219692   41.972698      44.115353    43.892569   44.633738
# 3       0.157685    0.193045       0.466301     0.571825    1.412391
# 4       5.427534    4.772978       5.448391     5.134837    4.860209
# ..           ...         ...            ...          ...         ...
# 156     0.341589    0.282083       0.285950     0.266525    0.257751
# 157     0.619799    0.502874       0.657151     0.569929    0.649242
# 158     0.131653    0.050837       0.087987     0.108368    0.111449
# 159     0.295258    0.150194       0.179546     0.722595    0.575438
# 160  1120.000000  248.000000     251.000000   251.764706  249.764706
#
#       Điện Biên    Lai Châu  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp  \
# 0     42.020432   43.622257  ...    40.143326   40.823086   41.322628
# 1     41.638435   42.995277  ...    39.749874   40.458561   40.915852
# 2     42.402428   44.249237  ...    40.536777   41.187611   41.729404
# 3      0.232222    0.381152  ...     0.239186    0.221600    0.247287
# 4      4.696440    4.966353  ...     3.934829    4.178352    3.924989
# ..          ...         ...  ...          ...         ...         ...
# 156    0.290189    0.410376  ...     0.235352    0.285029    0.238577
# 157    0.599581    0.546348  ...     0.416123    0.399126    0.553394
# 158    0.089363    0.134379  ...     0.035474    0.077305    0.062164
# 159    0.140513    0.233626  ...     0.000000    0.536965    0.236152
# 160  248.000000  246.000000  ...   255.000000  250.000000  250.000000
#
#        An Giang  An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1  \
# 0     41.845451   40.989231   40.174438   41.069191   45.619614   45.578411
# 1     41.090034   39.902859   38.339314   40.363041   45.161324   45.030888
# 2     42.600868   42.075603   42.009563   41.775341   46.077904   46.125935
# 3      0.459229    0.660423    1.115600    0.429279    0.278603    0.332847
# 4      4.338145    3.948747    3.864248    4.338764    4.958764    5.021307
# ..          ...         ...         ...         ...         ...         ...
# 156    0.140221    0.241908    0.189155    0.247089    0.308778    0.324232
# 157    0.393954    0.441836    0.545319    0.537096    0.651170    0.703507
# 158    0.029921    0.036087    0.060014    0.047824    0.107128    0.116432
# 159    0.697692    0.441678    0.231057    0.000000    0.500000    0.164164
# 160  491.000000  246.000000  371.000000  255.000000  247.000000  246.000000
#
#          Cà Mau
# 0     40.105442
# 1     39.787140
# 2     40.423744
# 3      0.193501
# 4      3.804902
# ..          ...
# 156    0.206163
# 157    0.532134
# 158    0.078543
# 159    0.436157
# 160  246.000000
#
# [161 rows x 64 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Thái Nguyên"] *= danso_dict["Thái Nguyên"]
df_2023_PAPI_VIE_ENG["Thái Nguyên 1"] *= danso_dict["Bắc Kạn"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Thái Nguyên"
df_2023_PAPI_VIE_ENG["Thái Nguyên"] = (
    df_2023_PAPI_VIE_ENG["Thái Nguyên"] + df_2023_PAPI_VIE_ENG["Thái Nguyên 1"]
) / (danso_dict["Thái Nguyên"] + danso_dict["Bắc Kạn"])

# Bước 3: Xóa cột "Thái Nguyên 1" (Bắc Kạn)
df_2023_PAPI_VIE_ENG.drop(columns=["Thái Nguyên 1"], inplace=True)
# Out:
# /tmp/ipython-input-2660180139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Thái Nguyên"] *= danso_dict["Thái Nguyên"]
# /tmp/ipython-input-2660180139.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Thái Nguyên 1"] *= danso_dict["Bắc Kạn"]
# /tmp/ipython-input-2660180139.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Thái Nguyên"] = (
# /tmp/ipython-input-2660180139.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Thái Nguyên 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 63 columns]

# %%
### Bước 1: Nhân dân số cho 3 cột
df_2023_PAPI_VIE_ENG["Phú Thọ"] *= danso_dict["Phú Thọ"]
df_2023_PAPI_VIE_ENG["Phú Thọ 1"] *= danso_dict["Vĩnh Phúc"]
df_2023_PAPI_VIE_ENG["Phú Thọ 2"] *= danso_dict["Hòa Bình"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Phú Thọ"
df_2023_PAPI_VIE_ENG["Phú Thọ"] = (
    df_2023_PAPI_VIE_ENG["Phú Thọ"] + df_2023_PAPI_VIE_ENG["Phú Thọ 1"] + df_2023_PAPI_VIE_ENG["Phú Thọ 2"]
) / (danso_dict["Phú Thọ"] + danso_dict["Vĩnh Phúc"] + danso_dict["Hòa Bình"])

# Bước 3: Xóa cột "Phú Thọ 1" (Vĩnh Phúc) và "Phú Thọ 2" (Hòa Bình)
df_2023_PAPI_VIE_ENG.drop(columns=["Phú Thọ 1"], inplace=True)
df_2023_PAPI_VIE_ENG.drop(columns=["Phú Thọ 2"], inplace=True)
# Out:
# /tmp/ipython-input-3697247225.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Phú Thọ"] *= danso_dict["Phú Thọ"]
# /tmp/ipython-input-3697247225.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Phú Thọ 1"] *= danso_dict["Vĩnh Phúc"]
# /tmp/ipython-input-3697247225.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Phú Thọ 2"] *= danso_dict["Hòa Bình"]
# /tmp/ipython-input-3697247225.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Phú Thọ"] = (
# /tmp/ipython-input-3697247225.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Phú Thọ 1"], inplace=True)
# /tmp/ipython-input-3697247225.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Phú Thọ 2"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 61 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Bắc Ninh"] *= danso_dict["Bắc Ninh"]
df_2023_PAPI_VIE_ENG["Bắc Ninh 1"] *= danso_dict["Bắc Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Bắc Ninh"
df_2023_PAPI_VIE_ENG["Bắc Ninh"] = (
    df_2023_PAPI_VIE_ENG["Bắc Ninh"] + df_2023_PAPI_VIE_ENG["Bắc Ninh 1"]
) / (danso_dict["Bắc Ninh"] + danso_dict["Bắc Giang"])

# Bước 3: Xóa cột "Bắc Ninh 1" (Bắc Giang)
df_2023_PAPI_VIE_ENG.drop(columns=["Bắc Ninh 1"], inplace=True)
# Out:
# /tmp/ipython-input-3069236553.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Bắc Ninh"] *= danso_dict["Bắc Ninh"]
# /tmp/ipython-input-3069236553.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Bắc Ninh 1"] *= danso_dict["Bắc Giang"]
# /tmp/ipython-input-3069236553.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Bắc Ninh"] = (
# /tmp/ipython-input-3069236553.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Bắc Ninh 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 60 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Hưng Yên"] *= danso_dict["Hưng Yên"]
df_2023_PAPI_VIE_ENG["Hưng Yên 1"] *= danso_dict["Thái Bình"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Hưng Yên"
df_2023_PAPI_VIE_ENG["Hưng Yên"] = (
    df_2023_PAPI_VIE_ENG["Hưng Yên"] + df_2023_PAPI_VIE_ENG["Hưng Yên 1"]
) / (danso_dict["Hưng Yên"] + danso_dict["Thái Bình"])

# Bước 3: Xóa cột "Hưng Yên 1" (Thái Bình)
df_2023_PAPI_VIE_ENG.drop(columns=["Hưng Yên 1"], inplace=True)
# Out:
# /tmp/ipython-input-3998923785.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Hưng Yên"] *= danso_dict["Hưng Yên"]
# /tmp/ipython-input-3998923785.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Hưng Yên 1"] *= danso_dict["Thái Bình"]
# /tmp/ipython-input-3998923785.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Hưng Yên"] = (
# /tmp/ipython-input-3998923785.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Hưng Yên 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 59 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Hải Phòng"] *= danso_dict["Hải Phòng"]
df_2023_PAPI_VIE_ENG["Hải Phòng 1"] *= danso_dict["Hải Dương"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Hải Phòng"
df_2023_PAPI_VIE_ENG["Hải Phòng"] = (
    df_2023_PAPI_VIE_ENG["Hải Phòng"] + df_2023_PAPI_VIE_ENG["Hải Phòng 1"]
) / (danso_dict["Hải Phòng"] + danso_dict["Hải Dương"])

# Bước 3: Xóa cột "Hải Phòng 1" (Hải Dương)
df_2023_PAPI_VIE_ENG.drop(columns=["Hải Phòng 1"], inplace=True)
# Out:
# /tmp/ipython-input-3593336772.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Hải Phòng"] *= danso_dict["Hải Phòng"]
# /tmp/ipython-input-3593336772.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Hải Phòng 1"] *= danso_dict["Hải Dương"]
# /tmp/ipython-input-3593336772.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Hải Phòng"] = (
# /tmp/ipython-input-3593336772.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Hải Phòng 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 58 columns]

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2023_PAPI_VIE_ENG["Ninh Bình"] *= danso_dict["Ninh Bình"]
df_2023_PAPI_VIE_ENG["Ninh Bình 1"] *= danso_dict["Nam Định"]
df_2023_PAPI_VIE_ENG["Ninh Bình 2"] *= danso_dict["Hà Nam"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Ninh Bình"
df_2023_PAPI_VIE_ENG["Ninh Bình"] = (
    df_2023_PAPI_VIE_ENG["Ninh Bình"] + df_2023_PAPI_VIE_ENG["Ninh Bình 1"] + df_2023_PAPI_VIE_ENG["Ninh Bình 2"]
) / (danso_dict["Ninh Bình"] + danso_dict["Nam Định"] + danso_dict["Hà Nam"])

# Bước 3: Xóa cột "Ninh Bình 1" (Nam Định) và "Ninh Bình 2" (Hà Nam)
df_2023_PAPI_VIE_ENG.drop(columns=["Ninh Bình 1"], inplace=True)
df_2023_PAPI_VIE_ENG.drop(columns=["Ninh Bình 2"], inplace=True)
# Out:
# /tmp/ipython-input-3921234592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Ninh Bình"] *= danso_dict["Ninh Bình"]
# /tmp/ipython-input-3921234592.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Ninh Bình 1"] *= danso_dict["Nam Định"]
# /tmp/ipython-input-3921234592.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Ninh Bình 2"] *= danso_dict["Hà Nam"]
# /tmp/ipython-input-3921234592.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Ninh Bình"] = (
# /tmp/ipython-input-3921234592.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Ninh Bình 1"], inplace=True)
# /tmp/ipython-input-3921234592.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Ninh Bình 2"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 56 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Quảng Trị"] *= danso_dict["Quảng Trị"]
df_2023_PAPI_VIE_ENG["Quảng Trị 1"] *= danso_dict["Quảng Bình"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Quảng Trị"
df_2023_PAPI_VIE_ENG["Quảng Trị"] = (
    df_2023_PAPI_VIE_ENG["Quảng Trị"] + df_2023_PAPI_VIE_ENG["Quảng Trị 1"]
) / (danso_dict["Quảng Trị"] + danso_dict["Quảng Bình"])

# Bước 3: Xóa cột "Quảng Trị 1" (Quảng Bình)
df_2023_PAPI_VIE_ENG.drop(columns=["Quảng Trị 1"], inplace=True)
# Out:
# /tmp/ipython-input-1513348425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Quảng Trị"] *= danso_dict["Quảng Trị"]
# /tmp/ipython-input-1513348425.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Quảng Trị 1"] *= danso_dict["Quảng Bình"]
# /tmp/ipython-input-1513348425.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Quảng Trị"] = (
# /tmp/ipython-input-1513348425.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Quảng Trị 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 55 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Đà Nẵng"] *= danso_dict["Đà Nẵng"]
df_2023_PAPI_VIE_ENG["Đà Nẵng 1"] *= danso_dict["Quảng Nam"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Đà Nẵng"
df_2023_PAPI_VIE_ENG["Đà Nẵng"] = (
    df_2023_PAPI_VIE_ENG["Đà Nẵng"] + df_2023_PAPI_VIE_ENG["Đà Nẵng 1"]
) / (danso_dict["Đà Nẵng"] + danso_dict["Quảng Nam"])

# Bước 3: Xóa cột "Đà Nẵng 1" (Quảng Nam)
df_2023_PAPI_VIE_ENG.drop(columns=["Đà Nẵng 1"], inplace=True)
# Out:
# /tmp/ipython-input-1198605269.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đà Nẵng"] *= danso_dict["Đà Nẵng"]
# /tmp/ipython-input-1198605269.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đà Nẵng 1"] *= danso_dict["Quảng Nam"]
# /tmp/ipython-input-1198605269.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đà Nẵng"] = (
# /tmp/ipython-input-1198605269.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Đà Nẵng 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 54 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Quảng Ngãi"] *= danso_dict["Quảng Ngãi"]
df_2023_PAPI_VIE_ENG["Quảng Ngãi 1"] *= danso_dict["Kon Tum"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Quảng Ngãi"
df_2023_PAPI_VIE_ENG["Quảng Ngãi"] = (
    df_2023_PAPI_VIE_ENG["Quảng Ngãi"] + df_2023_PAPI_VIE_ENG["Quảng Ngãi 1"]
) / (danso_dict["Quảng Ngãi"] + danso_dict["Kon Tum"])

# Bước 3: Xóa cột "Quảng Ngãi 1" (Kon Tum)
df_2023_PAPI_VIE_ENG.drop(columns=["Quảng Ngãi 1"], inplace=True)
# Out:
# /tmp/ipython-input-2693502636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Quảng Ngãi"] *= danso_dict["Quảng Ngãi"]
# /tmp/ipython-input-2693502636.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Quảng Ngãi 1"] *= danso_dict["Kon Tum"]
# /tmp/ipython-input-2693502636.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Quảng Ngãi"] = (
# /tmp/ipython-input-2693502636.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Quảng Ngãi 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 53 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Gia Lai"] *= danso_dict["Gia Lai"]
df_2023_PAPI_VIE_ENG["Gia Lai 1"] *= danso_dict["Bình Định"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Gia Lai"
df_2023_PAPI_VIE_ENG["Gia Lai"] = (
    df_2023_PAPI_VIE_ENG["Gia Lai"] + df_2023_PAPI_VIE_ENG["Gia Lai 1"]
) / (danso_dict["Gia Lai"] + danso_dict["Bình Định"])

# Bước 3: Xóa cột "Gia Lai 1" (Kon Tum)
df_2023_PAPI_VIE_ENG.drop(columns=["Gia Lai 1"], inplace=True)
# Out:
# /tmp/ipython-input-665236655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Gia Lai"] *= danso_dict["Gia Lai"]
# /tmp/ipython-input-665236655.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Gia Lai 1"] *= danso_dict["Bình Định"]
# /tmp/ipython-input-665236655.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Gia Lai"] = (
# /tmp/ipython-input-665236655.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Gia Lai 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 52 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Khánh Hòa"] *= danso_dict["Khánh Hòa"]
df_2023_PAPI_VIE_ENG["Khánh Hòa 1"] *= danso_dict["Ninh Thuận"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Khánh Hòa"
df_2023_PAPI_VIE_ENG["Khánh Hòa"] = (
    df_2023_PAPI_VIE_ENG["Khánh Hòa"] + df_2023_PAPI_VIE_ENG["Khánh Hòa 1"]
) / (danso_dict["Khánh Hòa"] + danso_dict["Ninh Thuận"])

# Bước 3: Xóa cột "Khánh Hòa 1" (Ninh Thuận)
df_2023_PAPI_VIE_ENG.drop(columns=["Khánh Hòa 1"], inplace=True)
# Out:
# /tmp/ipython-input-2291918767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Khánh Hòa"] *= danso_dict["Khánh Hòa"]
# /tmp/ipython-input-2291918767.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Khánh Hòa 1"] *= danso_dict["Ninh Thuận"]
# /tmp/ipython-input-2291918767.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Khánh Hòa"] = (
# /tmp/ipython-input-2291918767.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Khánh Hòa 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 51 columns]

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2023_PAPI_VIE_ENG["Lâm Đồng"] *= danso_dict["Lâm Đồng"]
df_2023_PAPI_VIE_ENG["Lâm Đồng 1"] *= danso_dict["Bình Thuận"]
df_2023_PAPI_VIE_ENG["Lâm Đồng 2"] *= danso_dict["Đắk Nông"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Lâm Đồng"
df_2023_PAPI_VIE_ENG["Lâm Đồng"] = (
    df_2023_PAPI_VIE_ENG["Lâm Đồng"] + df_2023_PAPI_VIE_ENG["Lâm Đồng 1"] + df_2023_PAPI_VIE_ENG["Lâm Đồng 2"]
) / (danso_dict["Lâm Đồng"] + danso_dict["Bình Thuận"] + danso_dict["Đắk Nông"])

# Bước 3: Xóa cột "Lâm Đồng 1" (Bình Thuận) và "Lâm Đồng 2" (Đắk Nông)
df_2023_PAPI_VIE_ENG.drop(columns=["Lâm Đồng 1"], inplace=True)
df_2023_PAPI_VIE_ENG.drop(columns=["Lâm Đồng 2"], inplace=True)
# Out:
# /tmp/ipython-input-4053286741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Lâm Đồng"] *= danso_dict["Lâm Đồng"]
# /tmp/ipython-input-4053286741.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Lâm Đồng 1"] *= danso_dict["Bình Thuận"]
# /tmp/ipython-input-4053286741.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Lâm Đồng 2"] *= danso_dict["Đắk Nông"]
# /tmp/ipython-input-4053286741.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Lâm Đồng"] = (
# /tmp/ipython-input-4053286741.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Lâm Đồng 1"], inplace=True)
# /tmp/ipython-input-4053286741.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Lâm Đồng 2"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 49 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Đắk Lắk"] *= danso_dict["Đắk Lắk"]
df_2023_PAPI_VIE_ENG["Đắk Lắk 1"] *= danso_dict["Phú Yên"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Đắk Lắk"
df_2023_PAPI_VIE_ENG["Đắk Lắk"] = (
    df_2023_PAPI_VIE_ENG["Đắk Lắk"] + df_2023_PAPI_VIE_ENG["Đắk Lắk 1"]
) / (danso_dict["Đắk Lắk"] + danso_dict["Phú Yên"])

# Bước 3: Xóa cột "Đắk Lắk 1" (Phú Yên)
df_2023_PAPI_VIE_ENG.drop(columns=["Đắk Lắk 1"], inplace=True)
# Out:
# /tmp/ipython-input-161825343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đắk Lắk"] *= danso_dict["Đắk Lắk"]
# /tmp/ipython-input-161825343.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đắk Lắk 1"] *= danso_dict["Phú Yên"]
# /tmp/ipython-input-161825343.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đắk Lắk"] = (
# /tmp/ipython-input-161825343.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Đắk Lắk 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 48 columns]

# %%
# Bước 1: Nhân dân số cho 3 cột
df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh"] *= danso_dict["TP. Hồ Chí Minh"]
df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 1"] *= danso_dict["Bình Dương"]
df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 2"] *= danso_dict["Bà Rịa-Vũng Tàu"]

# Bước 2: Tính trung bình có trọng số, bỏ qua NaN
# Tổng dân số chỉ tính các tỉnh có dữ liệu
total_population = (
    (~df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh"].isna()) * danso_dict["TP. Hồ Chí Minh"] +
    (~df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 1"].isna()) * danso_dict["Bình Dương"] +
    (~df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 2"].isna()) * danso_dict["Bà Rịa-Vũng Tàu"]
)

# Tính tổng điểm có trọng số, bỏ qua NaN
weighted_sum = (
    df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh"].fillna(0) +
    df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 1"].fillna(0) +
    df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 2"].fillna(0)
)

# Ghi đè vào cột TP. Hồ Chí Minh (tính trung bình có trọng số)
df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh"] = weighted_sum / total_population.replace(0, np.nan)

# Bước 3: Xóa 2 cột tạm
df_2023_PAPI_VIE_ENG.drop(columns=["TP. Hồ Chí Minh 1", "TP. Hồ Chí Minh 2"], inplace=True)
# Out:
# /tmp/ipython-input-4287809163.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh"] *= danso_dict["TP. Hồ Chí Minh"]
# /tmp/ipython-input-4287809163.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 1"] *= danso_dict["Bình Dương"]
# /tmp/ipython-input-4287809163.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh 2"] *= danso_dict["Bà Rịa-Vũng Tàu"]
# /tmp/ipython-input-4287809163.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["TP. Hồ Chí Minh"] = weighted_sum / total_population.replace(0, np.nan)
# /tmp/ipython-input-4287809163.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["TP. Hồ Chí Minh 1", "TP. Hồ Chí Minh 2"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 46 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Đồng Nai"] *= danso_dict["Đồng Nai"]
df_2023_PAPI_VIE_ENG["Đồng Nai 1"] *= danso_dict["Bình Phước"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Đồng Nai"
df_2023_PAPI_VIE_ENG["Đồng Nai"] = (
    df_2023_PAPI_VIE_ENG["Đồng Nai"] + df_2023_PAPI_VIE_ENG["Đồng Nai 1"]
) / (danso_dict["Đồng Nai"] + danso_dict["Bình Phước"])

# Bước 3: Xóa cột "Đồng Nai 1" (Bình Phước)
df_2023_PAPI_VIE_ENG.drop(columns=["Đồng Nai 1"], inplace=True)
# Out:
# /tmp/ipython-input-1753352076.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đồng Nai"] *= danso_dict["Đồng Nai"]
# /tmp/ipython-input-1753352076.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đồng Nai 1"] *= danso_dict["Bình Phước"]
# /tmp/ipython-input-1753352076.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đồng Nai"] = (
# /tmp/ipython-input-1753352076.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Đồng Nai 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 45 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Tây Ninh"] *= danso_dict["Tây Ninh"]
df_2023_PAPI_VIE_ENG["Tây Ninh 1"] *= danso_dict["Long An"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Tây Ninh"
df_2023_PAPI_VIE_ENG["Tây Ninh"] = (
    df_2023_PAPI_VIE_ENG["Tây Ninh"] + df_2023_PAPI_VIE_ENG["Tây Ninh 1"]
) / (danso_dict["Tây Ninh"] + danso_dict["Long An"])

# Bước 3: Xóa cột "Tây Ninh 1" (Long An)
df_2023_PAPI_VIE_ENG.drop(columns=["Tây Ninh 1"], inplace=True)
# Out:
# /tmp/ipython-input-3175667905.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Tây Ninh"] *= danso_dict["Tây Ninh"]
# /tmp/ipython-input-3175667905.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Tây Ninh 1"] *= danso_dict["Long An"]
# /tmp/ipython-input-3175667905.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Tây Ninh"] = (
# /tmp/ipython-input-3175667905.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Tây Ninh 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Vĩnh Long 2   Vĩnh Long   Đồng Tháp    An Giang  \
# 0     42.396557  ...    40.143326   40.823086   41.322628   41.845451
# 1     41.537930  ...    39.749874   40.458561   40.915852   41.090034
# 2     43.255184  ...    40.536777   41.187611   41.729404   42.600868
# 3      0.521973  ...     0.239186    0.221600    0.247287    0.459229
# 4      4.891806  ...     3.934829    4.178352    3.924989    4.338145
# ..          ...  ...          ...         ...         ...         ...
# 156    0.265691  ...     0.235352    0.285029    0.238577    0.140221
# 157    0.448234  ...     0.416123    0.399126    0.553394    0.393954
# 158    0.058670  ...     0.035474    0.077305    0.062164    0.029921
# 159    0.716731  ...     0.000000    0.536965    0.236152    0.697692
# 160  255.000000  ...   255.000000  250.000000  250.000000  491.000000
#
#      An Giang 1     Cần Thơ   Cần Thơ 2   Cần Thơ 1    Cà Mau 1      Cà Mau
# 0     40.989231   40.174438   41.069191   45.619614   45.578411   40.105442
# 1     39.902859   38.339314   40.363041   45.161324   45.030888   39.787140
# 2     42.075603   42.009563   41.775341   46.077904   46.125935   40.423744
# 3      0.660423    1.115600    0.429279    0.278603    0.332847    0.193501
# 4      3.948747    3.864248    4.338764    4.958764    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.241908    0.189155    0.247089    0.308778    0.324232    0.206163
# 157    0.441836    0.545319    0.537096    0.651170    0.703507    0.532134
# 158    0.036087    0.060014    0.047824    0.107128    0.116432    0.078543
# 159    0.441678    0.231057    0.000000    0.500000    0.164164    0.436157
# 160  246.000000  371.000000  255.000000  247.000000  246.000000  246.000000
#
# [161 rows x 44 columns]

# %%
# Bước 1: Nhân dân số cho 3 cột (Cần Thơ, Sóc Trăng, Hậu Giang)
df_2023_PAPI_VIE_ENG["Cần Thơ"] *= danso_dict["Cần Thơ"]
df_2023_PAPI_VIE_ENG["Cần Thơ 1"] *= danso_dict["Sóc Trăng"]
df_2023_PAPI_VIE_ENG["Cần Thơ 2"] *= danso_dict["Hậu Giang"]

# Bước 2: Tính tổng dân số chỉ tính cho các cột có dữ liệu (bỏ qua NaN)
total_population = (
    (~df_2023_PAPI_VIE_ENG["Cần Thơ"].isna()) * danso_dict["Cần Thơ"] +
    (~df_2023_PAPI_VIE_ENG["Cần Thơ 1"].isna()) * danso_dict["Sóc Trăng"] +
    (~df_2023_PAPI_VIE_ENG["Cần Thơ 2"].isna()) * danso_dict["Hậu Giang"]
)

# Bước 3: Tính tổng điểm có trọng số, bỏ qua NaN
weighted_sum = (
    df_2023_PAPI_VIE_ENG["Cần Thơ"].fillna(0) +
    df_2023_PAPI_VIE_ENG["Cần Thơ 1"].fillna(0) +
    df_2023_PAPI_VIE_ENG["Cần Thơ 2"].fillna(0)
)

# Bước 4: Ghi đè vào cột Cần Thơ với trung bình có trọng số (bỏ qua NaN)
df_2023_PAPI_VIE_ENG["Cần Thơ"] = weighted_sum / total_population.replace(0, np.nan)

# Bước 5: Xóa 2 cột phụ
df_2023_PAPI_VIE_ENG.drop(columns=["Cần Thơ 1", "Cần Thơ 2"], inplace=True)
# Out:
# /tmp/ipython-input-1438550201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Cần Thơ"] *= danso_dict["Cần Thơ"]
# /tmp/ipython-input-1438550201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Cần Thơ 1"] *= danso_dict["Sóc Trăng"]
# /tmp/ipython-input-1438550201.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Cần Thơ 2"] *= danso_dict["Hậu Giang"]
# /tmp/ipython-input-1438550201.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Cần Thơ"] = weighted_sum / total_population.replace(0, np.nan)
# /tmp/ipython-input-1438550201.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Cần Thơ 1", "Cần Thơ 2"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...  Đồng Tháp 1  Vĩnh Long 1  Vĩnh Long 2   Vĩnh Long  \
# 0     42.396557  ...    39.690632    40.212811    40.143326   40.823086
# 1     41.537930  ...    39.410149    36.995766    39.749874   40.458561
# 2     43.255184  ...    39.971115    43.429855    40.536777   41.187611
# 3      0.521973  ...     0.170509     1.955691     0.239186    0.221600
# 4      4.891806  ...     3.687938     4.671001     3.934829    4.178352
# ..          ...  ...          ...          ...          ...         ...
# 156    0.265691  ...     0.247575     0.205908     0.235352    0.285029
# 157    0.448234  ...     0.528887     0.543994     0.416123    0.399126
# 158    0.058670  ...     0.026681     0.026864     0.035474    0.077305
# 159    0.716731  ...     0.469638     0.655573     0.000000    0.536965
# 160  255.000000  ...   258.000000   251.000000   255.000000  250.000000
#
#       Đồng Tháp    An Giang  An Giang 1     Cần Thơ    Cà Mau 1      Cà Mau
# 0     41.322628   41.845451   40.989231   42.412106   45.578411   40.105442
# 1     40.915852   41.090034   39.902859   41.340258   45.030888   39.787140
# 2     41.729404   42.600868   42.075603   43.483955   46.125935   40.423744
# 3      0.247287    0.459229    0.660423    0.651593    0.332847    0.193501
# 4      3.924989    4.338145    3.948747    4.378492    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.238577    0.140221    0.241908    0.246687    0.324232    0.206163
# 157    0.553394    0.393954    0.441836    0.583214    0.703507    0.532134
# 158    0.062164    0.029921    0.036087    0.075015    0.116432    0.078543
# 159    0.236152    0.697692    0.441678    0.281367    0.164164    0.436157
# 160  250.000000  491.000000  246.000000  299.125000  246.000000  246.000000
#
# [161 rows x 42 columns]

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2023_PAPI_VIE_ENG["Vĩnh Long"] *= danso_dict["Vĩnh Long"]
df_2023_PAPI_VIE_ENG["Vĩnh Long 1"] *= danso_dict["Bến Tre"]
df_2023_PAPI_VIE_ENG["Vĩnh Long 2"] *= danso_dict["Trà Vinh"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Vĩnh Long"
df_2023_PAPI_VIE_ENG["Vĩnh Long"] = (
    df_2023_PAPI_VIE_ENG["Vĩnh Long"] + df_2023_PAPI_VIE_ENG["Vĩnh Long 1"] + df_2023_PAPI_VIE_ENG["Vĩnh Long 2"]
) / (danso_dict["Vĩnh Long"] + danso_dict["Bến Tre"] + danso_dict["Trà Vinh"])

# Bước 3: Xóa cột "Vĩnh Long 1" (Bến Tre) và "Vĩnh Long 2" (Trà Vinh)
df_2023_PAPI_VIE_ENG.drop(columns=["Vĩnh Long 1"], inplace=True)
df_2023_PAPI_VIE_ENG.drop(columns=["Vĩnh Long 2"], inplace=True)
# Out:
# /tmp/ipython-input-1388928845.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Vĩnh Long"] *= danso_dict["Vĩnh Long"]
# /tmp/ipython-input-1388928845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Vĩnh Long 1"] *= danso_dict["Bến Tre"]
# /tmp/ipython-input-1388928845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Vĩnh Long 2"] *= danso_dict["Trà Vinh"]
# /tmp/ipython-input-1388928845.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Vĩnh Long"] = (
# /tmp/ipython-input-1388928845.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Vĩnh Long 1"], inplace=True)
# /tmp/ipython-input-1388928845.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Vĩnh Long 2"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...    Đồng Nai  TP. Hồ Chí Minh  Đồng Tháp 1   Vĩnh Long  \
# 0     42.396557  ...   39.920955        42.089294    39.690632   40.376686
# 1     41.537930  ...   39.370553        41.769960    39.410149   38.879676
# 2     43.255184  ...   40.471356        42.408629    39.971115   41.873697
# 3      0.521973  ...    0.334598         0.194128     0.170509    0.910056
# 4      4.891806  ...    4.380994         4.609775     3.687938    4.298631
# ..          ...  ...         ...              ...          ...         ...
# 156    0.265691  ...    0.217812         0.274020     0.247575    0.238806
# 157    0.448234  ...    0.447154         0.470987     0.528887    0.461346
# 158    0.058670  ...    0.087953         0.076626     0.026681    0.044758
# 159    0.716731  ...    0.351157         0.615957     0.469638    0.420973
# 160  255.000000  ...  621.744186       994.813084   258.000000  251.909091
#
#       Đồng Tháp    An Giang  An Giang 1     Cần Thơ    Cà Mau 1      Cà Mau
# 0     41.322628   41.845451   40.989231   42.412106   45.578411   40.105442
# 1     40.915852   41.090034   39.902859   41.340258   45.030888   39.787140
# 2     41.729404   42.600868   42.075603   43.483955   46.125935   40.423744
# 3      0.247287    0.459229    0.660423    0.651593    0.332847    0.193501
# 4      3.924989    4.338145    3.948747    4.378492    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.238577    0.140221    0.241908    0.246687    0.324232    0.206163
# 157    0.553394    0.393954    0.441836    0.583214    0.703507    0.532134
# 158    0.062164    0.029921    0.036087    0.075015    0.116432    0.078543
# 159    0.236152    0.697692    0.441678    0.281367    0.164164    0.436157
# 160  250.000000  491.000000  246.000000  299.125000  246.000000  246.000000
#
# [161 rows x 40 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["Đồng Tháp"] *= danso_dict["Đồng Tháp"]
df_2023_PAPI_VIE_ENG["Đồng Tháp 1"] *= danso_dict["Tiền Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Đồng Tháp"
df_2023_PAPI_VIE_ENG["Đồng Tháp"] = (
    df_2023_PAPI_VIE_ENG["Đồng Tháp"] + df_2023_PAPI_VIE_ENG["Đồng Tháp 1"]
) / (danso_dict["Đồng Tháp"] + danso_dict["Tiền Giang"])

# Bước 3: Xóa cột "Đồng Tháp 1" (Tiền Giang)
df_2023_PAPI_VIE_ENG.drop(columns=["Đồng Tháp 1"], inplace=True)
# Out:
# /tmp/ipython-input-999209593.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đồng Tháp"] *= danso_dict["Đồng Tháp"]
# /tmp/ipython-input-999209593.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đồng Tháp 1"] *= danso_dict["Tiền Giang"]
# /tmp/ipython-input-999209593.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Đồng Tháp"] = (
# /tmp/ipython-input-999209593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Đồng Tháp 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...    Tây Ninh    Đồng Nai  TP. Hồ Chí Minh   Vĩnh Long  \
# 0     42.396557  ...   40.172293   39.920955        42.089294   40.376686
# 1     41.537930  ...   38.719060   39.370553        41.769960   38.879676
# 2     43.255184  ...   41.625525   40.471356        42.408629   41.873697
# 3      0.521973  ...    0.883443    0.334598         0.194128    0.910056
# 4      4.891806  ...    4.306470    4.380994         4.609775    4.298631
# ..          ...  ...         ...         ...              ...         ...
# 156    0.265691  ...    0.261395    0.217812         0.274020    0.238806
# 157    0.448234  ...    0.409318    0.447154         0.470987    0.461346
# 158    0.058670  ...    0.082643    0.087953         0.076626    0.044758
# 159    0.716731  ...    0.357685    0.351157         0.615957    0.420973
# 160  255.000000  ...  318.689655  621.744186       994.813084  251.909091
#
#       Đồng Tháp    An Giang  An Giang 1     Cần Thơ    Cà Mau 1      Cà Mau
# 0     40.458630   41.845451   40.989231   42.412106   45.578411   40.105442
# 1     40.118715   41.090034   39.902859   41.340258   45.030888   39.787140
# 2     40.798545   42.600868   42.075603   43.483955   46.125935   40.423744
# 3      0.206640    0.459229    0.660423    0.651593    0.332847    0.193501
# 4      3.799491    4.338145    3.948747    4.378492    5.021307    3.804902
# ..          ...         ...         ...         ...         ...         ...
# 156    0.243341    0.140221    0.241908    0.246687    0.324232    0.206163
# 157    0.540420    0.393954    0.441836    0.583214    0.703507    0.532134
# 158    0.043379    0.029921    0.036087    0.075015    0.116432    0.078543
# 159    0.359762    0.697692    0.441678    0.281367    0.164164    0.436157
# 160  254.235294  491.000000  246.000000  299.125000  246.000000  246.000000
#
# [161 rows x 39 columns]

# %%
# Bước 1: Nhân dân số cho hai cột (Cà Mau, Bạc Liêu)
df_2023_PAPI_VIE_ENG["Cà Mau"] *= danso_dict["Cà Mau"]
df_2023_PAPI_VIE_ENG["Cà Mau 1"] *= danso_dict["Bạc Liêu"]

# Bước 2: Tính tổng dân số (bỏ qua các tỉnh có NaN)
total_population = (
    (~df_2023_PAPI_VIE_ENG["Cà Mau"].isna()) * danso_dict["Cà Mau"] +
    (~df_2023_PAPI_VIE_ENG["Cà Mau 1"].isna()) * danso_dict["Bạc Liêu"]
)

# Bước 3: Tính tổng điểm có trọng số, bỏ qua NaN
weighted_sum = (
    df_2023_PAPI_VIE_ENG["Cà Mau"].fillna(0) +
    df_2023_PAPI_VIE_ENG["Cà Mau 1"].fillna(0)
)

# Bước 4: Tính trung bình có trọng số, bỏ qua NaN hoàn toàn
df_2023_PAPI_VIE_ENG["Cà Mau"] = weighted_sum / total_population.replace(0, np.nan)

# Bước 5: Xóa cột "Cà Mau 1" (Bạc Liêu)
df_2023_PAPI_VIE_ENG.drop(columns=["Cà Mau 1"], inplace=True)
# Out:
# /tmp/ipython-input-3165251215.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Cà Mau"] *= danso_dict["Cà Mau"]
# /tmp/ipython-input-3165251215.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Cà Mau 1"] *= danso_dict["Bạc Liêu"]
# /tmp/ipython-input-3165251215.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["Cà Mau"] = weighted_sum / total_population.replace(0, np.nan)
# /tmp/ipython-input-3165251215.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["Cà Mau 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...    Lâm Đồng    Tây Ninh    Đồng Nai  TP. Hồ Chí Minh  \
# 0     42.396557  ...   41.112656   40.172293   39.920955        42.089294
# 1     41.537930  ...   39.457340   38.719060   39.370553        41.769960
# 2     43.255184  ...   42.767972   41.625525   40.471356        42.408629
# 3      0.521973  ...    1.006293    0.883443    0.334598         0.194128
# 4      4.891806  ...    4.994676    4.306470    4.380994         4.609775
# ..          ...  ...         ...         ...         ...              ...
# 156    0.265691  ...    0.257551    0.261395    0.217812         0.274020
# 157    0.448234  ...    0.459732    0.409318    0.447154         0.470987
# 158    0.058670  ...    0.072479    0.082643    0.087953         0.076626
# 159    0.716731  ...    0.260045    0.357685    0.351157         0.615957
# 160  255.000000  ...  266.303030  318.689655  621.744186       994.813084
#
#       Vĩnh Long   Đồng Tháp    An Giang  An Giang 1     Cần Thơ      Cà Mau
# 0     40.376686   40.458630   41.845451   40.989231   42.412106   42.451000
# 1     38.879676   40.118715   41.090034   39.902859   41.340258   42.034460
# 2     41.873697   40.798545   42.600868   42.075603   43.483955   42.867540
# 3      0.910056    0.206640    0.459229    0.660423    0.651593    0.253221
# 4      4.298631    3.799491    4.338145    3.948747    4.378492    4.326218
# ..          ...         ...         ...         ...         ...         ...
# 156    0.238806    0.243341    0.140221    0.241908    0.246687    0.256764
# 157    0.461346    0.540420    0.393954    0.441836    0.583214    0.605580
# 158    0.044758    0.043379    0.029921    0.036087    0.075015    0.094781
# 159    0.420973    0.359762    0.697692    0.441678    0.281367    0.319589
# 160  251.909091  254.235294  491.000000  246.000000  299.125000  246.000000
#
# [161 rows x 38 columns]

# %%
## Bước 1: Nhân dân số cho hai cột
df_2023_PAPI_VIE_ENG["An Giang"] *= danso_dict["An Giang"]
df_2023_PAPI_VIE_ENG["An Giang 1"] *= danso_dict["Kiên Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "An Giang"
df_2023_PAPI_VIE_ENG["An Giang"] = (
    df_2023_PAPI_VIE_ENG["An Giang"] + df_2023_PAPI_VIE_ENG["An Giang 1"]
) / (danso_dict["An Giang"] + danso_dict["Kiên Giang"])

# Bước 3: Xóa cột "An Giang 1" (Kiên Giang)
df_2023_PAPI_VIE_ENG.drop(columns=["An Giang 1"], inplace=True)
# Out:
# /tmp/ipython-input-3970609081.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["An Giang"] *= danso_dict["An Giang"]
# /tmp/ipython-input-3970609081.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["An Giang 1"] *= danso_dict["Kiên Giang"]
# /tmp/ipython-input-3970609081.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG["An Giang"] = (
# /tmp/ipython-input-3970609081.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_PAPI_VIE_ENG.drop(columns=["An Giang 1"], inplace=True)

# %%
df_2023_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 156  Proportion of Respondents that Knows Provincia...
# 157  Proportion of Respondents Aware that Province ...
# 158           Used Online Government Service Portal(*)
# 159                  Able to Pay for Service Online(*)
# 160                                       Observations
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3    Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4    Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
# ..                                                 ...                ...
# 156  Tỉ lệ người trả lời cho biết cổng thông tin đi...            0%-100%
# 157  Tỉ lệ người trả lời cho biết chính quyền địa p...            0%-100%
# 158  Tỉ lệ người trả lời cho biết đã sử dụng cổng d...            0%-100%
# 159  Tỉ lệ người trả lời cho biết đã có thể thanh t...            0%-100%
# 160  Số quan sát từ mẫu đại diện theo chiến lược ch...                NaN
#
#           Hà Nội    Cao Bằng  Tuyên Quang     Lào Cai   Điện Biên    Lai Châu  \
# 0      43.960304   41.655148    42.951937   42.310404   42.020432   43.622257
# 1      43.700916   41.337597    42.011305   39.987069   41.638435   42.995277
# 2      44.219692   41.972698    43.892569   44.633738   42.402428   44.249237
# 3       0.157685    0.193045     0.571825    1.412391    0.232222    0.381152
# 4       5.427534    4.772978     5.134837    4.860209    4.696440    4.966353
# ..           ...         ...          ...         ...         ...         ...
# 156     0.341589    0.282083     0.266525    0.257751    0.290189    0.410376
# 157     0.619799    0.502874     0.569929    0.649242    0.599581    0.546348
# 158     0.131653    0.050837     0.108368    0.111449    0.089363    0.134379
# 159     0.295258    0.150194     0.722595    0.575438    0.140513    0.233626
# 160  1120.000000  248.000000   251.764706  249.764706  248.000000  246.000000
#
#          Sơn La  ...     Đắk Lắk    Lâm Đồng    Tây Ninh    Đồng Nai  \
# 0     42.396557  ...   41.713774   41.112656   40.172293   39.920955
# 1     41.537930  ...   41.347101   39.457340   38.719060   39.370553
# 2     43.255184  ...   42.080447   42.767972   41.625525   40.471356
# 3      0.521973  ...    0.222907    1.006293    0.883443    0.334598
# 4      4.891806  ...    4.633677    4.994676    4.306470    4.380994
# ..          ...  ...         ...         ...         ...         ...
# 156    0.265691  ...    0.284064    0.257551    0.261395    0.217812
# 157    0.448234  ...    0.523882    0.459732    0.409318    0.447154
# 158    0.058670  ...    0.036414    0.072479    0.082643    0.087953
# 159    0.716731  ...    0.628840    0.260045    0.357685    0.351157
# 160  255.000000  ...  252.714286  266.303030  318.689655  621.744186
#
#      TP. Hồ Chí Minh   Vĩnh Long   Đồng Tháp    An Giang     Cần Thơ  \
# 0          42.089294   40.376686   40.458630   41.428912   42.412106
# 1          41.769960   38.879676   40.118715   40.512490   41.340258
# 2          42.408629   41.873697   40.798545   42.345334   43.483955
# 3           0.194128    0.910056    0.206640    0.557107    0.651593
# 4           4.609775    4.298631    3.799491    4.148708    4.378492
# ..               ...         ...         ...         ...         ...
# 156         0.274020    0.238806    0.243341    0.189690    0.246687
# 157         0.470987    0.461346    0.540420    0.417248    0.583214
# 158         0.076626    0.044758    0.043379    0.032920    0.075015
# 159         0.615957    0.420973    0.359762    0.573145    0.281367
# 160       994.813084  251.909091  254.235294  371.810811  299.125000
#
#          Cà Mau
# 0     42.451000
# 1     42.034460
# 2     42.867540
# 3      0.253221
# 4      4.326218
# ..          ...
# 156    0.256764
# 157    0.605580
# 158    0.094781
# 159    0.319589
# 160  246.000000
#
# [161 rows x 37 columns]

# %%
from google.colab import files

# Xuất DataFrame ra file CSV với encoding UTF-8 để hiển thị tiếng Việt đúng
file_name = "PAPI 2023 34 đơn vị hành chính.csv"
df_2023_PAPI_VIE_ENG.to_csv(file_name, index=False, encoding="utf-8-sig")

# Tải file về máy
files.download(file_name)
