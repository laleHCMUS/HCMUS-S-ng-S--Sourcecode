# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import gdown

# %%
url = "https://drive.google.com/uc?id=1tUR6uqvH_tBJwO0fBpl8Mfa_M9O8nnPL"
output = "PAPI.xlsx"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tUR6uqvH_tBJwO0fBpl8Mfa_M9O8nnPL
# To: /content/PAPI.xlsx
# 100%|██████████| 2.27M/2.27M [00:00<00:00, 144MB/s]
# 'PAPI.xlsx'

# %%
df = pd.read_excel("PAPI.xlsx")

# %%
df_2024_PAPI_VIE_ENG = pd.read_excel(
    "PAPI.xlsx",
    sheet_name="2024_PAPI_VIE_ENG",
    header=1  # Bỏ dòng đầu, lấy tên tỉnh làm cột
)
df_2024_PAPI_VIE_ENG.head(5)
# Out:
#   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                Unweighted PAPI Score
# 1                Unweighted 95% CI Low
# 2               Unweighted 95% CI High
# 3            Unweighted Standard Error
# 4           Dimension 1: Participation
#
#               Tỉnh/Thành phố trực thuộc trung ương.1         Unnamed: 2  \
# 0           Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3  Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4  Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
#
#       Hà Nội   Hà Giang   Cao Bằng    Bắc Kạn  Tuyên Quang    Lào Cai  \
# 0  43.774715  43.728905  41.332478  44.096230    42.546780  41.748901
# 1  43.220791  41.017761  39.598320  42.439396    39.718628  38.581425
# 2  44.328640  46.440048  43.066635  45.753063    45.374931  44.916378
# ...

# %%
# Đổi tên cột "Unnamed: 2" thành "Thang điểm"
df_2024_PAPI_VIE_ENG.rename(columns={"Unnamed: 2": "Thang điểm"}, inplace=True)

# Xem lại 5 dòng đầu
print(df_2024_PAPI_VIE_ENG.head())
# Out:
#   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                Unweighted PAPI Score
# 1                Unweighted 95% CI Low
# 2               Unweighted 95% CI High
# 3            Unweighted Standard Error
# 4           Dimension 1: Participation
#
#               Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0           Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2  Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 3  Chỉ số PAPI tổng hợp (không có trọng số) - sai...                NaN
# 4  Chỉ số nội dung 1: Tham gia của người dân ở cấ...   1-10 điểm/points
#
#       Hà Nội   Hà Giang   Cao Bằng    Bắc Kạn  Tuyên Quang    Lào Cai  \
# 0  43.774715  43.728905  41.332478  44.096230    42.546780  41.748901
# 1  43.220791  41.017761  39.598320  42.439396    39.718628  38.581425
# 2  44.328640  46.440048  43.066635  45.753063    45.374931  44.916378
# ...

# %%
df_2024_PAPI_VIE_ENG.rename(columns={"Hà Giang": "Tuyên Quang 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Yên Bái": "Lào Cai 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bắc Kạn": "Thái Nguyên 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Vĩnh Phúc": "Phú Thọ 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Hòa Bình": "Phú Thọ 2"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bắc Giang": "Bắc Ninh 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Thái Bình": "Hưng Yên 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Hải Dương": "Hải Phòng 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Nam Định": "Ninh Bình 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Hà Nam": "Ninh Bình 2"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Quảng Bình": "Quảng Trị 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Quảng Nam": "Đà Nẵng 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Kon Tum": "Quảng Ngãi 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bình Định": "Gia Lai 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Ninh Thuận": "Khánh Hòa 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bình Thuận": "Lâm Đồng 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Đắk Nông": "Lâm Đồng 2"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Phú Yên": "Đắk Lắk 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bình Dương": "TP. Hồ Chí Minh 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bà Rịa-Vũng Tàu": "TP. Hồ Chí Minh 2"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bình Phước": "Đồng Nai 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Long An": "Tây Ninh 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Sóc Trăng": "Cần Thơ 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Hậu Giang": "Cần Thơ 2"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bến Tre": "Vĩnh Long 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Trà Vinh": "Vĩnh Long 2"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Tiền Giang": "Đồng Tháp 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Bạc Liêu": "Cà Mau 1"}, inplace=True)
df_2024_PAPI_VIE_ENG.rename(columns={"Kiên Giang": "An Giang 1"}, inplace=True)

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 158                         Observations (Dimension 1)
# 159  Note: Provinces without data in indicators mea...
# 160  Copyright @CECODES, VFF-CRT, RTA and UNDP (202...
# 161                                                NaN
# 162  * Các tiêu chí giữ nguyên kết quả của năm 2021...
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
# Lấy dữ liệu đến dòng 157 (bỏ các dòng Note, Copyright)
df_2024_PAPI_VIE_ENG = df_2024_PAPI_VIE_ENG.iloc[:158, :]
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
# Đếm số ô NaN theo cột
missing_per_column = df_2024_PAPI_VIE_ENG.isna().sum()

# In ra các cột có ít nhất 1 giá trị trống
missing_columns = missing_per_column[missing_per_column > 0]
print(missing_columns)
# Out:
# Thang điểm       3
# Phú Thọ 1      158
# Đồng Tháp 1    158
# Cà Mau           1
# dtype: int64

# %%
url = "https://drive.google.com/uc?id=16r9gJQHUwipXDRbHZwHLtGvjUsozr_ZF"
output = "danso.xlsx"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=16r9gJQHUwipXDRbHZwHLtGvjUsozr_ZF
# To: /content/danso.xlsx
# 100%|██████████| 18.6k/18.6k [00:00<00:00, 34.9MB/s]
# 'danso.xlsx'

# %%
danso = pd.read_excel("danso.xlsx", sheet_name = None)

# %%
danso
# Out:
# {'Sheet1':              Unnamed: 0     2019     2020     2021     2022     2023     2024  \
#  0   Đồng bằng sông Hồng  22620.2  22920.2  23224.8  23454.2  23732.4  24016.0
#  1                Hà Nội   8093.9   8246.5   8330.8   8435.7   8587.1   8717.6
#  2             Vĩnh Phúc   1154.8   1171.2   1191.8   1197.6   1211.3   1225.3
#  3              Bắc Ninh   1378.6   1419.1   1462.9   1488.2   1517.4   1546.6
#  4            Quảng Ninh   1324.8   1337.6   1350.9   1362.9   1381.2   1396.5
#  ..                  ...      ...      ...      ...      ...      ...      ...
#  64              Cần Thơ   1236.0   1240.7   1247.0   1252.3   1258.9   1271.7
#  65            Hậu Giang    732.2    729.8    729.9    729.5    728.3    730.0
#  66            Sóc Trăng   1199.5   1195.7   1206.8   1197.8   1198.8   1205.3
#  67             Bạc Liêu    908.2    913.5    918.5    921.8    925.2    928.7
#  68               Cà Mau   1194.3   1193.9   1208.8   1207.6   1207.4   1212.0
#
# ...

# %%
# Truy cập vào sheet "Sheet1"
df_danso = danso["Sheet1"]

# Lấy 2 cột: Tên tỉnh và dân số 2024 (làm tròn)
df_danso = df_danso[["Unnamed: 0", "2024 (làm tròn)"]]

# Đổi tên cột cho dễ dùng
df_danso = df_danso.rename(columns={"Unnamed: 0": "Tỉnh"})

# Chuyển thành dict để tra cứu nhanh
danso_dict = dict(zip(df_danso["Tỉnh"], df_danso["2024 (làm tròn)"]))

# %%
danso_dict
# Out:
# {'Đồng bằng sông Hồng': 24.0,
#  'Hà Nội': 8.7,
#  'Vĩnh Phúc': 1.2,
#  'Bắc Ninh': 1.5,
#  'Quảng Ninh': 1.4,
#  'Hải Dương': 2.0,
#  'Hải Phòng': 2.1,
#  'Hưng Yên': 1.3,
#  'Thái Bình': 1.9,
#  'Hà Nam': 0.9,
#  'Nam Định': 1.9,
#  'Ninh Bình': 1.0,
#  'Trung du và miền núi phía Bắc': 13.3,
#  'Hà Giang': 0.9,
#  'Cao Bằng': 0.6,
#  'Bắc Kạn': 0.3,
#  'Tuyên Quang': 0.8,
#  'Lào Cai': 0.8,
#  'Yên Bái': 0.9,
#  'Thái Nguyên': 1.4,
#  'Lạng Sơn': 0.8,
#  'Bắc Giang': 2.0,
#  'Phú Thọ': 1.5,
#  'Điện Biên': 0.7,
#  'Lai Châu': 0.5,
#  'Sơn La': 1.3,
#  'Hòa Bình': 0.9,
#  'Bắc Trung Bộ và Duyên hải miền Trung': 21.0,
#  'Thanh Hoá': 3.8,
#  'Nghệ An': 3.5,
#  'Hà Tĩnh': 1.3,
#  'Quảng Bình': 0.9,
#  'Quảng Trị': 0.7,
#  'Thừa Thiên Huế': 1.2,
#  'Đà Nẵng': 1.3,
#  'Quảng Nam': 1.5,
#  'Quảng Ngãi': 1.3,
#  'Bình Định': 1.5,
#  'Phú Yên': 0.9,
#  'Khánh Hòa': 1.3,
#  'Ninh Thuận': 0.6,
#  'Bình Thuận': 1.3,
#  'Tây Nguyên': 6.2,
#  'Kon Tum': 0.6,
#  'Gia Lai': 1.6,
# ...

# %%
# Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Tuyên Quang"] *= danso_dict["Tuyên Quang"]
df_2024_PAPI_VIE_ENG["Tuyên Quang 1"] *= danso_dict["Hà Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Tuyên Quang"
df_2024_PAPI_VIE_ENG["Tuyên Quang"] = (
    df_2024_PAPI_VIE_ENG["Tuyên Quang"] + df_2024_PAPI_VIE_ENG["Tuyên Quang 1"]
) / (danso_dict["Tuyên Quang"] + danso_dict["Hà Giang"])

# Bước 3: Xóa cột "Tuyên Quang 1"
df_2024_PAPI_VIE_ENG.drop(columns=["Tuyên Quang 1"], inplace=True)
# Out:
# /tmp/ipython-input-3066851281.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Tuyên Quang"] *= danso_dict["Tuyên Quang"]
# /tmp/ipython-input-3066851281.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Tuyên Quang 1"] *= danso_dict["Hà Giang"]
# /tmp/ipython-input-3066851281.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
# Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Lào Cai"] *= danso_dict["Lào Cai"]
df_2024_PAPI_VIE_ENG["Lào Cai 1"] *= danso_dict["Yên Bái"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Lào Cai"
df_2024_PAPI_VIE_ENG["Lào Cai"] = (
    df_2024_PAPI_VIE_ENG["Lào Cai"] + df_2024_PAPI_VIE_ENG["Lào Cai 1"]
) / (danso_dict["Lào Cai"] + danso_dict["Yên Bái"])

# Bước 3: Xóa cột "Lào Cai 1"
df_2024_PAPI_VIE_ENG.drop(columns=["Lào Cai 1"], inplace=True)
# Out:
# /tmp/ipython-input-3785182586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Lào Cai"] *= danso_dict["Lào Cai"]
# /tmp/ipython-input-3785182586.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Lào Cai 1"] *= danso_dict["Yên Bái"]
# /tmp/ipython-input-3785182586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Thái Nguyên"] *= danso_dict["Thái Nguyên"]
df_2024_PAPI_VIE_ENG["Thái Nguyên 1"] *= danso_dict["Bắc Kạn"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Thái Nguyên"
df_2024_PAPI_VIE_ENG["Thái Nguyên"] = (
    df_2024_PAPI_VIE_ENG["Thái Nguyên"] + df_2024_PAPI_VIE_ENG["Thái Nguyên 1"]
) / (danso_dict["Thái Nguyên"] + danso_dict["Bắc Kạn"])

# Bước 3: Xóa cột "Thái Nguyên 1" (Bắc Kạn)
df_2024_PAPI_VIE_ENG.drop(columns=["Thái Nguyên 1"], inplace=True)
# Out:
# /tmp/ipython-input-580360944.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Thái Nguyên"] *= danso_dict["Thái Nguyên"]
# /tmp/ipython-input-580360944.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Thái Nguyên 1"] *= danso_dict["Bắc Kạn"]
# /tmp/ipython-input-580360944.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
### Bước 1: Nhân dân số cho 3 cột
df_2024_PAPI_VIE_ENG["Phú Thọ"] *= danso_dict["Phú Thọ"]
df_2024_PAPI_VIE_ENG["Phú Thọ 1"] *= danso_dict["Vĩnh Phúc"]
df_2024_PAPI_VIE_ENG["Phú Thọ 2"] *= danso_dict["Hòa Bình"]

# Bước 2: Tính trung bình có trọng số, bỏ qua NaN
df_2024_PAPI_VIE_ENG["Phú Thọ"] = (
    df_2024_PAPI_VIE_ENG["Phú Thọ"] + df_2024_PAPI_VIE_ENG["Phú Thọ 1"].fillna(0) + df_2024_PAPI_VIE_ENG["Phú Thọ 2"]
) / (
    danso_dict["Phú Thọ"] +
    (danso_dict["Vĩnh Phúc"] * (~df_2024_PAPI_VIE_ENG["Phú Thọ 1"].isna())) +
    danso_dict["Hòa Bình"]
)

# Bước 3: Xóa cột "Phú Thọ 1" (Vĩnh Phúc) và "Phú Thọ 2" (Hòa Bình)
df_2024_PAPI_VIE_ENG.drop(columns=["Phú Thọ 1"], inplace=True)
df_2024_PAPI_VIE_ENG.drop(columns=["Phú Thọ 2"], inplace=True)
# Out:
# /tmp/ipython-input-1783506838.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Phú Thọ"] *= danso_dict["Phú Thọ"]
# /tmp/ipython-input-1783506838.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Phú Thọ 1"] *= danso_dict["Vĩnh Phúc"]
# /tmp/ipython-input-1783506838.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Bắc Ninh"] *= danso_dict["Bắc Ninh"]
df_2024_PAPI_VIE_ENG["Bắc Ninh 1"] *= danso_dict["Bắc Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Bắc Ninh"
df_2024_PAPI_VIE_ENG["Bắc Ninh"] = (
    df_2024_PAPI_VIE_ENG["Bắc Ninh"] + df_2024_PAPI_VIE_ENG["Bắc Ninh 1"]
) / (danso_dict["Bắc Ninh"] + danso_dict["Bắc Giang"])

# Bước 3: Xóa cột "Thái Nguyên 1" (Bắc Kạn)
df_2024_PAPI_VIE_ENG.drop(columns=["Bắc Ninh 1"], inplace=True)
# Out:
# /tmp/ipython-input-3530451873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Bắc Ninh"] *= danso_dict["Bắc Ninh"]
# /tmp/ipython-input-3530451873.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Bắc Ninh 1"] *= danso_dict["Bắc Giang"]
# /tmp/ipython-input-3530451873.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Hưng Yên"] *= danso_dict["Hưng Yên"]
df_2024_PAPI_VIE_ENG["Hưng Yên 1"] *= danso_dict["Thái Bình"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Hưng Yên"
df_2024_PAPI_VIE_ENG["Hưng Yên"] = (
    df_2024_PAPI_VIE_ENG["Hưng Yên"] + df_2024_PAPI_VIE_ENG["Hưng Yên 1"]
) / (danso_dict["Hưng Yên"] + danso_dict["Thái Bình"])

# Bước 3: Xóa cột "Hưng Yên 1" (Thái Bình)
df_2024_PAPI_VIE_ENG.drop(columns=["Hưng Yên 1"], inplace=True)
# Out:
# /tmp/ipython-input-3908688929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Hưng Yên"] *= danso_dict["Hưng Yên"]
# /tmp/ipython-input-3908688929.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Hưng Yên 1"] *= danso_dict["Thái Bình"]
# /tmp/ipython-input-3908688929.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Hải Phòng"] *= danso_dict["Hải Phòng"]
df_2024_PAPI_VIE_ENG["Hải Phòng 1"] *= danso_dict["Hải Dương"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Hải Phòng"
df_2024_PAPI_VIE_ENG["Hải Phòng"] = (
    df_2024_PAPI_VIE_ENG["Hải Phòng"] + df_2024_PAPI_VIE_ENG["Hải Phòng 1"]
) / (danso_dict["Hải Phòng"] + danso_dict["Hải Dương"])

# Bước 3: Xóa cột "Hải Phòng 1" (Hải Dương)
df_2024_PAPI_VIE_ENG.drop(columns=["Hải Phòng 1"], inplace=True)
# Out:
# /tmp/ipython-input-4110413348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Hải Phòng"] *= danso_dict["Hải Phòng"]
# /tmp/ipython-input-4110413348.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Hải Phòng 1"] *= danso_dict["Hải Dương"]
# /tmp/ipython-input-4110413348.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2024_PAPI_VIE_ENG["Ninh Bình"] *= danso_dict["Ninh Bình"]
df_2024_PAPI_VIE_ENG["Ninh Bình 1"] *= danso_dict["Nam Định"]
df_2024_PAPI_VIE_ENG["Ninh Bình 2"] *= danso_dict["Hà Nam"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Ninh Bình"
df_2024_PAPI_VIE_ENG["Ninh Bình"] = (
    df_2024_PAPI_VIE_ENG["Ninh Bình"] + df_2024_PAPI_VIE_ENG["Ninh Bình 1"] + df_2024_PAPI_VIE_ENG["Ninh Bình 2"]
) / (danso_dict["Ninh Bình"] + danso_dict["Nam Định"] + danso_dict["Hà Nam"])

# Bước 3: Xóa cột "Ninh Bình 1" (Nam Định) và "Ninh Bình 2" (Hà Nam)
df_2024_PAPI_VIE_ENG.drop(columns=["Ninh Bình 1"], inplace=True)
df_2024_PAPI_VIE_ENG.drop(columns=["Ninh Bình 2"], inplace=True)
# Out:
# /tmp/ipython-input-2302346150.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Ninh Bình"] *= danso_dict["Ninh Bình"]
# /tmp/ipython-input-2302346150.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Ninh Bình 1"] *= danso_dict["Nam Định"]
# /tmp/ipython-input-2302346150.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Quảng Trị"] *= danso_dict["Quảng Trị"]
df_2024_PAPI_VIE_ENG["Quảng Trị 1"] *= danso_dict["Quảng Bình"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Quảng Trị"
df_2024_PAPI_VIE_ENG["Quảng Trị"] = (
    df_2024_PAPI_VIE_ENG["Quảng Trị"] + df_2024_PAPI_VIE_ENG["Quảng Trị 1"]
) / (danso_dict["Quảng Trị"] + danso_dict["Quảng Bình"])

# Bước 3: Xóa cột "Quảng Trị 1" (Quảng Bình)
df_2024_PAPI_VIE_ENG.drop(columns=["Quảng Trị 1"], inplace=True)
# Out:
# /tmp/ipython-input-281591296.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Quảng Trị"] *= danso_dict["Quảng Trị"]
# /tmp/ipython-input-281591296.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Quảng Trị 1"] *= danso_dict["Quảng Bình"]
# /tmp/ipython-input-281591296.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Đà Nẵng"] *= danso_dict["Đà Nẵng"]
df_2024_PAPI_VIE_ENG["Đà Nẵng 1"] *= danso_dict["Quảng Nam"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Đà Nẵng"
df_2024_PAPI_VIE_ENG["Đà Nẵng"] = (
    df_2024_PAPI_VIE_ENG["Đà Nẵng"] + df_2024_PAPI_VIE_ENG["Đà Nẵng 1"]
) / (danso_dict["Đà Nẵng"] + danso_dict["Quảng Nam"])

# Bước 3: Xóa cột "Đà Nẵng 1" (Quảng Nam)
df_2024_PAPI_VIE_ENG.drop(columns=["Đà Nẵng 1"], inplace=True)
# Out:
# /tmp/ipython-input-3789206983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đà Nẵng"] *= danso_dict["Đà Nẵng"]
# /tmp/ipython-input-3789206983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đà Nẵng 1"] *= danso_dict["Quảng Nam"]
# /tmp/ipython-input-3789206983.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Quảng Ngãi"] *= danso_dict["Quảng Ngãi"]
df_2024_PAPI_VIE_ENG["Quảng Ngãi 1"] *= danso_dict["Kon Tum"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Quảng Ngãi"
df_2024_PAPI_VIE_ENG["Quảng Ngãi"] = (
    df_2024_PAPI_VIE_ENG["Quảng Ngãi"] + df_2024_PAPI_VIE_ENG["Quảng Ngãi 1"]
) / (danso_dict["Quảng Ngãi"] + danso_dict["Kon Tum"])

# Bước 3: Xóa cột "Quảng Ngãi 1" (Kon Tum)
df_2024_PAPI_VIE_ENG.drop(columns=["Quảng Ngãi 1"], inplace=True)
# Out:
# /tmp/ipython-input-1413464424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Quảng Ngãi"] *= danso_dict["Quảng Ngãi"]
# /tmp/ipython-input-1413464424.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Quảng Ngãi 1"] *= danso_dict["Kon Tum"]
# /tmp/ipython-input-1413464424.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Gia Lai"] *= danso_dict["Gia Lai"]
df_2024_PAPI_VIE_ENG["Gia Lai 1"] *= danso_dict["Bình Định"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Gia Lai"
df_2024_PAPI_VIE_ENG["Gia Lai"] = (
    df_2024_PAPI_VIE_ENG["Gia Lai"] + df_2024_PAPI_VIE_ENG["Gia Lai 1"]
) / (danso_dict["Gia Lai"] + danso_dict["Bình Định"])

# Bước 3: Xóa cột "Gia Lai 1" (Kon Tum)
df_2024_PAPI_VIE_ENG.drop(columns=["Gia Lai 1"], inplace=True)
# Out:
# /tmp/ipython-input-1750099997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Gia Lai"] *= danso_dict["Gia Lai"]
# /tmp/ipython-input-1750099997.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Gia Lai 1"] *= danso_dict["Bình Định"]
# /tmp/ipython-input-1750099997.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Khánh Hòa"] *= danso_dict["Khánh Hòa"]
df_2024_PAPI_VIE_ENG["Khánh Hòa 1"] *= danso_dict["Ninh Thuận"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Khánh Hòa"
df_2024_PAPI_VIE_ENG["Khánh Hòa"] = (
    df_2024_PAPI_VIE_ENG["Khánh Hòa"] + df_2024_PAPI_VIE_ENG["Khánh Hòa 1"]
) / (danso_dict["Khánh Hòa"] + danso_dict["Ninh Thuận"])

# Bước 3: Xóa cột "Khánh Hòa 1" (Ninh Thuận)
df_2024_PAPI_VIE_ENG.drop(columns=["Khánh Hòa 1"], inplace=True)
# Out:
# /tmp/ipython-input-2833233888.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Khánh Hòa"] *= danso_dict["Khánh Hòa"]
# /tmp/ipython-input-2833233888.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Khánh Hòa 1"] *= danso_dict["Ninh Thuận"]
# /tmp/ipython-input-2833233888.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2024_PAPI_VIE_ENG["Lâm Đồng"] *= danso_dict["Lâm Đồng"]
df_2024_PAPI_VIE_ENG["Lâm Đồng 1"] *= danso_dict["Bình Thuận"]
df_2024_PAPI_VIE_ENG["Lâm Đồng 2"] *= danso_dict["Đắk Nông"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Lâm Đồng"
df_2024_PAPI_VIE_ENG["Lâm Đồng"] = (
    df_2024_PAPI_VIE_ENG["Lâm Đồng"] + df_2024_PAPI_VIE_ENG["Lâm Đồng 1"] + df_2024_PAPI_VIE_ENG["Lâm Đồng 2"]
) / (danso_dict["Lâm Đồng"] + danso_dict["Bình Thuận"] + danso_dict["Đắk Nông"])

# Bước 3: Xóa cột "Lâm Đồng 1" (Bình Thuận) và "Lâm Đồng 2" (Đắk Nông)
df_2024_PAPI_VIE_ENG.drop(columns=["Lâm Đồng 1"], inplace=True)
df_2024_PAPI_VIE_ENG.drop(columns=["Lâm Đồng 2"], inplace=True)
# Out:
# /tmp/ipython-input-1442600694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Lâm Đồng"] *= danso_dict["Lâm Đồng"]
# /tmp/ipython-input-1442600694.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Lâm Đồng 1"] *= danso_dict["Bình Thuận"]
# /tmp/ipython-input-1442600694.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Đắk Lắk"] *= danso_dict["Đắk Lắk"]
df_2024_PAPI_VIE_ENG["Đắk Lắk 1"] *= danso_dict["Phú Yên"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Đắk Lắk"
df_2024_PAPI_VIE_ENG["Đắk Lắk"] = (
    df_2024_PAPI_VIE_ENG["Đắk Lắk"] + df_2024_PAPI_VIE_ENG["Đắk Lắk 1"]
) / (danso_dict["Đắk Lắk"] + danso_dict["Phú Yên"])

# Bước 3: Xóa cột "Đắk Lắk 1" (Phú Yên)
df_2024_PAPI_VIE_ENG.drop(columns=["Đắk Lắk 1"], inplace=True)
# Out:
# /tmp/ipython-input-2271240552.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đắk Lắk"] *= danso_dict["Đắk Lắk"]
# /tmp/ipython-input-2271240552.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đắk Lắk 1"] *= danso_dict["Phú Yên"]
# /tmp/ipython-input-2271240552.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh"] *= danso_dict["TP. Hồ Chí Minh"]
df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh 1"] *= danso_dict["Bình Dương"]
df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh 2"] *= danso_dict["Bà Rịa-Vũng Tàu"]
# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "TP. Hồ Chí Minh"
df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh"] = ( df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh"] + df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh 1"]
                                           + df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh 2"] ) / (danso_dict["TP. Hồ Chí Minh"]
                                                                                            + danso_dict["Bình Dương"] + danso_dict["Bà Rịa-Vũng Tàu"])
# Bước 3: Xóa cột "TP. Hồ Chí Minh 1" (Bình Dương) và "TP. Hồ Chí Minh 2" (Bà Rịa-Vũng Tàu)
df_2024_PAPI_VIE_ENG.drop(columns=["TP. Hồ Chí Minh 1"], inplace=True)
df_2024_PAPI_VIE_ENG.drop(columns=["TP. Hồ Chí Minh 2"], inplace=True)
# Out:
# /tmp/ipython-input-3839168565.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh"] *= danso_dict["TP. Hồ Chí Minh"]
# /tmp/ipython-input-3839168565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["TP. Hồ Chí Minh 1"] *= danso_dict["Bình Dương"]
# /tmp/ipython-input-3839168565.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Đồng Nai"] *= danso_dict["Đồng Nai"]
df_2024_PAPI_VIE_ENG["Đồng Nai 1"] *= danso_dict["Bình Phước"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Đồng Nai"
df_2024_PAPI_VIE_ENG["Đồng Nai"] = (
    df_2024_PAPI_VIE_ENG["Đồng Nai"] + df_2024_PAPI_VIE_ENG["Đồng Nai 1"]
) / (danso_dict["Đồng Nai"] + danso_dict["Bình Phước"])

# Bước 3: Xóa cột "Đồng Nai 1" (Bình Phước)
df_2024_PAPI_VIE_ENG.drop(columns=["Đồng Nai 1"], inplace=True)
# Out:
# /tmp/ipython-input-564346623.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đồng Nai"] *= danso_dict["Đồng Nai"]
# /tmp/ipython-input-564346623.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đồng Nai 1"] *= danso_dict["Bình Phước"]
# /tmp/ipython-input-564346623.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["Tây Ninh"] *= danso_dict["Tây Ninh"]
df_2024_PAPI_VIE_ENG["Tây Ninh 1"] *= danso_dict["Long An"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Tây Ninh"
df_2024_PAPI_VIE_ENG["Tây Ninh"] = (
    df_2024_PAPI_VIE_ENG["Tây Ninh"] + df_2024_PAPI_VIE_ENG["Tây Ninh 1"]
) / (danso_dict["Tây Ninh"] + danso_dict["Long An"])

# Bước 3: Xóa cột "Tây Ninh 1" (Long An)
df_2024_PAPI_VIE_ENG.drop(columns=["Tây Ninh 1"], inplace=True)
# Out:
# /tmp/ipython-input-2386519599.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Tây Ninh"] *= danso_dict["Tây Ninh"]
# /tmp/ipython-input-2386519599.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Tây Ninh 1"] *= danso_dict["Long An"]
# /tmp/ipython-input-2386519599.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2024_PAPI_VIE_ENG["Cần Thơ"] *= danso_dict["Cần Thơ"]
df_2024_PAPI_VIE_ENG["Cần Thơ 1"] *= danso_dict["Sóc Trăng"]
df_2024_PAPI_VIE_ENG["Cần Thơ 2"] *= danso_dict["Hậu Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Lâm Đồng"
df_2024_PAPI_VIE_ENG["Cần Thơ"] = (
    df_2024_PAPI_VIE_ENG["Cần Thơ"] + df_2024_PAPI_VIE_ENG["Cần Thơ 1"] + df_2024_PAPI_VIE_ENG["Cần Thơ 2"]
) / (danso_dict["Cần Thơ"] + danso_dict["Sóc Trăng"] + danso_dict["Hậu Giang"])

# Bước 3: Xóa cột "Lâm Đồng 1" (Bình Thuận) và "Lâm Đồng 2" (Đắk Nông)
df_2024_PAPI_VIE_ENG.drop(columns=["Cần Thơ 1"], inplace=True)
df_2024_PAPI_VIE_ENG.drop(columns=["Cần Thơ 2"], inplace=True)
# Out:
# /tmp/ipython-input-493679551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Cần Thơ"] *= danso_dict["Cần Thơ"]
# /tmp/ipython-input-493679551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Cần Thơ 1"] *= danso_dict["Sóc Trăng"]
# /tmp/ipython-input-493679551.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho 3 cột
df_2024_PAPI_VIE_ENG["Vĩnh Long"] *= danso_dict["Vĩnh Long"]
df_2024_PAPI_VIE_ENG["Vĩnh Long 1"] *= danso_dict["Bến Tre"]
df_2024_PAPI_VIE_ENG["Vĩnh Long 2"] *= danso_dict["Trà Vinh"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "Vĩnh Long"
df_2024_PAPI_VIE_ENG["Vĩnh Long"] = (
    df_2024_PAPI_VIE_ENG["Vĩnh Long"] + df_2024_PAPI_VIE_ENG["Vĩnh Long 1"] + df_2024_PAPI_VIE_ENG["Vĩnh Long 2"]
) / (danso_dict["Vĩnh Long"] + danso_dict["Bến Tre"] + danso_dict["Trà Vinh"])

# Bước 3: Xóa cột "Vĩnh Long 1" (Bến Tre) và "Vĩnh Long 2" (Trà Vinh)
df_2024_PAPI_VIE_ENG.drop(columns=["Vĩnh Long 1"], inplace=True)
df_2024_PAPI_VIE_ENG.drop(columns=["Vĩnh Long 2"], inplace=True)
# Out:
# /tmp/ipython-input-1583392658.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Vĩnh Long"] *= danso_dict["Vĩnh Long"]
# /tmp/ipython-input-1583392658.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Vĩnh Long 1"] *= danso_dict["Bến Tre"]
# /tmp/ipython-input-1583392658.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
# Bước 1: Nhân dân số cho 2 cột (NaN sẽ tự được bỏ qua)
df_2024_PAPI_VIE_ENG["Đồng Tháp"] = df_2024_PAPI_VIE_ENG["Đồng Tháp"] * danso_dict["Đồng Tháp"]
df_2024_PAPI_VIE_ENG["Đồng Tháp 1"] = df_2024_PAPI_VIE_ENG["Đồng Tháp 1"] * danso_dict["Tiền Giang"]

# Bước 2: Tính trung bình có trọng số, bỏ qua NaN
df_2024_PAPI_VIE_ENG["Đồng Tháp"] = (
    df_2024_PAPI_VIE_ENG["Đồng Tháp"] + df_2024_PAPI_VIE_ENG["Đồng Tháp 1"].fillna(0)
) / (
    danso_dict["Đồng Tháp"] +
    (danso_dict["Tiền Giang"] * (~df_2024_PAPI_VIE_ENG["Đồng Tháp 1"].isna()))
)
# Bước 3: Xóa cột "Đồng Tháp 1" (Tiền Giang)
df_2024_PAPI_VIE_ENG.drop(columns=["Đồng Tháp 1"], inplace=True)
# Out:
# /tmp/ipython-input-1686129101.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đồng Tháp"] = df_2024_PAPI_VIE_ENG["Đồng Tháp"] * danso_dict["Đồng Tháp"]
# /tmp/ipython-input-1686129101.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Đồng Tháp 1"] = df_2024_PAPI_VIE_ENG["Đồng Tháp 1"] * danso_dict["Tiền Giang"]
# /tmp/ipython-input-1686129101.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
# Bước 1: Nhân dân số cho 2 cột (NaN sẽ tự được bỏ qua)
df_2024_PAPI_VIE_ENG["Cà Mau"] = df_2024_PAPI_VIE_ENG["Cà Mau"] * danso_dict["Cà Mau"]
df_2024_PAPI_VIE_ENG["Cà Mau 1"] = df_2024_PAPI_VIE_ENG["Cà Mau 1"] * danso_dict["Bạc Liêu"]

# Bước 2: Tính trung bình có trọng số, bỏ qua NaN
df_2024_PAPI_VIE_ENG["Cà Mau"] = (
    df_2024_PAPI_VIE_ENG["Cà Mau"].fillna(0) + df_2024_PAPI_VIE_ENG["Cà Mau 1"]
) / (
    (danso_dict["Cà Mau"] * (~df_2024_PAPI_VIE_ENG["Cà Mau"].isna())) +
    danso_dict["Bạc Liêu"]
)
# Bước 3: Xóa cột "Cà Mau 1" (Bạc Liêu)
df_2024_PAPI_VIE_ENG.drop(columns=["Cà Mau 1"], inplace=True)
# Out:
# /tmp/ipython-input-4156030555.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Cà Mau"] = df_2024_PAPI_VIE_ENG["Cà Mau"] * danso_dict["Cà Mau"]
# /tmp/ipython-input-4156030555.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["Cà Mau 1"] = df_2024_PAPI_VIE_ENG["Cà Mau 1"] * danso_dict["Bạc Liêu"]
# /tmp/ipython-input-4156030555.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
## Bước 1: Nhân dân số cho hai cột
df_2024_PAPI_VIE_ENG["An Giang"] *= danso_dict["An Giang"]
df_2024_PAPI_VIE_ENG["An Giang 1"] *= danso_dict["Kiên Giang"]

# Bước 2: Tính trung bình có trọng số và ghi đè vào cột "An Giang"
df_2024_PAPI_VIE_ENG["An Giang"] = (
    df_2024_PAPI_VIE_ENG["An Giang"] + df_2024_PAPI_VIE_ENG["An Giang 1"]
) / (danso_dict["An Giang"] + danso_dict["Kiên Giang"])

# Bước 3: Xóa cột "An Giang 1" (Kiên Giang)
df_2024_PAPI_VIE_ENG.drop(columns=["An Giang 1"], inplace=True)
# Out:
# /tmp/ipython-input-772890966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["An Giang"] *= danso_dict["An Giang"]
# /tmp/ipython-input-772890966.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_PAPI_VIE_ENG["An Giang 1"] *= danso_dict["Kiên Giang"]
# /tmp/ipython-input-772890966.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2024_PAPI_VIE_ENG
# Out:
#                   Tỉnh/Thành phố trực thuộc trung ương  \
# 0                                Unweighted PAPI Score
# 1                                Unweighted 95% CI Low
# 2                               Unweighted 95% CI High
# 3                            Unweighted Standard Error
# 4                           Dimension 1: Participation
# ..                                                 ...
# 153  Proportion of Respondents Who Used Local Gover...
# 154  Proportion of Respondents that Knows Provincia...
# 155  Proportion of Respondents Aware that Province ...
# 156              Used Online Government Service Portal
# 157                     Able to Pay for Service Online
#
#                 Tỉnh/Thành phố trực thuộc trung ương.1         Thang điểm  \
# 0             Chỉ số PAPI tổng hợp (không có trọng số)  10-80 điểm/points
# 1    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# 2    Chỉ số PAPI tổng hợp (không có trọng số) - điể...                NaN
# ...

# %%
from google.colab import files

# Xuất DataFrame ra file CSV với encoding UTF-8 để hiển thị tiếng Việt đúng
file_name = "PAPI 2024 34 đơn vị hành chính.csv"
df_2024_PAPI_VIE_ENG.to_csv(file_name, index=False, encoding="utf-8-sig")

# Tải file về máy
files.download(file_name)
